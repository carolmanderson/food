# %%
from collections import Counter
import os

import pandas as pd
from sklearn.model_selection import train_test_split

# %%
recipe_file = "/Users/Carol/Dropbox/epicurious-recipes-with-rating-and-nutrition/full_format_recipes.json"

# %%
recipe_df = pd.read_json(recipe_file, orient='records')
recipe_df.head(2)
# Out:
#    calories                                         categories  \
# 0     426.0  [Sandwich, Bean, Fruit, Tomato, turkey, Vegeta...
# 1     403.0  [Food Processor, Onion, Pork, Bake, Bastille D...
#
#                  date                                               desc  \
# 0 2006-09-01 04:00:00                                               None
# 1 2004-08-20 04:00:00  This uses the same ingredients found in boudin...
#
#                                           directions   fat  \
# 0  [1. Place the stock, lentils, celery, carrot, ...   7.0
# 1  [Combine first 9 ingredients in heavy medium s...  23.0
#
#                                          ingredients  protein  rating  sodium  \
# 0  [4 cups low-sodium vegetable or chicken stock,...     30.0   2.500   559.0
# 1  [1 1/2 cups whipping cream, 2 medium onions, c...     18.0   4.375  1439.0
#
#                                          title
# 0              Lentil, Apple, and Turkey Wrap
# 1  Boudin Blanc Terrine with Red Onion Confit

# %%
recipe_df.shape
# Out:
# (20130, 11)

# %%
recipe_df['categories'] = recipe_df['categories'].fillna(value="")

# %%
deduped = recipe_df.drop_duplicates(subset="title", keep="first")

# %%
deduped.shape
# Out:
# (17776, 11)

# %%
# compile all the categories and their counts
cats = deduped.categories.tolist()
all_cats = []
for cat in cats:
    if isinstance(cat, float):
        print(cat)
    else:
        all_cats.extend(cat)

# %%
cat_counts = Counter(all_cats)
cat_counts.most_common()
# Out:
# [('Bon Appétit', 8470),
#  ('Peanut Free', 7564),
#  ('Soy Free', 7279),
#  ('Tree Nut Free', 6302),
#  ('Vegetarian', 6027),
#  ('Gourmet', 5745),
#  ('Kosher', 5511),
#  ('Pescatarian', 5399),
#  ('Quick & Easy', 4728),
#  ('Wheat/Gluten-Free', 4357),
#  ('Bake', 4035),
#  ('Summer', 3762),
#  ('Dessert', 3153),
#  ('Dairy Free', 2853),
#  ('No Sugar Added', 2792),
#  ('Winter', 2768),
#  ('Side', 2710),
#  ('Fall', 2676),
#  ('Dinner', 2535),
#  ('Sugar Conscious', 2172),
#  ('Healthy', 2158),
#  ('Tomato', 1961),
#  ('Kidney Friendly', 1955),
#  ('Onion', 1934),
#  ('Sauté', 1900),
#  ('Vegetable', 1876),
#  ('Fruit', 1807),
#  ('Milk/Cream', 1791),
#  ('Kid-Friendly', 1653),
#  ('Egg', 1599),
#  ('Spring', 1540),
#  ('Vegan', 1535),
#  ('Herb', 1490),
#  ('Garlic', 1438),
#  ('Salad', 1432),
#  ('Dairy', 1336),
#  ('Appetizer', 1305),
#  ('Lunch', 1284),
#  ('Cheese', 1273),
#  ('Chicken', 1240),
#  ('Thanksgiving', 1228),
#  ('Roast', 1173),
#  ('Cocktail Party', 1041),
#  ('Potato', 1032),
#  ('Ginger', 1030),
#  ('Soup/Stew', 1014),
#  ('No-Cook', 1012),
#  ('Grill/Barbecue', 1012),
#  ('Lemon', 982),
#  ('Drink', 977),
#  ('Chill', 969),
#  ('High Fiber', 969),
#  ('Low Cal', 935),
#  ('Pasta', 934),
#  ('Christmas', 897),
#  ('Pork', 872),
#  ('Fish', 872),
#  ('Food Processor', 861),
#  ('Leafy Green', 856),
#  ('Backyard BBQ', 835),
#  ('Low Fat', 831),
#  ('Nut', 831),
#  ('Party', 806),
#  ('Mushroom', 791),
#  ('Brunch', 783),
#  ('Orange', 771),
#  ('Chocolate', 769),
#  ('Citrus', 766),
#  ('Alcoholic', 759),
#  ('Beef', 744),
#  ('Simmer', 705),
#  ('Bell Pepper', 705),
#  ('Sauce', 685),
#  ('Paleo', 683),
#  ('Breakfast', 677),
#  ('Condiment/Spread', 674),
#  ('Cake', 672),
#  ('Carrot', 609),
#  ('Parmesan', 609),
#  ('Apple', 602),
#  ('Spice', 592),
#  ('Mixer', 565),
#  ('Mint', 557),
#  ('Poultry', 551),
#  ('Marinate', 551),
#  ('Vinegar', 549),
#  ('Bacon', 548),
#  ('Almond', 542),
#  ('Blender', 538),
#  ('Bean', 537),
#  ('Pepper', 537),
#  ('Cilantro', 532),
#  ('Shellfish', 527),
#  ('Mustard', 524),
#  ('Basil', 521),
#  ('Olive', 511),
#  ('Grill', 507),
#  ('Yogurt', 489),
#  ('Lime', 487),
#  ('Shrimp', 478),
#  ('Picnic', 474),
#  ('Rice', 464),
#  ('Potluck', 454),
#  ('Broil', 444),
#  ('Parsley', 439),
#  ('White Wine', 437),
#  ('Bread', 428),
#  ('Fruit Juice', 427),
#  ('House & Garden', 417),
#  ('Berry', 413),
#  ('Hot Pepper', 412),
#  ('Cinnamon', 411),
#  ('Sandwich', 406),
#  ('Walnut', 401),
#  ('Fry', 386),
#  ('Seafood', 382),
#  ('Low Cholesterol', 380),
#  ('Freeze/Chill', 366),
#  ('Honey', 365),
#  ('turkey', 362),
#  ('Cucumber', 359),
#  ('Boil', 358),
#  ('Spinach', 357),
#  ('Sausage', 356),
#  ('Sour Cream', 355),
#  ('Cream Cheese', 346),
#  ('Corn', 345),
#  ('Mayonnaise', 344),
#  ('Fennel', 341),
#  ('Low Sodium', 340),
#  ('Cocktail', 339),
#  ('Coconut', 337),
#  ('Fourth of July', 337),
#  ('Rosemary', 336),
#  ('Lamb', 333),
#  ('Low Carb', 327),
#  ('Cranberry', 327),
#  ('Frozen Dessert', 320),
#  ('Pecan', 315),
#  ('Raspberry', 313),
#  ('Raisin', 313),
#  ('Jalapeño', 311),
#  ('Shallot', 305),
#  ('Rum', 305),
#  ('Braise', 302),
#  ('Shower', 300),
#  ('Fat Free', 299),
#  ('Goat Cheese', 298),
#  ('Salmon', 298),
#  ('Thyme', 297),
#  ('Self', 296),
#  ('Liqueur', 291),
#  ('Christmas Eve', 289),
#  ('Super Bowl', 288),
#  ('Strawberry', 286),
#  ('Cabbage', 286),
#  ('Zucchini', 285),
#  ('Family Reunion', 282),
#  ('Celery', 273),
#  ('Sweet Potato/Yam', 270),
#  ('Pear', 268),
#  ("Father's Day", 266),
#  ('Meat', 265),
#  ('Soy Sauce', 264),
#  ('Curry', 258),
#  ('Arugula', 257),
#  ('Avocado', 247),
#  ('Apricot', 246),
#  ('Low/No Sugar', 246),
#  ('Dill', 243),
#  ('Red Wine', 242),
#  ('Leek', 240),
#  ('Brandy', 239),
#  ('Pineapple', 239),
#  ('Cookies', 238),
#  ('Steak', 236),
#  ('Cheddar', 236),
#  ('Pan-Fry', 235),
#  ('Cornmeal', 228),
#  ('Vanilla', 227),
#  ('Chive', 226),
#  ('Cherry', 226),
#  ('Blue Cheese', 225),
#  ('Tarragon', 223),
#  ('Feta', 220),
#  ('Mango', 218),
#  ("Valentine's Day", 217),
#  ('Stir-Fry', 216),
#  ('Ham', 211),
#  ('Green Bean', 211),
#  ('Lettuce', 210),
#  ('Chile Pepper', 210),
#  ('Pine Nut', 210),
#  ('Eggplant', 206),
#  ('Easter', 205),
#  ('Gin', 205),
#  ('Spirit', 205),
#  ('Steam', 201),
#  ('Dried Fruit', 197),
#  ('Asparagus', 197),
#  ('Beet', 197),
#  ('Pea', 196),
#  ('Radish', 192),
#  ('Non-Alcoholic', 187),
#  ('Back to School', 185),
#  ('Casserole/Gratin', 183),
#  ('Mozzarella', 181),
#  ('Peach', 178),
#  ('Coffee', 177),
#  ('Butternut Squash', 174),
#  ('Stew', 172),
#  ('Banana', 171),
#  ('Birthday', 171),
#  ('Root Vegetable', 169),
#  ('Wine', 169),
#  ('Engagement Party', 168),
#  ('Hazelnut', 168),
#  ('Blueberry', 168),
#  ('Capers', 167),
#  ('Sage', 167),
#  ('Butter', 166),
#  ('Pistachio', 163),
#  ('Clove', 161),
#  ("Mother's Day", 160),
#  ('Scallop', 160),
#  ('Passover', 159),
#  ('Noodle', 158),
#  ('Ricotta', 153),
#  ('Cinco de Mayo', 152),
#  ('Chickpea', 151),
#  ('Prosciutto', 149),
#  ('Horseradish', 149),
#  ('Crab', 147),
#  ('Artichoke', 145),
#  ('Tortillas', 145),
#  ('Peanut', 144),
#  ('Fig', 143),
#  ('Jam or Jelly', 141),
#  ('Squash', 141),
#  ('Maple Syrup', 141),
#  ('California', 138),
#  ('Ice Cream Machine', 137),
#  ('Lemon Juice', 135),
#  ('Blackberry', 134),
#  ('Kale', 133),
#  ("New Year's Eve", 132),
#  ('Watercress', 131),
#  ('Oat', 131),
#  ('Seed', 130),
#  ('Tuna', 129),
#  ('Sesame', 129),
#  ('Poach', 129),
#  ('Salad Dressing', 128),
#  ('Parsnip', 126),
#  ('Buffet', 126),
#  ('Clam', 123),
#  ('Poker/Game Night', 122),
#  ('Phyllo/Puff Pastry Dough', 122),
#  ('Mussel', 121),
#  ('Tailgating', 119),
#  ('Lime Juice', 118),
#  ('Bitters', 117),
#  ('HarperCollins', 117),
#  ('Parade', 117),
#  ('Date', 116),
#  ('Grapefruit', 114),
#  ('Coriander', 114),
#  ('Broccoli', 114),
#  ('Pork Tenderloin', 114),
#  ('Bourbon', 113),
#  ('Vodka', 112),
#  ('Cauliflower', 112),
#  ('Veal', 110),
#  ('Pumpkin', 109),
#  ('Stuffing/Dressing', 109),
#  ('Anniversary', 108),
#  ('Green Onion/Scallion', 108),
#  ('Plum', 108),
#  ('Sherry', 108),
#  ('Endive', 107),
#  ('Molasses', 106),
#  ('Soy', 104),
#  ('Oscars', 102),
#  ('Wedding', 102),
#  ('Port', 101),
#  ('Beer', 101),
#  ('Currant', 101),
#  ('Advance Prep Required', 100),
#  ('Saffron', 99),
#  ('Hanukkah', 99),
#  ('Prune', 99),
#  ('Tree Nut', 98),
#  ('Anise', 98),
#  ('Wok', 96),
#  ('Tea', 95),
#  ('Lentil', 94),
#  ('Edible Gift', 93),
#  ('Nutmeg', 92),
#  ('Oregano', 92),
#  ('Pork Chop', 91),
#  ('Tofu', 89),
#  ('Duck', 88),
#  ('Ground Beef', 87),
#  ('Halibut', 86),
#  ('Couscous', 86),
#  ('Bass', 86),
#  ('Tequila', 84),
#  ('Turnip', 83),
#  ('Deep-Fry', 82),
#  ('Cumin', 81),
#  ('Champagne', 80),
#  ('Condiment', 79),
#  ('Cognac/Armagnac', 79),
#  ('Hominy/Cornmeal/Masa', 78),
#  ('Chard', 77),
#  ('Lobster', 77),
#  ('Lemongrass', 75),
#  ('Graduation', 75),
#  ('Sugar Snap Pea', 74),
#  ("New Year's Day", 73),
#  ('Pastry', 73),
#  ('Triple Sec', 73),
#  ('Rhubarb', 73),
#  ('Cod', 71),
#  ('Swiss Cheese', 71),
#  ('Fortified Wine', 71),
#  ('Pomegranate', 70),
#  ('Buttermilk', 70),
#  ('Watermelon', 70),
#  ('Beef Tenderloin', 67),
#  ('Grape', 67),
#  ('Raw', 67),
#  ('Chestnut', 65),
#  ('Legume', 65),
#  ('Cookie', 64),
#  ('Quick and Healthy', 64),
#  ('Cashew', 63),
#  ('Rosh Hashanah/Yom Kippur', 63),
#  ('Melon', 61),
#  ('Nectarine', 60),
#  ('Tomatillo', 59),
#  ('Tropical Fruit', 58),
#  ('Candy', 57),
#  ('Punch', 56),
#  ('Bok Choy', 56),
#  ('Snapper', 55),
#  ('Brussel Sprout', 54),
#  ('Pork Rib', 53),
#  ('Breadcrumbs', 52),
#  ('Beef Rib', 52),
#  ('Whiskey', 52),
#  ('Pernod', 52),
#  ('Cantaloupe', 51),
#  ('Lima Bean', 51),
#  ('Sparkling Wine', 51),
#  ("St. Patrick's Day", 50),
#  ('Trout', 50),
#  ('Mardi Gras', 49),
#  ('Candy Thermometer', 49),
#  ('Barley', 49),
#  ('Quinoa', 48),
#  ('New York', 47),
#  ('Papaya', 47),
#  ('Paprika', 46),
#  ('Orange Juice', 46),
#  ('Monterey Jack', 46),
#  ('Macadamia Nut', 46),
#  ('Massachusetts', 45),
#  ('Squid', 45),
#  ('Broccoli Rabe', 44),
#  ('Lunar New Year', 44),
#  ('Escarole', 42),
#  ('Passion Fruit', 42),
#  ('Smoothie', 42),
#  ('Lamb Chop', 42),
#  ('Cardamom', 41),
#  ('Anchovy', 41),
#  ('Florida', 39),
#  ('Rutabaga', 39),
#  ('Kumquat', 38),
#  ('Honeydew', 38),
#  ('Halloween', 37),
#  ('Microwave', 36),
#  ('Amaretto', 36),
#  ('Marsala', 36),
#  ('Fontina', 35),
#  ('Ramadan', 35),
#  ('Oyster', 35),
#  ('Sesame Oil', 35),
#  ('Cottage Cheese', 35),
#  ('Mustard Greens', 34),
#  ('Game', 34),
#  ('Jícama', 33),
#  ('Brisket', 33),
#  ('Oktoberfest', 33),
#  ('Kentucky Derby', 33),
#  ('Ramekin', 33),
#  ('Kiwi', 33),
#  ('Peanut Butter', 32),
#  ('Weelicious', 32),
#  ('Ground Lamb', 32),
#  ('Brine', 32),
#  ('Tangerine', 32),
#  ('Hot Drink', 31),
#  ('Kirsch', 30),
#  ('Pennsylvania', 30),
#  ('Double Boiler', 29),
#  ('Bulgur', 29),
#  ('Whole Wheat', 29),
#  ('Collard Greens', 28),
#  ('Kosher for Passover', 28),
#  ('Bastille Day', 27),
#  ('Quince', 27),
#  ('Rack of Lamb', 27),
#  ('3-Ingredient Recipes', 27),
#  ('Caraway', 26),
#  ('snack', 26),
#  ('Yellow Squash', 25),
#  ('Okra', 25),
#  ('Washington', 24),
#  ('Michigan', 24),
#  ('New Jersey', 24),
#  ('Wasabi', 23),
#  ('Slow Cooker', 23),
#  ('Kahlúa', 22),
#  ('Shavuot', 21),
#  ('Texas', 21),
#  ('Frangelico', 21),
#  ('Poultry Sausage', 21),
#  ('Los Angeles', 21),
#  ('Sake', 21),
#  ('Créme de Cacao', 21),
#  ('Diwali', 21),
#  ('Scotch', 20),
#  ('Pie', 20),
#  ('Georgia', 20),
#  ('Asian Pear', 19),
#  ('Guava', 19),
#  ('Calvados', 19),
#  ('Poppy', 19),
#  ('Brown Rice', 19),
#  ('Tamarind', 19),
#  ('Oregon', 18),
#  ('Plantain', 18),
#  ('Margarita', 18),
#  ('Jerusalem Artichoke', 18),
#  ('Chartreuse', 18),
#  ('Dip', 18),
#  ('22-Minute Meals', 17),
#  ('Campari', 17),
#  ('Radicchio', 17),
#  ('snack week', 17),
#  ("Hors D'Oeuvre", 17),
#  ('North Carolina', 17),
#  ('Wild Rice', 17),
#  ('Iced Tea', 17),
#  ('Lamb Shank', 16),
#  ('Swordfish', 16),
#  ('Pickles', 16),
#  ('Sangria', 16),
#  ('Quail', 15),
#  ('Colorado', 15),
#  ('Rye', 14),
#  ('Coffee Grinder', 14),
#  ('Portland', 14),
#  ('Sukkot', 14),
#  ('Goose', 14),
#  ('Semolina', 14),
#  ('Beef Shank', 13),
#  ('Ohio', 13),
#  ('Missouri', 13),
#  ('Chile', 13),
#  ('Butterscotch/Caramel', 12),
#  ('Pasadena', 12),
#  ('Brie', 12),
#  ('Flaming Hot Summer', 12),
#  ('Ice Cream', 12),
#  ('Purim', 12),
#  ('Tapioca', 12),
#  ('New Mexico', 12),
#  ('Sandwich Theory', 12),
#  ('Maryland', 12),
#  ('France', 12),
#  ('One-Pot Meal', 11),
#  ('Ireland', 11),
#  ('Chambord', 11),
#  ('Minnesota', 11),
#  ('Oatmeal', 11),
#  ('Persimmon', 11),
#  ('Virginia', 11),
#  ('Tilapia', 11),
#  ('Gouda', 10),
#  ('Connecticut', 10),
#  ('Kwanzaa', 10),
#  ('South Carolina', 10),
#  ('Drinks', 10),
#  ('Bon App��tit', 10),
#  ('Pasta Maker', 10),
#  ('Santa Monica', 9),
#  ('Grains', 9),
#  ('Friendsgiving', 9),
#  ('Low Sugar', 9),
#  ('Pittsburgh', 9),
#  ('Marshmallow', 9),
#  ('Venison', 9),
#  ('Labor Day', 9),
#  ('Vermouth', 9),
#  ('Seattle', 8),
#  ('Aperitif', 8),
#  ('Washington, D.C.', 8),
#  ('San Francisco', 8),
#  ('Entertaining', 8),
#  ('Rhode Island', 8),
#  ('Tart', 8),
#  ('Canada', 8),
#  ('Taco', 8),
#  ('Pizza', 8),
#  ('Meatball', 8),
#  ('Arizona', 8),
#  ('Eau de Vie', 8),
#  ('30 Days of Groceries', 7),
#  ('Egg Nog', 7),
#  ('Pressure Cooker', 7),
#  ('Poblano', 7),
#  ('Lychee', 7),
#  ('Skewer', 7),
#  ('Brooklyn', 7),
#  ('Illinois', 7),
#  ('Rabbit', 7),
#  ('Mandoline', 7),
#  ('St. Louis', 7),
#  ('Atlanta', 7),
#  ('leftovers', 7),
#  ('Biscuit', 7),
#  ('Spritzer', 7),
#  ('Apple Juice', 6),
#  ('No Meat, No Problem', 6),
#  ('House Cocktail', 6),
#  ('Buffalo', 6),
#  ('Yuca', 6),
#  ('#CAKEWEEK', 6),
#  ('Smoker', 6),
#  ('Italy', 6),
#  ('Juicer', 6),
#  ('Octopus', 6),
#  ('Cobbler/Crumble', 6),
#  ('Pomegranate Juice', 6),
#  ('Martini', 6),
#  ('Salsa', 6),
#  ('Australia', 5),
#  ('Pancake', 5),
#  ('Mexico', 5),
#  ('Organic', 5),
#  ('Marscarpone', 5),
#  ('Boston', 5),
#  ('Granola', 5),
#  ('Muffin', 5),
#  ('Lingonberry', 5),
#  ('Philippines', 5),
#  ('Vermont', 5),
#  ('Midori', 5),
#  ('Dallas', 4),
#  ('Hamburger', 4),
#  ('Wisconsin', 4),
#  ('Rosé', 4),
#  ('Cook Like a Diner', 4),
#  ('Persian New Year', 4),
#  ('Louisiana', 4),
#  ('Flat Bread', 4),
#  ('Sardine', 4),
#  ('Grappa', 4),
#  ('Paris', 4),
#  ('Lancaster', 4),
#  ('Cranberry Sauce', 4),
#  ('Hawaii', 4),
#  ('Maine', 4),
#  ('Switzerland', 4),
#  ('Kansas', 3),
#  ('Bran', 3),
#  ('cookbooks', 3),
#  ('Macaroni and Cheese', 3),
#  ('Denver', 3),
#  ('Utah', 3),
#  ('Freezer Food', 3),
#  ('Stock', 3),
#  ('Cupcake', 3),
#  ('Chicago', 3),
#  ('Indiana', 3),
#  ('Columbus', 3),
#  ('Lasagna', 3),
#  ('Cambridge', 3),
#  ('Kentucky', 3),
#  ('Cookbook Critic', 3),
#  ('Brownie', 3),
#  ('Alabama', 3),
#  ('Digestif', 3),
#  ('Soufflé/Meringue', 3),
#  ('Oklahoma', 3),
#  ('Rub', 3),
#  ('Cuba', 3),
#  ('Spain', 2),
#  ('Chili', 2),
#  ('Omelet', 2),
#  ('Potato Salad', 2),
#  ('New Orleans', 2),
#  ('Tennessee', 2),
#  ('Pot Pie', 2),
#  ('Japan', 2),
#  ('Miami', 2),
#  ('Orzo', 2),
#  ('Dominican Republic', 2),
#  ('Custard', 2),
#  ('Long Beach', 2),
#  ('Peru', 2),
#  ('Louisville', 2),
#  ('Hummus', 2),
#  ('Israel', 2),
#  ('Mortar and Pestle', 2),
#  ('Minneapolis', 2),
#  ('Nebraska', 2),
#  ('Epi Loves the Microwave', 2),
#  ('Healdsburg', 2),
#  ('Kansas City', 2),
#  ('Frittata', 2),
#  ('Meatloaf', 2),
#  ('Epi + USHG', 2),
#  ('Iced Coffee', 2),
#  ('Anthony Bourdain', 2),
#  ('Alaska', 2),
#  ('Guam', 1),
#  ('Hollywood', 1),
#  ('Kitchen Olympics', 1),
#  ('Haiti', 1),
#  ('Costa Mesa', 1),
#  ('Yonkers', 1),
#  ('Tested & Improved', 1),
#  ('Grand Marnier', 1),
#  ('Aspen', 1),
#  ('Waffle', 1),
#  ('Caviar', 1),
#  ('Suzanne Goin', 1),
#  ('Iowa', 1),
#  ('Sorbet', 1),
#  ('Cr��me de Cacao', 1),
#  ('Idaho', 1),
#  ('Westwood', 1),
#  ('Providence', 1),
#  ('#WasteLess', 1),
#  ('London', 1),
#  ('England', 1),
#  ('Nancy Silverton', 1),
#  ('Dorie Greenspan', 1),
#  ('Frankenrecipe', 1),
#  ('Emeril Lagasse', 1),
#  ('Beverly Hills', 1),
#  ('West Virginia', 1),
#  ('Mezcal', 1),
#  ('Windsor', 1),
#  ('Jamaica', 1),
#  ('Burrito', 1),
#  ('Las Vegas', 1),
#  ('Bulgaria', 1),
#  ('Camping', 1),
#  ('Fritter', 1),
#  ('Egypt', 1),
#  ('Houston', 1),
#  ('Germany', 1),
#  ('Quiche', 1),
#  ('Marinade', 1),
#  ('Pacific Palisades', 1),
#  ('Mississippi', 1),
#  ('Crêpe', 1),
#  ('Sourdough', 1)]

# %%
# Some interesting categories

cat_lists = [["Breakfast", "Lunch", "Dinner", "Appetizer", "Dessert"], ["Winter", "Spring", "Summer", "Fall"],
            ["Quick & Easy", "Gourmet"], ["Sugar Conscious", "Kidney Friendly", "Healthy", "Wheat/Gluten-Free", "Kosher", "Vegan"]]

for c_list in cat_lists:
    for c in c_list:
        print("{} : ".format(c), cat_counts[c])
    print("========")
# Out:
# Breakfast :  677
# Lunch :  1284
# Dinner :  2535
# Appetizer :  1305
# Dessert :  3153
# ========
# Winter :  2768
# Spring :  1540
# Summer :  3762
# Fall :  2676
# ========
# Quick & Easy :  4728
# Gourmet :  5745
# ========
# Sugar Conscious :  2172
# Kidney Friendly :  1955
# Healthy :  2158
# Wheat/Gluten-Free :  4357
# Kosher :  5511
# Vegan :  1535
# ========

# %%
def filter_by_category(df, category):
    mask = df.categories.apply(lambda x: category in x)
    selected = df[mask]
    return selected

def exclude_category(df, category):
    mask = df.categories.apply(lambda x: category not in x)
    selected = df[mask]
    return selected

winter = filter_by_category(deduped, "Winter")
winter.head()
# Out:
#     calories                                         categories  \
# 1      403.0  [Food Processor, Onion, Pork, Bake, Bastille D...
# 7        NaN  [Egg, Fruit, No-Cook, Cocktail Party, Vegetari...
# 15     382.0  [Soup/Stew, Garlic, Onion, No-Cook, Vegetarian...
# 24     279.0  [Nut, Bake, Cocktail Party, Super Bowl, Quick ...
# 25      95.0  [Bread, Condiment/Spread, Fry, No-Cook, Quick ...
#
#                   date                                               desc  \
# 1  2004-08-20 04:00:00  This uses the same ingredients found in boudin...
# 7  2004-08-20 04:00:00  Pop one of these in your mouth for a burst of ...
# 15 2004-08-20 04:00:00  This uncooked soup isn't for the timid — raw g...
# 24 2007-01-18 04:25:29                                               None
# 25 2004-08-20 04:00:00                                               None
#
#                                            directions   fat  \
# 1   [Combine first 9 ingredients in heavy medium s...  23.0
# 7   [Stir together sugar and chili powder. Whisk e...   NaN
# 15  [Purée vegetable juice, spinach, and escarole ...  31.0
# 24  [Preheat oven to 325°F. Toss pecans and melted...  30.0
# 25  [Mince garlic and mash to a paste with a pinch...   7.0
#
#                                           ingredients  protein  rating  \
# 1   [1 1/2 cups whipping cream, 2 medium onions, c...     18.0   4.375
# 7   [6 tablespoons granulated sugar, 1 1/2 tablesp...      NaN   3.750
# 15  [2 cups fresh tomato and/or carrot juice (from...      5.0   4.375
# 24  [2 cups pecan halves, 3 tablespoons unsalted b...      3.0   3.750
# 25  [1 garlic clove, 2 tablespoons olive oil, 1/4 ...      1.0   0.000
#
#     sodium                                        title
# 1   1439.0  Boudin Blanc Terrine with Red Onion Confit
# 7      NaN                        Spicy-Sweet Kumquats
# 15   977.0                   Raw Cream of Spinach Soup
# 24   206.0                     Sea Salt-Roasted Pecans
# 25   103.0                      Garlic Baguette Crumbs

# %%
winter.iloc[1,1]
# Out:
# ['Egg',
#  'Fruit',
#  'No-Cook',
#  'Cocktail Party',
#  'Vegetarian',
#  'Winter',
#  'Kumquat',
#  'Gourmet']

# %%
gf = filter_by_category(deduped, 'Wheat/Gluten-Free')

# %%
gf.head()
# Out:
#     calories                                         categories  \
# 6        NaN  [Salad, Potato, Side, Easter, Low Fat, Quick &...
# 9      602.0  [Salad, Mustard, Potato, Picnic, Lunch, Mayonn...
# 13     174.0  [Garlic, Sauté, Low Carb, Quick & Easy, Wheat/...
# 16     146.0  [Bread, Milk/Cream, Breakfast, Brunch, Dessert...
# 19     421.0  [Potato, High Fiber, Lunch, Tuna, Asparagus, R...
#
#                   date                                               desc  \
# 6  2004-08-20 04:00:00  Serve this newfangled main-course salad with a...
# 9  2008-10-23 22:24:26  Transform your picnic into un pique-nique to r...
# 13 2004-08-20 04:00:00  This recipe can be prepared in 45 minutes or l...
# 16 2008-12-04 04:00:00  Classic spoon bread is a savory pudding served...
# 19 2009-03-04 04:00:00  A springy take on Niçoise salad, with radishes...
#
#                                            directions   fat  \
# 6   [Cook potatoes and carrots in large pot of boi...   NaN
# 9   [Chop enough parsley leaves to measure 1 table...  41.0
# 13  [Sprinkle steaks with salt and pepper. Heat oi...  12.0
# 16  [Butter and sugar six 2/3-to 3/4-cup ramekins....   5.0
# 19  [Puree first 5 ingredients in blender until sm...  33.0
#
#                                           ingredients  protein  rating  \
# 6   [1 1/2 pounds small red-skinned potatoes, each...      NaN   4.375
# 9   [6 long parsley sprigs, divided, 1 3/4 cups re...     23.0   3.750
# 13  [4 6- to 7-ounce beef tenderloin steaks (each ...     11.0   4.375
# 16  [1 cup water, 2/3 cup buttermilk, 1/3 cup heav...      4.0   1.875
# 19  [1/3 cup chopped fresh chives, 1/4 cup Champag...     10.0   5.000
#
#     sodium                                              title
# 6      NaN  Ham and Spring Vegetable Salad with Shallot Vi...
# 9   1696.0  Ham Persillade with Mustard Potato Salad and M...
# 13   176.0            Beef Tenderloin with Garlic and Brandy
# 16   160.0                     Sweet Buttermilk Spoon Breads
# 19   383.0  Tuna, Asparagus, and New Potato Salad with Chi...

# %%
non_gf = exclude_category(deduped, "Wheat/Gluten-Free")
non_gf.head()
# Out:
#    calories                                         categories  \
# 0     426.0  [Sandwich, Bean, Fruit, Tomato, turkey, Vegeta...
# 1     403.0  [Food Processor, Onion, Pork, Bake, Bastille D...
# 2     165.0  [Soup/Stew, Dairy, Potato, Vegetable, Fennel, ...
# 3       NaN  [Fish, Olive, Tomato, Sauté, Low Fat, Low Cal,...
# 4     547.0  [Cheese, Dairy, Pasta, Vegetable, Side, Bake, ...
#
#                  date                                               desc  \
# 0 2006-09-01 04:00:00                                               None
# 1 2004-08-20 04:00:00  This uses the same ingredients found in boudin...
# 2 2004-08-20 04:00:00                                               None
# 3 2009-03-27 04:00:00  The Sicilian-style tomato sauce has tons of Me...
# 4 2004-08-20 04:00:00                                               None
#
#                                           directions   fat  \
# 0  [1. Place the stock, lentils, celery, carrot, ...   7.0
# 1  [Combine first 9 ingredients in heavy medium s...  23.0
# 2  [In a large heavy saucepan cook diced fennel a...   7.0
# 3  [Heat oil in heavy large skillet over medium-h...   NaN
# 4  [Preheat oven to 350°F. Lightly grease 8x8x2-i...  32.0
#
#                                          ingredients  protein  rating  sodium  \
# 0  [4 cups low-sodium vegetable or chicken stock,...     30.0   2.500   559.0
# 1  [1 1/2 cups whipping cream, 2 medium onions, c...     18.0   4.375  1439.0
# 2  [1 fennel bulb (sometimes called anise), stalk...      6.0   3.750   165.0
# 3  [2 tablespoons extra-virgin olive oil, 1 cup c...      NaN   5.000     NaN
# 4  [1 12-ounce package frozen spinach soufflé, th...     20.0   3.125   452.0
#
#                                          title
# 0              Lentil, Apple, and Turkey Wrap
# 1  Boudin Blanc Terrine with Red Onion Confit
# 2                Potato and Fennel Soup Hodge
# 3             Mahi-Mahi in Tomato Olive Sauce
# 4                    Spinach Noodle Casserole

# %%
non_gf.iloc[1, 6]
# Out:
# ['1 1/2 cups whipping cream',
#  '2 medium onions, chopped',
#  '5 teaspoons salt',
#  '3 bay leaves',
#  '3 whole cloves',
#  '1 large garlic clove, crushed',
#  '1 teaspoon pepper',
#  '1/8 teaspoon ground nutmeg',
#  'Pinch of dried thyme, crumbled',
#  '8 large shallots, minced',
#  '1 tablespoon butter',
#  '1 pound trimmed boneless center pork loin, sinew removed cut into 1-inch chunks, well chilled',
#  '3 eggs',
#  '6 tablespoon all purpose flour',
#  '1/4 cup tawny Port',
#  '3 tablespoons dried currants, minced',
#  'Lettuce leaves',
#  'Cracked peppercorns',
#  'Minced fresh parsley',
#  'Bay leaves',
#  'French bread baguette slices',
#  '3 tablespoons olive oil',
#  '2 large red onions, halved, sliced',
#  '3 tablespoons dried currants',
#  '3 tablespoons red wine vinegar',
#  '1 tablespoons canned chicken broth',
#  '2 teaspoons chopped fresh thyme or 3/4 teaspoon dried, crumbled',
#  '1/2 teaspoon sugar']

# %%
kosher = filter_by_category(deduped, "Kosher")
kosher.head()
# Out:
#     calories                                         categories  \
# 3        NaN  [Fish, Olive, Tomato, Sauté, Low Fat, Low Cal,...
# 12     766.0  [Cake, Chocolate, Fruit, Dessert, Bake, Kid-Fr...
# 16     146.0  [Bread, Milk/Cream, Breakfast, Brunch, Dessert...
# 19     421.0  [Potato, High Fiber, Lunch, Tuna, Asparagus, R...
# 26     215.0  [Egg, Herb, Vegetable, Side, Easter, Vegetaria...
#
#                   date                                               desc  \
# 3  2009-03-27 04:00:00  The Sicilian-style tomato sauce has tons of Me...
# 12 2012-09-18 04:00:00  This cake is perfect for beginners—it's moist,...
# 16 2008-12-04 04:00:00  Classic spoon bread is a savory pudding served...
# 19 2009-03-04 04:00:00  A springy take on Niçoise salad, with radishes...
# 26 2011-03-31 04:00:00  The glories of summer are captured in this pal...
#
#                                            directions   fat  \
# 3   [Heat oil in heavy large skillet over medium-h...   NaN
# 12  [Preheat oven to 350°F. Coat cake pans with no...  48.0
# 16  [Butter and sugar six 2/3-to 3/4-cup ramekins....   5.0
# 19  [Puree first 5 ingredients in blender until sm...  33.0
# 26  [Gently combine the eggs, cucumbers, shallots,...  20.0
#
#                                           ingredients  protein  rating  \
# 3   [2 tablespoons extra-virgin olive oil, 1 cup c...      NaN   5.000
# 12  [Nonstick vegetable oil spray, 3 cups all-purp...     12.0   4.375
# 16  [1 cup water, 2/3 cup buttermilk, 1/3 cup heav...      4.0   1.875
# 19  [1/3 cup chopped fresh chives, 1/4 cup Champag...     10.0   5.000
# 26  [6 hard-cooked eggs, diced (2 cups), 3/4 cup s...      6.0   3.750
#
#     sodium                                              title
# 3      NaN                   Mahi-Mahi in Tomato Olive Sauce
# 12   439.0  Banana-Chocolate Chip Cake With Peanut Butter ...
# 16   160.0                     Sweet Buttermilk Spoon Breads
# 19   383.0  Tuna, Asparagus, and New Potato Salad with Chi...
# 26   250.0                          Cucumber-Basil Egg Salad

# %%
non_kosher = exclude_category(deduped, "Kosher")
non_kosher.head()
# Out:
#    calories                                         categories  \
# 0     426.0  [Sandwich, Bean, Fruit, Tomato, turkey, Vegeta...
# 1     403.0  [Food Processor, Onion, Pork, Bake, Bastille D...
# 2     165.0  [Soup/Stew, Dairy, Potato, Vegetable, Fennel, ...
# 4     547.0  [Cheese, Dairy, Pasta, Vegetable, Side, Bake, ...
# 5     948.0  [Sandwich, Food Processor, Tomato, Kid-Friendl...
#
#                  date                                               desc  \
# 0 2006-09-01 04:00:00                                               None
# 1 2004-08-20 04:00:00  This uses the same ingredients found in boudin...
# 2 2004-08-20 04:00:00                                               None
# 4 2004-08-20 04:00:00                                               None
# 5 2004-08-20 04:00:00  This recipe can be prepared in 45 minutes or l...
#
#                                           directions   fat  \
# 0  [1. Place the stock, lentils, celery, carrot, ...   7.0
# 1  [Combine first 9 ingredients in heavy medium s...  23.0
# 2  [In a large heavy saucepan cook diced fennel a...   7.0
# 4  [Preheat oven to 350°F. Lightly grease 8x8x2-i...  32.0
# 5  [Mix basil, mayonnaise and butter in processor...  79.0
#
#                                          ingredients  protein  rating  sodium  \
# 0  [4 cups low-sodium vegetable or chicken stock,...     30.0   2.500   559.0
# 1  [1 1/2 cups whipping cream, 2 medium onions, c...     18.0   4.375  1439.0
# 2  [1 fennel bulb (sometimes called anise), stalk...      6.0   3.750   165.0
# 4  [1 12-ounce package frozen spinach soufflé, th...     20.0   3.125   452.0
# 5  [2 1/2 cups (lightly packed) fresh basil leave...     19.0   4.375  1042.0
#
#                                          title
# 0              Lentil, Apple, and Turkey Wrap
# 1  Boudin Blanc Terrine with Red Onion Confit
# 2                Potato and Fennel Soup Hodge
# 4                    Spinach Noodle Casserole
# 5                               The Best Blts

# %% [markdown]
# # Make a dataset for classifying by vegan, gluten-free, and kosher categories

# %%
cats = deduped.categories.tolist()
ingreds = deduped.ingredients.tolist()
titles = deduped.title.tolist()

new_rows = []

for cat, ingred, title in zip(cats, ingreds, titles):
    gf = False
    k = False
    v = False
    if "Wheat/Gluten-Free" in cat:
        gf = True
    if "Kosher" in cat:
        k = True
    if "Vegan" in cat:
        v = True
    labels = (gf, k, v)
    new_row = {"title": title, "ingredients": ingred, "gluten_free": gf, "kosher" : k,
              "vegan": v}
    new_rows.append(new_row)
    

labeled = pd.DataFrame(new_rows)
labeled = labeled[["title", "ingredients", "gluten_free", "kosher", "vegan"]]
labeled.head()
# Out:
#                                          title  \
# 0              Lentil, Apple, and Turkey Wrap
# 1  Boudin Blanc Terrine with Red Onion Confit
# 2                Potato and Fennel Soup Hodge
# 3             Mahi-Mahi in Tomato Olive Sauce
# 4                    Spinach Noodle Casserole
#
#                                          ingredients  gluten_free  kosher  \
# 0  [4 cups low-sodium vegetable or chicken stock,...        False   False
# 1  [1 1/2 cups whipping cream, 2 medium onions, c...        False   False
# 2  [1 fennel bulb (sometimes called anise), stalk...        False   False
# 3  [2 tablespoons extra-virgin olive oil, 1 cup c...        False    True
# 4  [1 12-ounce package frozen spinach soufflé, th...        False   False
#
#    vegan
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
labeled.groupby(["gluten_free"])["title"].count()
# Out:
# gluten_free
# False    13418
# True      4357
# Name: title, dtype: int64

# %%
labeled.groupby(["kosher"])["title"].count()
# Out:
# kosher
# False    12264
# True      5511
# Name: title, dtype: int64

# %%
labeled.groupby(["vegan"])["title"].count()
# Out:
# vegan
# False    16240
# True      1535
# Name: title, dtype: int64

# %%
non = labeled[labeled["gluten_free"]==False]
non = non[non["kosher"]==False]
non  = non[non["vegan"]==False]
print(non.shape)
non.head()
# Out:
# (10497, 5)
#                                          title  \
# 0              Lentil, Apple, and Turkey Wrap
# 1  Boudin Blanc Terrine with Red Onion Confit
# 2                Potato and Fennel Soup Hodge
# 4                    Spinach Noodle Casserole
# 5                               The Best Blts
#
#                                          ingredients  gluten_free  kosher  \
# 0  [4 cups low-sodium vegetable or chicken stock,...        False   False
# 1  [1 1/2 cups whipping cream, 2 medium onions, c...        False   False
# 2  [1 fennel bulb (sometimes called anise), stalk...        False   False
# 4  [1 12-ounce package frozen spinach soufflé, th...        False   False
# 5  [2 1/2 cups (lightly packed) fresh basil leave...        False   False
#
#    vegan
# 0  False
# 1  False
# 2  False
# 4  False
# 5  False

# %%
pos = labeled[~labeled.index.isin(non.index)]
pos.shape
# Out:
# (7279, 5)

# %%
pos.groupby(["vegan"])["title"].count()
# Out:
# vegan
# False    5744
# True     1535
# Name: title, dtype: int64

# %%
pos.groupby(["kosher"])["title"].count()
# Out:
# kosher
# False    1768
# True     5511
# Name: title, dtype: int64

# %%
pos.groupby(["gluten_free"])["title"].count()
# Out:
# gluten_free
# False    2922
# True     4357
# Name: title, dtype: int64

# %%
# use all rows that are vegan, gluten-free, or kosher and add 3743 rows that have none of
# those labels
non_to_use = non.sample(3743)

# %%
non_to_use.shape
# Out:
# (3743, 5)

# %%
all_to_use = pd.concat([pos, non_to_use])
all_to_use.shape
# Out:
# (11022, 5)

# %%
all_to_use.groupby(["vegan"])["title"].count()
# Out:
# vegan
# False    9486
# True     1535
# Name: title, dtype: int64

# %%
all_to_use.groupby(["kosher"])["title"].count()
# Out:
# kosher
# False    5510
# True     5511
# Name: title, dtype: int64

# %%
all_to_use.groupby(["gluten_free"])["title"].count()
# Out:
# gluten_free
# False    6664
# True     4357
# Name: title, dtype: int64

# %%
all_to_use.head()
# Out:
#                                                 title  \
# 3                    Mahi-Mahi in Tomato Olive Sauce
# 6   Ham and Spring Vegetable Salad with Shallot Vi...
# 9   Ham Persillade with Mustard Potato Salad and M...
# 12  Banana-Chocolate Chip Cake With Peanut Butter ...
# 13            Beef Tenderloin with Garlic and Brandy
#
#                                           ingredients  gluten_free  kosher  \
# 3   [2 tablespoons extra-virgin olive oil, 1 cup c...        False    True
# 6   [1 1/2 pounds small red-skinned potatoes, each...         True   False
# 9   [6 long parsley sprigs, divided, 1 3/4 cups re...         True   False
# 12  [Nonstick vegetable oil spray, 3 cups all-purp...        False    True
# 13  [4 6- to 7-ounce beef tenderloin steaks (each ...         True   False
#
#     vegan
# 3   False
# 6   False
# 9   False
# 12  False
# 13  False

# %%
outfile = "/Users/Carol/Google Drive/nlp_data/recipe_data/20200524_gf_k_v_cats.tsv"
all_to_use.to_csv(outfile, sep="\t", index=False)

# %%
# write out the training, dev, and test sets
outpath = "/Users/Carol/Google Drive/nlp_data/recipe_data/20200524_categories"
for name, df in zip(["train", "dev", "test"], [train, dev, test]):
    outfile = os.path.join(outpath, name + ".tsv")
    df.to_csv(outfile, sep="\t", index=False)
