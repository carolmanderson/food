# %% [markdown]
# # Recipe data from https://www.kaggle.com/hugodarwood/epirecipes
#
# # Grab a subset of the data and convert to JSONL for labeling in Prodigy

# %% [raw]
# Output format example:
#
# {"text": "This is a sentence."}
# {"text": "This is another sentence.", "meta": {"score": 0.1}}

# %%
import json

import pandas as pd
from sklearn.model_selection import train_test_split

# %%
recipe_file = "/Users/Carol/Documents/epicurious-recipes-with-rating-and-nutrition/full_format_recipes.json"

# %%
recipe_df = pd.read_json(recipe_file, orient='records')
recipe_df.head()
# Out:
#    calories                                         categories  \
# 0     426.0  [Sandwich, Bean, Fruit, Tomato, turkey, Vegeta...
# 1     403.0  [Food Processor, Onion, Pork, Bake, Bastille D...
# 2     165.0  [Soup/Stew, Dairy, Potato, Vegetable, Fennel, ...
# 3       NaN  [Fish, Olive, Tomato, Sauté, Low Fat, Low Cal,...
# 4     547.0  [Cheese, Dairy, Pasta, Vegetable, Side, Bake, ...
#
#                  date                                               desc  \
# 0 2006-09-01 04:00:00                                               None
# 1 2004-08-20 04:00:00  This uses the same ingredients found in boudin...
# 2 2004-08-20 04:00:00                                               None
# 3 2009-03-27 04:00:00  The Sicilian-style tomato sauce has tons of Me...
# 4 2004-08-20 04:00:00                                               None
#
#                                           directions   fat  \
# 0  [1. Place the stock, lentils, celery, carrot, ...   7.0
# 1  [Combine first 9 ingredients in heavy medium s...  23.0
# 2  [In a large heavy saucepan cook diced fennel a...   7.0
# 3  [Heat oil in heavy large skillet over medium-h...   NaN
# 4  [Preheat oven to 350°F. Lightly grease 8x8x2-i...  32.0
#
#                                          ingredients  protein  rating  sodium  \
# 0  [4 cups low-sodium vegetable or chicken stock,...     30.0   2.500   559.0
# 1  [1 1/2 cups whipping cream, 2 medium onions, c...     18.0   4.375  1439.0
# 2  [1 fennel bulb (sometimes called anise), stalk...      6.0   3.750   165.0
# 3  [2 tablespoons extra-virgin olive oil, 1 cup c...      NaN   5.000     NaN
# 4  [1 12-ounce package frozen spinach soufflé, th...     20.0   3.125   452.0
#
#                                          title
# 0              Lentil, Apple, and Turkey Wrap
# 1  Boudin Blanc Terrine with Red Onion Confit
# 2                Potato and Fennel Soup Hodge
# 3             Mahi-Mahi in Tomato Olive Sauce
# 4                    Spinach Noodle Casserole

# %%
recipe_df.shape
# Out:
# (20130, 11)

# %% [markdown]
# # Make a sample of the data for labeling
#
# Start with ~2000 recipes

# %%
use, ignore = train_test_split(recipe_df, test_size=0.9, random_state=12)
print(use.shape, ignore.shape)
# Out:
# (2013, 11) (18117, 11)

# %%
# save the split to csvs 
use_file = "/Users/Carol/Documents/epicurious-recipes-with-rating-and-nutrition/use_2013.tsv"
ignore_file = "/Users/Carol/Documents/epicurious-recipes-with-rating-and-nutrition/ignore_18117.tsv"

use.to_csv(use_file, sep="\t")
ignore.to_csv(ignore_file, sep="\t")

# %%
indices = use.index.tolist()
directions = use.directions.tolist()

# %%
# write jsonl
outfile = "/Users/Carol/Documents/epicurious-recipes-with-rating-and-nutrition/use_directions.jsonl"

with open(outfile, 'w', encoding='utf-8') as out:
    for index, direction_list in zip(indices, directions):
        subindex = 1  
        if type(direction_list) != list:   # skip nans
            continue
        for direction_item in direction_list:
            row = {"text" : direction_item, "meta": {"row": index, "subpart": subindex}}
            subindex += 1
            json.dump(row, out)
            out.write("\n")

# %% [markdown]
# # Make patterns file for teaching Prodigy food terms
#
# ```
#
# Start with some simple one-word terms:
#
# prodigy terms.teach food_terms en_core_web_lg --seeds "flour, chicken, tomato"
#
# prodigy terms.to-patterns food_terms /Users/Carol/Documents/epicurious-recipes-with-rating-and-nutrition/food_term_patterns.jsonl --label FOOD
# ```

# %% [markdown]
# ## Load resulting terms and merge with hand-written patterns

# %%
pattern_file_1 = "/Users/Carol/Documents/epicurious-recipes-with-rating-and-nutrition/food_term_patterns.jsonl"

term_patterns = []
with open(pattern_file_1, 'r') as p:
    for line in p:
        linedict = json.loads(line)
        term_patterns.append(linedict)

term_patterns
# Out:
# [{'label': 'FOOD', 'pattern': [{'lower': 'flour'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'chicken'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'tomato'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'sauce'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'onion'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'garlic'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'onions'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'potato'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'butter'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'bread'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'rice'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'spinach'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'salad'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'pepper'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'soup'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'pasta'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'vegetable'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'chili'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'pork'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'beans'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'sausage'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'vegetables'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'egg'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'peppers'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'zucchini'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'tofu'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'broth'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'broccoli'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'eggs'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'mustard'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'carrots'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'celery'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'basil'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'veggies'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'carrot'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'eggplant'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'chilli'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'shrimp'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'seasoning'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'peanut'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'cabbage'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'curry'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'parmesan'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'noodles'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'parsley'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'lettuce'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'chopped'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'macaroni'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'vinegar'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'paprika'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'lemon'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'buttermilk'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'wheat'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'salt'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'hamburger'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'olives'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'avocado'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'cornmeal'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'ketchup'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'coconut'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'cinnamon'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'loaf'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'stew'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'almonds'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'spices'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'lentils'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'lasagna'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'pumpkin'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'ginger'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'turkey'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'polenta'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'sugar'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'sandwich'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'artichoke'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'shallots'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'dough'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'veg'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'quinoa'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'chilies'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'sprouts'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'chipotle'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'marinara'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'couscous'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'chorizo'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'honey'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'taco'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'salads'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'sausages'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'meats'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'pancakes'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'oatmeal'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'marinade'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'tuna'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'noodle'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'spicy'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'okra'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'hummus'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'cashew'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'scallions'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'risotto'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'pepperoni'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'strawberries'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'spaghetti'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'biscuits'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'pecans'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'dumplings'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'balsamic'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'rosemary'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'squash'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'bananas'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'fennel'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'crackers'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'burgers'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'yoghurt'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'enchilada'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'vinaigrette'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'flakes'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'fruit'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'crust'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'breaded'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'poultry'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'spiced'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'soya'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'slaw'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'powdered'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'arugula'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'cucumbers'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'pastry'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'fillets'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'leeks'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'cutlets'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'jalapenos'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'coleslaw'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'pickle'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'cayenne'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'buns'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'pancetta'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'tarragon'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'yolks'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'scallops'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'appetizer'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'tempeh'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'nutmeg'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'cakes'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'cranberry'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'blueberries'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'sundried'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'chocolate'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'sunflower'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'chops'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'spice'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'cheeses'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'strawberry'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'radish'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'venison'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'unsalted'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'chiles'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'oat'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'paneer'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'tapioca'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'chard'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'crabmeat'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'raisin'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'bouillon'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'tortellini'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'calamari'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'panko'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'scallion'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'soda'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'orzo'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'tacos'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'grits'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'herbs'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'patty'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'aioli'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'fillet'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'capers'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'romaine'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'cranberries'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'paste'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'toast'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'enchiladas'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'chowder'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'chile'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'rind'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'cherries'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'adobo'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'provolone'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'tahini'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'zest'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'garbanzo'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'watercress'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'oranges'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'truffle'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'quesadilla'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'batter'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'berries'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'masala'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'cutlet'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'popcorn'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'focaccia'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'peach'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'oyster'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'raspberries'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'sherry'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'vermicelli'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'ciabatta'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'matzo'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'shiitake'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'loaves'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'caramel'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'clams'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'quesadillas'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'alfredo'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'plantains'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'tart'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'tandoori'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'bulgur'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'waffles'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'herb'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'plum'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'tomatillo'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'savoury'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'clam'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'sweetcorn'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'casseroles'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'pretzels'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'peppercorns'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'ramen'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'gratin'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'baguette'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'relish'}]},
#  {'label': 'FOOD', 'pattern': [{'lower': 'millet'}]}]

# %%
patterns = [
    {"label": "FOOD", "pattern": [{"lower": "butter"}]},
    {"label": "FOOD", "pattern": [{"POS": "NOUN"}, {"lower": "butter"}]},
    {"label": "FOOD", "pattern": [{"lower": "salt"}]},
    {"label": "FOOD", "pattern": [{"lower": "flour"}]},
    {"label": "FOOD", "pattern": [{"lower": "vinegar"}]},
    {"label": "FOOD", "pattern": [{"lower": "chicken"}]},
    {"label": "FOOD", "pattern": [{"lower": "rice"}]},
    {"label": "FOOD", "pattern": [{"POS": "ADJ"}, {"lower": "oil"}]},
    {"label": "FOOD", "pattern": [{"POS": "ADJ"}, {"lower": "pepper"}]},
        {"label": "FOOD", "pattern": [{"POS": "ADJ"}, {"lower": "pepper"},{"POS": "NOUN"}]},
    {"label": "FOOD", "pattern": [{"POS": "NOUN"}, {"lower": "sauce"}]},
    {"label": "FOOD", "pattern": [{"POS": "NOUN"}, {"lower": "extract"}]},
    {"label": "FOOD", "pattern": [{"POS": "NOUN"}, {"lower": "juice"}]},
    {"label": "FOOD", "pattern": [{"POS": "NOUN"}, {"lower":"stock"}]}
] + term_patterns



pattern_file_2 = "/Users/Carol/Documents/epicurious-recipes-with-rating-and-nutrition/food_patterns.jsonl"

with open(pattern_file_2, 'w', encoding='utf-8') as out:
        for pattern in patterns:
            json.dump(pattern, out)
            out.write("\n")

# %% [markdown]
# ## Begin binary labeling in Prodigy:
#
# ```
# prodigy ner.teach food_ner en_core_web '/Users/Carol/Documents/epicurious-recipes-with-rating-and-nutrition/use_directions.jsonl' --label FOOD --patterns '/Users/Carol/Documents/epicurious-recipes-with-rating-and-nutrition/food_patterns.jsonl' --unsegmented
#
# ```
#
#
#
# ## Batch train after accumulating ~2000 decisions
#
# ```
# prodigy ner.batch-train food_ner en_core_web_lg --output '/Users/Carol/Documents/epicurious-recipes-with-rating-and-nutrition/ner_models/food_2192' --unsegmented --n-iter 20
#
# ```
#
# ## Continue labeling, now without patterns
#
# ```
# prodigy ner.teach food_ner '/Users/Carol/Documents/epicurious-recipes-with-rating-and-nutrition/ner_models/food_2192' '/Users/Carol/Documents/epicurious-recipes-with-rating-and-nutrition/use_directions.jsonl' --label FOOD --unsegmented
# ```

# %%
# Possible other categories: tool/equipment ("bowl" or "small bowl"? "saucepan" or "heavy saucepan")
# Interesting items: butter and salt as verb vs. noun (could put in patterns)
# patterns: noun + juice, noun + extract, chicken + noun
