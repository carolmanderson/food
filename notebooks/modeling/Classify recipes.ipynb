# %%
import ast
import json
import os
import pickle

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.naive_bayes import MultinomialNB, ComplementNB
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.class_weight import compute_sample_weight, compute_class_weight
from xgboost import XGBClassifier

# %% [markdown]
# ## Load data, split into train/dev/test

# %%
recipe_df = pd.read_csv("/Users/Carol/Google Drive/nlp_data/recipe_data/20200524_categories/20200524_gf_k_v_food_terms_extracted.tsv", sep="\t")

# %%
# split into training, dev, and test
train, devtest = train_test_split(recipe_df, test_size=0.4, stratify=recipe_df[['vegan', "kosher", "gluten_free"]]) 
dev, test = train_test_split(devtest, test_size=0.5, stratify=devtest[['vegan', "kosher", "gluten_free"]])

# %%
recipe_df.shape
# Out:
# (11022, 8)

# %%
for name, df in zip(["train", "dev", "test"], [train, dev, test]):
    shape = df.shape
    print(name)
    gf = df.gluten_free.tolist()
    print("gluten free: {}".format(sum(gf)/shape[0]))
    print(sum(gf))
    k = df.kosher.tolist()
    print("kosher: {}".format(sum(k)/shape[0]))
    print(sum(k))
    v = df.vegan.tolist()
    print("vegan: {}".format(sum(v)/shape[0]))
    print(sum(v))
# Out:
# train
# gluten free: 0.3952820202631181
# 2614
# kosher: 0.5000756086496295
# 3307
# vegan: 0.13927113261757146
# 921
# dev
# gluten free: 0.3951905626134301
# 871
# kosher: 0.5
# 1102
# vegan: 0.1397459165154265
# 308
# test
# gluten free: 0.39546485260770975
# 872
# kosher: 0.4997732426303855
# 1102
# vegan: 0.13877551020408163
# 306

# %%
# write out the training, dev, and test sets
outpath = "/Users/Carol/Google Drive/nlp_data/recipe_data/20200524_categories"
for name, df in zip(["train", "dev", "test"], [train, dev, test]):
    outfile = os.path.join(outpath, name + ".tsv")
    df.to_csv(outfile, sep="\t", index=False)

# %%
# reload the data later
inpath = "/Users/Carol/Google Drive/nlp_data/recipe_data/20200524_categories"
train = pd.read_csv(os.path.join(inpath, "train.tsv"), sep="\t")
dev = pd.read_csv(os.path.join(inpath, "dev.tsv"), sep="\t")
test = pd.read_csv(os.path.join(inpath, "test.tsv"), sep="\t")

# %%
train.head(2)
# Out:
#                                   title  \
# 0  Bratwurst with Creamy Apple Compote
# 1         The Ultimate Bolognese Sauce
#
#                                          ingredients  \
# 0  ['2 tablespoons unsalted butter', '1 tablespoo...
# 1  ['2 bay leaves', '3 whole cloves', '2 teaspoon...
#
#                                           directions  gluten_free  kosher  \
# 0  ['Preheat broiler.', 'Heat butter and oil in a...         True   False
# 1  ['Toast spices in a dry small skillet over med...        False   False
#
#    vegan                                         food_terms  \
# 0  False  ['butter', 'oil', '-', 'onion', 'apples', 'bay...
# 1  False  ['spices', 'flavor', 'spice', 'oil', '-', 'liv...
#
#                                   joined_ingredients
# 0  2 tablespoons unsalted butter. 1 tablespoon ve...
# 1  2 bay leaves. 3 whole cloves. 2 teaspoons fenn...

# %% [markdown]
# ## Feature vectorization methods

# %%
def get_tokens(input_cell):
    return ast.literal_eval(input_cell)

def get_unique_tokens(input_cell):
    return list(set(ast.literal_eval(input_cell)))

# %%
count_unique = CountVectorizer(tokenizer=get_unique_tokens)
count = CountVectorizer(tokenizer=get_tokens)
tfidf = TfidfVectorizer(tokenizer=get_tokens)

# %% [markdown]
# ## Calculate baseline performance

# %%
# baseline_labels
for category in ["gluten_free", "kosher", "vegan"]:
    print(category)
    baseline_labels = [0]*len(dev[category])
    labels = dev[category].tolist()
    print(classification_report(labels, baseline_labels))
    print("=====================")
# Out:
# gluten_free
#               precision    recall  f1-score   support
#
#        False       0.60      1.00      0.75      1333
#         True       0.00      0.00      0.00       871
#
#     accuracy                           0.60      2204
#    macro avg       0.30      0.50      0.38      2204
# weighted avg       0.37      0.60      0.46      2204
#
# =====================
# kosher
#               precision    recall  f1-score   support
#
#        False       0.50      1.00      0.67      1102
#         True       0.00      0.00      0.00      1102
#
#     accuracy                           0.50      2204
#    macro avg       0.25      0.50      0.33      2204
# weighted avg       0.25      0.50      0.33      2204
#
# =====================
# vegan
#               precision    recall  f1-score   support
#
#        False       0.86      1.00      0.92      1896
#         True       0.00      0.00      0.00       308
#
#     accuracy                           0.86      2204
#    macro avg       0.43      0.50      0.46      2204
# weighted avg       0.74      0.86      0.80      2204
#
# =====================
# /Users/Carol/anaconda/envs/nlp/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Try various model types, vectorization methods, and hyperparameters

# %%
# logistic regression
def fit_lr(X_train, Y_train, X_dev, y_dev, custom_vec):
    lr_param_grid = [{"vect__ngram_range": [(1,1)], 
                   'clf__penalty':['l1', 'l2'], 
                   'clf__C':[1]}]

    pipeline = Pipeline([('vect', custom_vec), ('clf', LogisticRegression(class_weight="balanced")),])
    lr_gs = GridSearchCV(pipeline, lr_param_grid, scoring="f1_macro", cv=5, verbose=0, n_jobs=-1)
    lr_gs.fit(train.food_terms, y_train)
    print("Logistic regression: ")
    print(lr_gs.best_params_)
    clf = lr_gs.best_estimator_
    print(clf.score(X_dev, y_dev))
    
# fit_lr(X_train, y_train, X_dev, y_dev)

# %%
# multinomial naive bayes
def fit_mnb(X_train, y_train, X_dev, y_dev, custom_vec):
    
    nb_param_grid = [{"vect__ngram_range": [(1,1)], 
                   'clf__alpha': (1, 0.1, 0.01, 0.001, 0.0001, 0.00001)}]
    weights = compute_sample_weight("balanced", y_train)
    pipeline = Pipeline([('vect', custom_vec), ('clf', MultinomialNB())])
    nb_gs = GridSearchCV(pipeline, nb_param_grid, scoring="f1_macro", cv=5, verbose=0, n_jobs=-1)
    nb_gs.fit(X_train, y_train, clf__sample_weight=weights)
    print("Mutinomial Naive Bayes: ")
    print(nb_gs.best_params_)
    clf = nb_gs.best_estimator_
    print(clf.score(X_dev, y_dev))
    
# fit_mnb(X_train, y_train, X_dev, y_dev)

# %%
# complement naive bayes
def fit_cnb(X_train, y_train, X_dev, y_dev, custom_vec):
    nb_param_grid = [{"vect__ngram_range": [(1,1)], 
                   'clf__alpha': (1, 0.1, 0.01, 0.001, 0.0001)}]
    weights = compute_sample_weight("balanced", y_train)
    pipeline = Pipeline([('vect', custom_vec), ('clf', ComplementNB())])
    nb_gs = GridSearchCV(pipeline, nb_param_grid, scoring="f1_macro", cv=5, verbose=0, n_jobs=-1)
    nb_gs.fit(X_train, y_train, clf__sample_weight=weights)
    print("Complement Naive Bayes: ")
    print(nb_gs.best_params_)
    clf = nb_gs.best_estimator_
    print(clf.score(X_dev, y_dev))
  
# fit_cnb(X_train, y_train, X_dev, y_dev)

# %%
# random forest
def fit_rf(X_train, y_train, X_dev, y_dev, custom_vec):
    param_grid = {
    "vect__ngram_range": [(1,1),],
    'clf__bootstrap': [True],
    'clf__max_depth': [100],
    'clf__max_features': ['auto'],
    'clf__min_samples_leaf': [1],
    'clf__min_samples_split': [2],
    'clf__n_estimators': [100, 200]
}

    pipeline = Pipeline([('vect', custom_vec), ('clf', RandomForestClassifier())])
    rf_gs = GridSearchCV(pipeline, param_grid, scoring="f1_macro", cv=5, verbose=0, n_jobs=-1)
    rf_gs.fit(X_train, y_train)
    print("Random Forest: ")
    print(rf_gs.best_params_)
    clf = rf_gs.best_estimator_
    print(clf.score(X_dev, y_dev))
    
# fit_rf(X_train, y_train, X_dev, y_dev)

# %%
# multilayer perceptron
def fit_mlp(X_train, y_train, X_dev, y_dev, custom_vec):
    param_grid = [{"clf__hidden_layer_sizes": [(50), (100,), (200,), (50, 50)]}]
    pipeline = Pipeline([('vect', custom_vec), ('clf', MLPClassifier(early_stopping=True))])
    mlp_gs = GridSearchCV(pipeline, param_grid, scoring="f1_macro", cv=5, verbose=0, n_jobs=-1)
    mlp_gs.fit(X_train, y_train)
    print("Multilayer perceptron: ")
    print(mlp_gs.best_params_)
    clf = mlp_gs.best_estimator_
    print(clf.score(X_dev, y_dev))
  

X_train = train.food_terms
y_train = train["vegan"]
X_dev = dev.food_terms
y_dev = dev["vegan"]

# fit_mlp(X_train, y_train, X_dev, y_dev, count_unique)

# %%
# xgboost
def fit_xgb(X_train, y_train, X_dev, y_dev, custom_vec):
    param_grid = [{"clf__n_estimators": [100, 200]}]
    pipeline = Pipeline([('vect', custom_vec), ('clf', XGBClassifier())])
    gs = GridSearchCV(pipeline, param_grid, scoring="f1_macro", cv=5, verbose=0, n_jobs=-1)
    gs.fit(train.food_terms, y_train)
    print("XGBoost: ")
    print(gs.best_params_)
    clf = gs.best_estimator_
    print(clf.score(X_dev, y_dev))
    
#xgboost with weighted gradients   
def fit_xgb_weighted(X_train, y_train, X_dev, y_dev, custom_vec):
    param_grid = [{"clf__n_estimators": [100, 200]}]
    weights = compute_class_weight("balanced", [0, 1], y_train)
    pos_weight = weights[1]/weights[0]
    pipeline = Pipeline([('vect', custom_vec), ('clf', XGBClassifier(scale_pos_weight=pos_weight))])
    gs = GridSearchCV(pipeline, param_grid, scoring="f1_macro", cv=5, verbose=0, n_jobs=-1)
    gs.fit(train.food_terms, y_train)
    print("XGBoost: ")
    print(gs.best_params_)
    clf = gs.best_estimator_
    print(clf.score(X_dev, y_dev))

# %%
for category in ["gluten_free", "kosher", "vegan"]:
    print(category)
    X_train = train.food_terms
    y_train = train[category]
    X_dev = dev.food_terms
    y_dev = dev[category]
    

    for name, vectorizer in zip(["counts", "unique", "tfidf"], [count, count_unique, tfidf]):
        print(name)
        fit_mlp(X_train, y_train, X_dev, y_dev, vectorizer)
# Out:
# gluten_free
# counts
# Multilayer perceptron:
# {'clf__hidden_layer_sizes': (100,)}
# 0.7590744101633394
# unique
# Multilayer perceptron:
# {'clf__hidden_layer_sizes': 50}
# 0.7581669691470054
# tfidf
# Multilayer perceptron:
# {'clf__hidden_layer_sizes': (200,)}
# 0.7558983666061706
# kosher
# counts
# Multilayer perceptron:
# {'clf__hidden_layer_sizes': (100,)}
# 0.7368421052631579
# unique
# Multilayer perceptron:
# {'clf__hidden_layer_sizes': 50}
# 0.7313974591651543
# tfidf
# Multilayer perceptron:
# {'clf__hidden_layer_sizes': 50}
# 0.7291288566243194
# vegan
# counts
# Multilayer perceptron:
# {'clf__hidden_layer_sizes': (200,)}
# 0.8906533575317604
# unique
# Multilayer perceptron:
# {'clf__hidden_layer_sizes': (100,)}
# 0.8933756805807622
# tfidf
# Multilayer perceptron:
# {'clf__hidden_layer_sizes': (200,)}
# 0.8901996370235935

# %%
for category in ["gluten_free", "kosher", "vegan"]:
    print(category)
    X_train = train.food_terms
    y_train = train[category]
    X_dev = dev.food_terms
    y_dev = dev[category]
    
    for model in fit_lr, fit_cnb, fit_rf:
        for name, vectorizer in zip(["counts", "unique", "tfidf"], [count, count_unique, tfidf]):
            print(name)
            model(X_train, y_train, X_dev, y_dev, vectorizer)
# Out:
# gluten_free
# counts
# /Users/Carol/anaconda/envs/nlp/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic regression:
# {'clf__C': 1, 'clf__penalty': 'l1', 'vect__ngram_range': (1, 1)}
# 0.7490925589836661
# unique
# /Users/Carol/anaconda/envs/nlp/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic regression:
# {'clf__C': 1, 'clf__penalty': 'l1', 'vect__ngram_range': (1, 1)}
# 0.7431941923774955
# tfidf
# /Users/Carol/anaconda/envs/nlp/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic regression:
# {'clf__C': 1, 'clf__penalty': 'l1', 'vect__ngram_range': (1, 1)}
# 0.7486388384754991
# counts
# Complement Naive Bayes:
# {'clf__alpha': 0.1, 'vect__ngram_range': (1, 1)}
# 0.7182395644283122
# unique
# Complement Naive Bayes:
# {'clf__alpha': 0.1, 'vect__ngram_range': (1, 1)}
# 0.7196007259528131
# tfidf
# Complement Naive Bayes:
# {'clf__alpha': 0.1, 'vect__ngram_range': (1, 1)}
# 0.73502722323049
# counts
# Random Forest:
# {'clf__bootstrap': True, 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 2, 'clf__n_estimators': 200, 'vect__ngram_range': (1, 1)}
# 0.7663339382940109
# unique
# Random Forest:
# {'clf__bootstrap': True, 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 2, 'clf__n_estimators': 200, 'vect__ngram_range': (1, 1)}
# 0.7617967332123412
# tfidf
# Random Forest:
# {'clf__bootstrap': True, 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 2, 'clf__n_estimators': 200, 'vect__ngram_range': (1, 1)}
# 0.7522686025408348
# kosher
# counts
# /Users/Carol/anaconda/envs/nlp/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic regression:
# {'clf__C': 1, 'clf__penalty': 'l1', 'vect__ngram_range': (1, 1)}
# 0.721415607985481
# unique
# /Users/Carol/anaconda/envs/nlp/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic regression:
# {'clf__C': 1, 'clf__penalty': 'l1', 'vect__ngram_range': (1, 1)}
# 0.7186932849364791
# tfidf
# /Users/Carol/anaconda/envs/nlp/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic regression:
# {'clf__C': 1, 'clf__penalty': 'l1', 'vect__ngram_range': (1, 1)}
# 0.7295825771324864
# counts
# Complement Naive Bayes:
# {'clf__alpha': 0.1, 'vect__ngram_range': (1, 1)}
# 0.6923774954627949
# unique
# Complement Naive Bayes:
# {'clf__alpha': 1, 'vect__ngram_range': (1, 1)}
# 0.6869328493647913
# tfidf
# Complement Naive Bayes:
# {'clf__alpha': 1, 'vect__ngram_range': (1, 1)}
# 0.6982758620689655
# counts
# Random Forest:
# {'clf__bootstrap': True, 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 2, 'clf__n_estimators': 200, 'vect__ngram_range': (1, 1)}
# 0.7323049001814882
# unique
# Random Forest:
# {'clf__bootstrap': True, 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 2, 'clf__n_estimators': 200, 'vect__ngram_range': (1, 1)}
# 0.7377495462794919
# tfidf
# Random Forest:
# {'clf__bootstrap': True, 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 2, 'clf__n_estimators': 200, 'vect__ngram_range': (1, 1)}
# 0.7286751361161524
# vegan
# counts
# /Users/Carol/anaconda/envs/nlp/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic regression:
# {'clf__C': 1, 'clf__penalty': 'l1', 'vect__ngram_range': (1, 1)}
# 0.8734119782214156
# unique
# /Users/Carol/anaconda/envs/nlp/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic regression:
# {'clf__C': 1, 'clf__penalty': 'l1', 'vect__ngram_range': (1, 1)}
# 0.8706896551724138
# tfidf
# /Users/Carol/anaconda/envs/nlp/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Logistic regression:
# {'clf__C': 1, 'clf__penalty': 'l1', 'vect__ngram_range': (1, 1)}
# 0.8484573502722323
# counts
# Complement Naive Bayes:
# {'clf__alpha': 0.01, 'vect__ngram_range': (1, 1)}
# 0.8511796733212341
# unique
# Complement Naive Bayes:
# {'clf__alpha': 0.1, 'vect__ngram_range': (1, 1)}
# 0.8548094373865699
# tfidf
# Complement Naive Bayes:
# {'clf__alpha': 0.1, 'vect__ngram_range': (1, 1)}
# 0.8448275862068966
# counts
# Random Forest:
# {'clf__bootstrap': True, 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 2, 'clf__n_estimators': 200, 'vect__ngram_range': (1, 1)}
# 0.8802177858439202
# unique
# Random Forest:
# {'clf__bootstrap': True, 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 2, 'clf__n_estimators': 200, 'vect__ngram_range': (1, 1)}
# 0.8806715063520871
# tfidf
# Random Forest:
# {'clf__bootstrap': True, 'clf__max_depth': 100, 'clf__max_features': 'auto', 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 2, 'clf__n_estimators': 100, 'vect__ngram_range': (1, 1)}
# 0.868421052631579

# %%
for category in ["gluten_free", "kosher", "vegan"]:
    print(category)
    X_train = train.food_terms
    y_train = train[category]
    X_dev = dev.food_terms
    y_dev = dev[category]
    

    for name, vectorizer in zip(["counts", "unique", "tfidf"], [count, count_unique, tfidf]):
        print(name)
        fit_xgb(X_train, y_train, X_dev, y_dev, vectorizer)
# Out:
# gluten_free
# counts
# XGBoost:
# {'clf__n_estimators': 100}
# 0.7676950998185118
# unique
# XGBoost:
# {'clf__n_estimators': 100}
# 0.7672413793103449
# tfidf
# XGBoost:
# {'clf__n_estimators': 100}
# 0.75
# kosher
# counts
# XGBoost:
# {'clf__n_estimators': 100}
# 0.7386569872958257
# unique
# XGBoost:
# {'clf__n_estimators': 200}
# 0.73502722323049
# tfidf
# XGBoost:
# {'clf__n_estimators': 100}
# 0.721415607985481
# vegan
# counts
# XGBoost:
# {'clf__n_estimators': 200}
# 0.9065335753176044
# unique
# XGBoost:
# {'clf__n_estimators': 200}
# 0.8997277676950998
# tfidf
# XGBoost:
# {'clf__n_estimators': 200}
# 0.8947368421052632

# %%
for category in ["gluten_free", "kosher", "vegan"]:
    print(category)
    X_train = train.food_terms
    y_train = train[category]
    X_dev = dev.food_terms
    y_dev = dev[category]

    for name, vectorizer in zip(["counts", "unique", "tfidf"], [count, count_unique, tfidf]):
        print(name)
        fit_xgb_weighted(X_train, y_train, X_dev, y_dev, vectorizer)
# Out:
# gluten_free
# counts
# XGBoost:
# {'clf__n_estimators': 200}
# 0.7622504537205081
# unique
# XGBoost:
# {'clf__n_estimators': 200}
# 0.7518148820326679
# tfidf
# XGBoost:
# {'clf__n_estimators': 100}
# 0.7463702359346642
# kosher
# counts
# XGBoost:
# {'clf__n_estimators': 200}
# 0.7291288566243194
# unique
# XGBoost:
# {'clf__n_estimators': 100}
# 0.7400181488203267
# tfidf
# XGBoost:
# {'clf__n_estimators': 100}
# 0.7368421052631579
# vegan
# counts
# XGBoost:
# {'clf__n_estimators': 200}
# 0.8901996370235935
# unique
# XGBoost:
# {'clf__n_estimators': 200}
# 0.8911070780399274
# tfidf
# XGBoost:
# {'clf__n_estimators': 100}
# 0.8747731397459165

# %% [raw]
# Best Performance
# gluten free
# counts
# XGBoost:
# {'clf__n_estimators': 100}
# 0.7676950998185118
#
# kosher
# counts
# XGBoost:
# {'clf__n_estimators': 100}
# 0.7386569872958257
#
# vegan
# counts
# XGBoost:
# {'clf__n_estimators': 200}
# 0.9065335753176044

# %% [markdown]
# ## Compare Xgboost with and without class weights

# %%
X_train = train.food_terms
y_train = train["vegan"]
X_dev = dev.food_terms
y_dev = dev["vegan"]

# xgboost
clf =  XGBClassifier(n_estimators=200)
X_train = count.fit_transform(X_train)
clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=200, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
X_dev = count.transform(X_dev)
ypred_dev = clf.predict(X_dev)

# %%
print(classification_report(y_dev, ypred_dev))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.94      0.96      0.95      1896
#         True       0.69      0.60      0.64       308
#
#     accuracy                           0.91      2204
#    macro avg       0.81      0.78      0.79      2204
# weighted avg       0.90      0.91      0.90      2204

# %%
weights = compute_class_weight("balanced", [0, 1], y_train)
pos_weight = weights[1]/weights[0]
weighted_clf =  XGBClassifier(n_estimators=200, scale_pos_weight=pos_weight)
weighted_clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=200, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=6.180238870792617, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
ypred_dev_weighted = weighted_clf.predict(X_dev)

# %%
print(classification_report(y_dev, ypred_dev_weighted))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.98      0.89      0.93      1896
#         True       0.57      0.87      0.69       308
#
#     accuracy                           0.89      2204
#    macro avg       0.77      0.88      0.81      2204
# weighted avg       0.92      0.89      0.90      2204

# %%
X_train = train.food_terms
y_train = train["gluten_free"]
X_dev = dev.food_terms
y_dev = dev["gluten_free"]

# xgboost
clf =  XGBClassifier(n_estimators=200)
X_train = count.fit_transform(X_train)
clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=200, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
X_dev = count.transform(X_dev)
ypred_dev = clf.predict(X_dev)

# %%
print(classification_report(y_dev, ypred_dev))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.83      0.77      0.80      1333
#         True       0.68      0.76      0.72       871
#
#     accuracy                           0.76      2204
#    macro avg       0.76      0.76      0.76      2204
# weighted avg       0.77      0.76      0.77      2204

# %%
weights = compute_class_weight("balanced", [0, 1], y_train)
pos_weight = weights[1]/weights[0]
weighted_clf =  XGBClassifier(n_estimators=200, scale_pos_weight=pos_weight)
weighted_clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=200, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1.5298393267023718, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
ypred_dev_weighted = weighted_clf.predict(X_dev)

# %%
print(classification_report(y_dev, ypred_dev_weighted))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.88      0.71      0.78      1333
#         True       0.65      0.85      0.74       871
#
#     accuracy                           0.76      2204
#    macro avg       0.77      0.78      0.76      2204
# weighted avg       0.79      0.76      0.76      2204

# %% [markdown]
# ## Final model training with combined training + dev sets

# %%
traindev = pd.concat([train, dev])
traindev.shape
# Out:
# (8817, 8)

# %%
X_train = traindev.food_terms
X_test = test.food_terms
X_train = count.fit_transform(X_train)
X_test = count.transform(X_test)

# %%
def train_save_test(X_train, X_test, y_train, y_test, outfile):
    weights = compute_class_weight("balanced", [0, 1], y_train)
    pos_weight = weights[1]/weights[0]
    clf =  XGBClassifier(n_estimators=200, scale_pos_weight=pos_weight)
    clf.fit(X_train, y_train)
    with open(outfile, "wb") as out:
        pickle.dump(clf, out)
    ypred_test = clf.predict(X_test)
    print(classification_report(ypred_test, y_test))
    

for category in ["gluten_free", "vegan", "kosher"]:
    outfile = "/Users/Carol/Google Drive/nlp_data/models/20200613_{}.p".format(category)
    y_train = traindev[category]
    y_test = test[category]
    print(category)
    train_save_test(X_train, X_test, y_train, y_test, outfile)
# Out:
# gluten_free
#               precision    recall  f1-score   support
#
#        False       0.70      0.88      0.78      1064
#         True       0.85      0.65      0.73      1141
#
#     accuracy                           0.76      2205
#    macro avg       0.77      0.76      0.76      2205
# weighted avg       0.78      0.76      0.75      2205
#
# vegan
#               precision    recall  f1-score   support
#
#        False       0.91      0.98      0.95      1767
#         True       0.89      0.62      0.73       438
#
#     accuracy                           0.91      2205
#    macro avg       0.90      0.80      0.84      2205
# weighted avg       0.91      0.91      0.90      2205
#
# kosher
#               precision    recall  f1-score   support
#
#        False       0.68      0.78      0.72       954
#         True       0.81      0.71      0.76      1251
#
#     accuracy                           0.74      2205
#    macro avg       0.74      0.75      0.74      2205
# weighted avg       0.75      0.74      0.74      2205

# %%
# save the vectorizer
outfile = "/Users/Carol/Google Drive/nlp_data/models/20200613_vectorizer.p".format(category)

with open(outfile, "wb") as out:
    pickle.dump(count, out)

# %% [markdown]
# ## Error analysis

# %%
# False positives
for category in ["gluten_free", "vegan", "kosher"]:
    print(category.upper())
    saved_model = "/Users/Carol/Google Drive/nlp_data/models/20200613_{}.p".format(category)
    clf = pickle.load(open(saved_model, "rb"))
    ypred_test = clf.predict(X_test)
    y_test = test[category]
    FP = np.where((ypred_test == True) & (y_test==False))[0].tolist()
    fp = test.food_terms[FP]
    for item in fp:
        print(category)
        print(item)
        print("=========")
# Out:
# GLUTEN_FREE
# gluten_free
# ['steak', '-', 'peppercorns', 'allspice', 'berries', 'peppercorn', 'steaks', 'steaks', 'butter', 'oil', 'fat', 'steaks', 'seasoned', 'salt', 'meat', 'steaks', 'fat', 'butter', 'white', 'scallion', 'scallion', 'wine', 'bits', 'wine', 'wine', 'glaze', 'butter', 'scallion green', 'salt', 'black pepper', 'red - cabbage', 'confit', 'venison', 'steak', 'sauce', 'steak']
# =========
# gluten_free
# ['crabmeat', '-', 'cakes', 'oil', 'crab', 'cakes', 'bottoms', 'cakes', 'greens', 'vinaigrette', 'crab', 'cakes', 'lemon']
# =========
# gluten_free
# ['375ºF.', 'oil', 'prosciutto', 'cheese', 'prosciutto', 'egg', 'yolk', 'cream', 'egg', 'thyme', 'salt', 'pepper', 'whites', 'prosciutto']
# =========
# gluten_free
# ['wholemilk', 'Greek yogurt', 'tahini', 'powdered sugar', 'tahini', 'toasted', 'coconut', 'cacao nibs']
# =========
# gluten_free
# ['rind', 'fat', 'ham', '-', 'fat', 'ham', 'onions', 'mangos', 'nectar', 'ham', 'juices', 'ham', 'mangos', 'onions', 'ham', 'mangos', 'onions', 'juices', 'ham', 'mangos', 'onions', 'juices']
# =========
# gluten_free
# ['mint', 'pistachios', 'olive', 'oil', 'garlic', 'salt', 'pesto', 'olive', 'oil', 'mint', 'thyme', 'herb', 'fish', 'fillets', 'fish', 'seeds', 'seeds', 'spice', 'oil', '-', 'carrots', 'crushed red pepper', 'seeds', 'carrots', 'broth', 'lemon juice', '-', 'carrots', 'salt', 'pepper', 'fish', 'salt', 'pepper', 'oil', '-', 'fish', 'carrots', 'carrots', 'juices', 'fish', 'fillet', 'pesto']
# =========
# gluten_free
# ['turkey', '1-gallon', 'oil', 'cabbage', 'onion', 'cabbage', 'cabbage', 'oil', 'vinegar', 'sugar', 'allspice', 'salt', 'pepper', 'turkey', 'marinade', 'meat', 'marinade', 'turkey', 'turkey', 'grain', '-', 'cabbage', 'turkey', 'cabbage']
# =========
# gluten_free
# ['steaks', 'oil', 'steaks', 'chipotle', 'steaks', 'steaks', 'crusty', '-', 'steaks', '-', 'seasoned', 'steaks', 'beans', 'steaks', 'salsa', 'butter', 'steaks', 'onion', '-', 'oregano', 'oregano', 'coffee / spice', 'oil', 'chiles', 'chiles', 'chiles', 'fried', 'chiles', 'coffee / spice', 'oregano', 'chiles', 'garlic', 'salt', 'shaggy', 'saltlike', 'Chipotle', 'Regrind']
# =========
# gluten_free
# ['8x8x2-inch', 'oil', 'pecan', 'pecan', 'egg', 'white', 'fish', 'fillets', 'egg', 'white', 'pecan', 'fish', 'salt', 'pepper', 'pecan', 'fish', 'fillets', 'fish']
# =========
# gluten_free
# ['potatoes', 'potatoes', 'butter', 'potatoes', 'milk', 'milk', 'potatoes', 'salt', 'pepper', 'butter', '-', 'mushrooms', 'mushrooms', 'shallots', 'juices', 'mushrooms', 'salt', 'pepper', 'Potatoes', 'mushrooms', 'mushrooms', 'potatoes', 'mushrooms', 'chives']
# =========
# gluten_free
# ['Butter', 'salt', 'pepper', 'pudding', 'Josmeyer Les Folastries \n', 'Gewürztraminer', "'"]
# =========
# gluten_free
# ['Raita']
# =========
# gluten_free
# ['steak', 'salt', 'pepper', 'salt', 'steak', 'oil', 'meat', 'steak', 'ragout', 'oil', 'uncleaned', 'garlic', 'rosemary', 'red - pepper', 'mushrooms', 'salt', 'bits', 'mushrooms', 'juicy', 'tomatoes', 'juice', 'sugar', 'steak', 'meat', 'juices', 'mushroom', 'ragout', 'steak', 'grain', 'ragout']
# =========
# gluten_free
# ['butter', '-', 'shrimp', 'salt', 'pepper', 'shrimp', 'butter', 'shallots', 'rice', 'wine', 'wine', 'clam juice', 'rice', 'risotto', 'butter', 'basil', 'tarragon', 'herb', 'butter', 'salt', 'pepper', 'shrimp', 'juices', 'basil', 'risotto', 'salt', 'pepper', 'risotto', 'herb', 'butter', 'cheese']
# =========
# gluten_free
# ['chicken', 'thyme', 'salt', 'pepper', 'oil', '-', 'chicken', 'chicken', 'bits', 'sauce', 'chicken', 'salt', 'pepper', 'chicken', 'sauce']
# =========
# gluten_free
# ['butter', '7-', 'onions', 'celery', 'carrots', 'bay', 'parsley', 'thyme', 'peppercorns', 'vegetables', 'fish', 'vegetables', 'fish', 'wine', 'bones', 'white', 'bones', 'brew', 'white', 'herbs', 'spices', 'vegetables', 'stock', '-', 'salt', 'stock', 'stock', 'jellied']
# =========
# gluten_free
# ['artichokes', 'artichoke', 'heart', 'artichokes', 'charred', 'artichokes', 'artichokes', 'artichoke hearts', 'mint', 'cream', 'cheese', 'oil', 'salt', 'pepper']
# =========
# gluten_free
# ['corn', 'silks', 'husk', 'corn', 'corn']
# =========
# gluten_free
# ['butter', 'roasted', 'peppers', 'garlic', 'red pepper', 'salt', 'red pepper', 'butter', 'mussels', 'beards', 'mussels', 'white', 'wine', 'Sherry', 'fennel bulb', 'shallot', 'red pepper', 'fennel seeds', 'thyme', 'salt', 'mussels', 'shells', 'mussels', 'mussels', 'fennel bulb', 'shallot', 'broth', 'red pepper', 'butter', 'red pepper', 'butter', 'size="4">Using', '-', 'peppers', 'blackened', 'peppers', 'charred', 'peppers', 'peppers', 'whole', 'blossom', 'seeds', 'ribs', 'chilies.)</font']
# =========
# gluten_free
# ['vinegar', 'juice', 'butter', 'sugar', '13-', 'apples', 'melon -', 'apples', 'apples', 'juices', 'brandy', 'apples', 'crme fraîche', 'sauce']
# =========
# gluten_free
# ['nuts', 'trout', 'salt', 'egg', 'pie', 'nuts', 'trout', 'egg', 'nuts', 'oil', 'trout', 'trout', 'butter', 'lemon juice', 'salt', 'pepper', 'trout', 'fish', 'parsley']
# =========
# gluten_free
# ['garlic', 'oil', 'black pepper', 'steaks', 'garlic', 'steaks', '-', 'steaks', '-', 'steaks', 'steaks', '-', 'arugula', 'steak', 'juices', 'steaks', 'salt', 'oil', 'steaks', 'vegetable', 'Parmesan', 'steaks', 'lemon']
# =========
# gluten_free
# ['pepper', 'sauce', 'wine', 'shallot', 'lemon juice', 'vinegar', 'cream', 'cream', 'milk', 'butter', 'grits', 'grits', 'olive', 'oil', 'sausage', 'bell', 'peppers', 'onion', 'garlic', 'vegetables', 'shrimp', 'tomatoes', 'Cajun', 'seasoning', 'Bay', 'seasoning', 'shrimp', 'salt', 'pepper', 'pepper - cream', 'sauce', 'grits', 'shrimp', 'grits', 'pepper - cream', 'sauce', 'Corn', 'grits', 'polenta', 'yellow', 'cornmeal', 'smoked', 'pork -', '-', 'beef', 'sausage', 'Smoked', 'bratwurst', 'kielbasa', 'smoked Hungarian', 'sausage']
# =========
# gluten_free
# ['strawberries', 'Marsala', 'strawberries', 'eggs', 'sugar', 'Marsala', 'candy', 'zabaglione', 'strawberries']
# =========
# gluten_free
# ['mayonnaise', 'lemon juice', 'garlic', 'cayenne', 'mustard', 'oil', 'cornmeal', 'salt', 'cayenne', 'shrimp', 'shrimp', 'oil', '-', 'shrimp', 'shrimp', 'aioli', 'shrimp']
# =========
# gluten_free
# ['vinegar', 'sugar', 'salt', '-', 'garlic', 'chile', 'mushrooms', 'red pepper', 'brining', 'mushroom']
# =========
# gluten_free
# ['white', 'wine', 'Sherry', 'honey', 'sugar', 'sugar', 'syrup', 'pith', 'grapefruits', 'oranges', 'fruit', 'pomegranate', 'seeds', 'juice', 'citrus', 'pomegranate seeds', 'juice', 'wine syrup', 'dessert', 'compote']
# =========
# gluten_free
# ['shallot', 'fresh', 'lemon juice', 'unseasoned', 'rice', 'vinegar', 'kosher', 'salt', 'freshly', 'black pepper', 'olive', 'oil']
# =========
# gluten_free
# ['oil', 'fennel', 'salt', 'pepper', 'fennel', 'oil', 'tomatoes', 'stock', 'fennel', 'fish', 'fennel', 'tomato', 'fish']
# =========
# gluten_free
# ['-', 'oregano', 'oregano', 'coffee / spice', 'oil', 'chiles', 'chiles', 'chiles', 'fried', 'chiles', 'coffee / spice', 'oregano', 'chiles', 'garlic', 'salt', 'shaggy', 'saltlike', 'Chipotle', 'Regrind']
# =========
# gluten_free
# ['cucumber', 'vinegar', 'oil', 'salt', 'pepper', 'frisée', 'watercress', 'spinach', 'radishes']
# =========
# gluten_free
# ['Bell Pepper', 'Tomato', 'Relish', 'relish', 'chicken', 'pork', 'pizza', 'bell', 'peppers', 'oil', 'peppers', 'peppers', 'seed', 'peppers', 'oil', '-', 'tomatoes', 'garlic', 'tomatoes', 'peppers', 'cilantro', 'vinegar', 'salt', 'pepper']
# =========
# gluten_free
# ['hazelnuts', 'nuts', 'nuts', 'sugar', 'cinnamon', 'nutmeg', 'allspice', 'egg', 'white', 'hazelnuts', 'almonds', 'nuts', 'sugar', 'nuts', 'nuts']
# =========
# gluten_free
# ['oil', 'onion', 'potato', 'garlic', 'broth', 'green', 'onions', 'potato', 'spinach', 'mint', 'cilantro', 'soup', 'soup', 'broth', 'cupfuls', 'soup', 'salt', 'pepper', 'oil', 'paprika', 'soup', 'paprika', 'oil', 'mint']
# =========
# gluten_free
# ['sugar', 'cocoa powder', 'salt', '-', 'resistant', 'cocoa', 'syrup', 'vanilla', 'cream', 'vanilla', 'Kahlúa', 'cocoa syrup', '10-ounce', 'ice cream', 'stout', 'whipped cream', 'cocoa syrup', 'straw']
# =========
# gluten_free
# ['apple corer', 'pear', 'pear', 'base', 'bottoms', 'pears', 'pears', '15x10x2-inch', 'sugar', 'sugar', 'cinnamon', 'currants', 'pear', 'sugar', 'sugar', 'pears', 'pears', 'sauce', 'cupfuls', 'syrup', 'pears', 'syrup']
# =========
# gluten_free
# ['lamb', 'salt', 'pepper', 'basil', 'thyme', 'onion', 'carrot', 'cloves', 'garlic', 'red', 'wine', 'lamb', 'terrine', 'meat', 'onion', 'bacon', 'salt', 'pork', 'garlic', 'parsley', 'thyme', 'basil', 'orange rind', 'meat', 'seasoning', 'marinade', 'meat', 'larding', 'pork', 'potatoes', 'green', 'salad', 'red', 'wine', 'Château', "Cos d'Estournal"]
# =========
# gluten_free
# ['herbs', 'oil', 'salt', '-']
# =========
# gluten_free
# ['chilies', 'chilies', 'chilies', 'chilies', 'lime juice', 'mayonnaise', 'sugar', 'oregano', 'rosemary', 'cumin', 'salt', 'pepper']
# =========
# gluten_free
# ['rosemary', 'lamb', 'marinade', 'lamb', 'lamb', 'marinade', '-', 'lamb', 'marinade', 'lamb', 'salt', 'pepper', 'lamb', 'crusty', '-']
# =========
# gluten_free
# ['orange juice', 'sugar', 'tangerines', '-', 'sugar', '-', 'tangerines', 'fruit', 'fruit', 'tangerine', 'strained syrup', 'syrup', 'cream', 'Marnier', 'sugar', 'Butter', '2/3-cup', 'soufflé', 'sugar', 'tangerine', 'egg', 'whites', 'sugar', 'egg', 'whites', 'whites', 'tangerine', 'tangerine', 'whites', 'whipped cream']
# =========
# gluten_free
# ['oil', 'fat', 'onions', 'potatoes', 'carrots', 'tomatoes', 'cumin', 'chile', 'salt', 'pepper', 'stock', 'mung', 'beans', 'stock', 'beans', 'rice', 'stock', 'seasoning', 'sprigs', 'fresh', 'mint', 'yogurt', 'Uzbek', 'lamb', 'pound', 'lamb', 'cubes', 'meat', 'sautéing', 'onions', 'salt', 'pepper']
# =========
# gluten_free
# ['cucumber', 'sour cream', 'horseradish', 'vinegar', 'tarragon', 'salt', 'pepper', 'sauce', 'sauce', 'tarragon']
# =========
# gluten_free
# ['salt', 'pepper']
# =========
# gluten_free
# ['sugar', 'sugar', 'seeds', 'vanilla', 'bean', 'lemon zest', 'crushed green', 'cardamom', 'anise', 'juniper', 'berries', 'dried', 'petals', 'dried', 'hibiscus flowers', 'hibiscus', 'tea', 'pink', 'peppercorns', 'Sichuan', 'peppercorns', 'syrup', '20–25', '-', 'Syrup']
# =========
# gluten_free
# ['sauce', '-', 'beets', '-', 'round-', 'heart -', 'other-', 'cookie', 'slices-10', 'beet', 'oil', 'lemon juice', 'salt', 'beets', 'thicker', 'beet', 'cheese', 'beet', 'sauce', 'ravioli', 'aged balsamic', 'vinegar', 'sprigs', 'microgreens', 'fresh', 'herbs']
# =========
# gluten_free
# ['onion', 'garlic', 'salt', 'black pepper', 'oil', '2-', 'cashews', 'tomato', 'cayenne', 'broth', 'broth', 'soup', 'salt']
# =========
# gluten_free
# ['Oil', '13-', '2-', 'polenta', '1/3-inch -', 'mascarpone', 'polenta', 'Parmigiano - Reggiano', 'pepper']
# =========
# gluten_free
# ['oil', '-', 'mushrooms', 'onions', 'mushrooms', 'celery', 'garlic', 'beef', 'shank', '-', 'meat', 'meat', 'meat', 'bones', 'bones', 'meat', 'bite -', 'soup', 'soup', 'salt', 'pepper']
# =========
# gluten_free
# []
# =========
# gluten_free
# ['-', 'black - eyed', 'peas', 'salt', 'peas', 'salt', 'saffron', '-', 'olive', 'oil', 'onion', 'carrots', 'red', 'bell pepper', 'peppers', 'onion', 'saffron', 'blooming', 'Spice', 'garlic', 'black - eyed', 'peas', 'carrots', 'peas', 'salt', 'pepper', 'carrots', 'peppers', 'black - eyed', 'peas', 'glazed', 'lemon juice', 'honey', 'parsley']
# =========
# gluten_free
# ['herb', 'mayonnaise', 'salt', 'pepper', 'artichokes', 'artichokes', 'base', 'artichokes', 'Resteam', 'artichokes', 'herb', 'mayonnaise']
# =========
# gluten_free
# ['/', 'cranberries', 'cranberries', 'kumquats', 'seeds', 'kumquats', 'seeds', 'kumquats', 'sugar', 'ginger', 'cranberries', 'sugar', 'relish', 'Cranberry', 'relish']
# =========
# gluten_free
# ['oil', 'chicken', 'squid', 'garlic', 'chicken', 'garlic', 'noodles', 'sugar', 'noodles', 'chicken', 'seasoning', 'sauce', 'cabbage', 'radish', 'noodles', 'eggs', 'eggs', 'yolks', 'whites', 'whites', 'noodles', 'eggs', 'egg', 'scallions', 'fish', 'sauce', 'pepper', 'lettuce', 'noodle', 'chili']
# =========
# gluten_free
# ['radishes', 'cream', 'cheese', 'herbs', 'lemon juice', 'grated', 'radishes', 'salt', 'pepper', 'Radish', 'radish', 'toasts', 'radishes', 'canapé', 'canapés', 'salt']
# =========
# gluten_free
# ['white pith', 'oranges', 'orange', 'cranberries', 'almond syrup', 'coffee', 'almond syrup', 'sweetener', 'flavoring', 'agent', 'cocktails', 'orgeat syrup', 'sirop d’amandes']
# =========
# gluten_free
# ['orange', 'onion', 'olives', 'oil', 'vinegar', 'cumin', 'salt', 'pepper', 'romaine', 'salad']
# =========
# gluten_free
# ['gelato', '-', '-', 'milk', 'ricotta', 'sugar', 'cinnamon', 'zest', 'corn syrup', 'vanilla', 'ice - cream', 'gelato', 'dariole', 'gelato', 'blackberry', 'sauce', 'sugar', 'syrup', 'caramel', 'blackberries', 'lemon juice', 'crème', 'cassis', 'caramel', 'sauce', 'sauce', 'dessert', 'gelato', 'mango', 'blackberries']
# =========
# gluten_free
# ['oil', 'chicken', 'salt', 'pepper', 'chicken', 'oil', 'oil', 'mushrooms', 'broth', 'olives', 'plum', 'tomatoes', 'garlic', 'shallot', 'capers', 'salt', 'pepper', 'butter', 'teardrop', 'tomatoes', 'salt', 'pepper', 'mushroom', 'chicken', 'parsley', 'pine', 'nuts', 'caper', 'berries']
# =========
# gluten_free
# ['ice', 'onions', 'onions', 'ice', 'onions', 'vegetables', 'cubes', 'vegetables', 'onions', 'oil', 'butter', 'onions', 'roasted', 'vegetables', 'stock', 'salt', 'pepper', 'stock', 'vegetables', 'ragout', 'parsley', 'zest']
# =========
# gluten_free
# ['onions', 'oil', 'meat', 'salt', 'meat', 'saffron', 'turmeric', 'onions', 'meat', 'pink', 'tomatoes', 'peas', 'tomato', 'Omani', 'lemons', 'cinnamon', 'allspice', 'pepper', 'meat', 'Omani', 'lemons', 'salt', 'lime juice']
# =========
# gluten_free
# ['spices']
# =========
# gluten_free
# ['Sherry', 'cinnamon', 'lemon juice', '-', 'prunes', 'apricots', 'fruits', 'Sherry', 'peppercorns', 'cloves', 'marinade', 'pork', 'onion', 'pork', '13x9x2-inch', 'onion', 'marinade', 'pork', 'fruit', 'fruit', 'cinnamon', 'mango', 'papaya', 'sugar', 'fruit', 'pork', 'marinade', 'pork', 'pork', 'salt', 'pepper', 'fruit', 'pork', 'fruit', 'pork', 'filling', 'pork', 'filling', 'salt', 'pepper', 'oil', '-', 'pork', 'pork', 'pork', 'juices', 'pork', 'fruit', 'fruit', 'juices', 'pork', 'fruit', 'sauce']
# =========
# gluten_free
# ['beans', '-', 'ice', 'beans', 'salt', 'tuna', 'olive', 'oil', 'lemon juice', 'anchovy', 'sauce', 'salt', 'pepper', 'beans', 'olives', 'parsley']
# =========
# gluten_free
# ['hash', 'browns', 'green', 'chilies', 'cream', 'chicken', 'soup', 'cheddar', 'cheese', 'sour cream', '13x9x2-inch']
# =========
# gluten_free
# ['fillets', 'ginger', 'garlic', 'lime juice', 'oil', 'salt', 'chili powder', 'turmeric', 'mackerel', 'mackerel', 'cilantro']
# =========
# gluten_free
# ['gingersnaps', 'yogurt', 'marbled', 'sugar', 'plum', 'sugar', 'plums', '-', 'sugar', 'plums', 'yogurt']
# =========
# gluten_free
# ['sauce', 'sugar', 'ice', 'salmon', 'steaks', 'salmon', 'sauce', 'salmon', 'vegetables', '-', 'vegetables', 'ice', 'oil', 'salmon', 'sauce', 'marinade', 'salmon', 'oil', 'vegetables', 'sauce', 'vegetables', 'sauce', 'salmon', 'scallion', 'greens']
# =========
# gluten_free
# ['-', 'oil', 'butter', 'mustard', 'soaked bamboo', 'onion', 'bamboo', 'onion', 'oil', 'onions', 'oil', 'onions', 'mustard', 'onions', 'mustard', 'onions', 'mustard']
# =========
# gluten_free
# ['melon', 'seeds', 'pineapple', 'pineapple', 'rind', 'meat', 'rind', 'fruit', 'pineapple', 'strawberries', 'oranges', 'white', 'greens', 'corn syrup', 'mayonnaise', 'orange juice', 'onion', 'greens', 'bite -', 'salad', 'fruit', 'dressing']
# =========
# gluten_free
# ['black', 'pink', 'white', 'peppercorns', 'bay', 'salt', 'sugar', 'lemon zest', 'orange zest', 'turkey', 'curing', 'brine']
# =========
# gluten_free
# ['thawed', 'raspberries', 'seeds', 'cream', 'cheese', 'sugar', 'cream', 'whipped cream', 'cream', 'cheese', 'raspberries', 'sugar', 'lemon juice', 'biscuit', 'lemon syrup', 'biscuits', 'biscuits', 'raspberry - cream', 'cheese', 'biscuits', 'biscuits', 'lemon syrup', 'raspberry - cream', 'cheese', 'raspberry - cream', 'cheese', 'biscuits', 'raspberry - cream', 'cheese', 'fresh', 'raspberries', 'fresh', 'mint sprigs']
# =========
# gluten_free
# ['sugar', 'sugar', 'sugar syrup', 'pur`the', 'strawberries', 'syrup', 'lime juice', 'sugar syrup', 'brandy', 'club soda', 'champagne', 'strawberry', 'lime']
# =========
# gluten_free
# ['chicken', 'salt', 'oil', 'curry powder', 'yogurt', 'chicken', 'chicken', 'marinade', '13x9', 'chicken', '-', 'bone', '30–35', 'chicken', 'juices', 'fat', 'juices', 'juices', 'yogurt', 'salt', 'chicken', 'Chicken', 'marinated']
# =========
# gluten_free
# ['sugar', 'lemon rind', 'cinnamon', 'cloves', 'nutmeg', 'rum', 'butter']
# =========
# gluten_free
# ['olive', 'oil', 'maple syrup', 'cayenne pepper', 'fresh', 'rosemary', 'fresh', 'thyme', 'walnut halves', 'fresh', 'thyme', 'kosher', 'salt']
# =========
# gluten_free
# ['garlic', 'garlic', 'brine', 'brine', 'pork', 'chops', 'brine', 'pork', 'chops', 'spice', 'pork', 'chops', 'brine', 'brine', 'spices', 'chops', 'chops', 'salt', 'pepper', 'spice', 'meat', 'chops', 'meat', 'chops', 'chops', 'meat', 'chops']
# =========
# gluten_free
# ['leek', 'parsley', 'leek', 'oil', '2-', 'zucchini', 'salt', 'wine', 'zucchini', 'parsley', 'salt', 'pepper', '-']
# =========
# gluten_free
# ['vinegar', 'mustard', 'oil', 'dressing', 'salt', 'pepper', 'cauliflower', 'olives', 'celery', 'dressing', 'salad', 'dressing', 'green', 'onions', 'parsley', 'salad', 'arugula', 'dressing', 'arugula', 'cauliflower', 'pepper']
# =========
# gluten_free
# ['cream', 'milk', 'coffee', 'beans', 'seeds', 'vanilla', 'bean', 'bean', 'cream', 'chocolate', 'chocolate', 'Kahlúa', 'sugar', 'egg', 'yolks', 'chocolate', 'chocolate', 'custard', '3/4-cup', 'custard', 'chocolate', 'custards', 'custards', 'custard', 'buttermilk', 'doughnut']
# =========
# gluten_free
# ['celery', 'lovage', 'salt', 'celery', '-', 'butter', '2-', '-', 'mushrooms', 'fennel', 'onion', 'salt', 'wine', 'celery', 'cream', 'butter', 'scallops', 'shrimp', 'shellfish', 'scallops', 'shrimp', 'vegetables', 'celery', 'oysters', 'liquor', 'seafood', 'vegetables', 'pepper', 'sea', 'salt']
# =========
# gluten_free
# ['bread', 'cubes', 'crumble', 'Butter 13x9x2-inch', 'butter', '-', 'onions', 'celery', 'corn', 'bread', 'broth', 'herbs', 'chestnuts', 'salt', 'pepper', 'egg', 'broth', 'stuffing']
# =========
# gluten_free
# ['breads', 'breads', 'artichoke', 'marinade', 'breads', 'feta', 'crumbled', 'feta', 'cheese', 'tomatoes', 'olives', 'oregano', 'artichokes', 'artichoke', 'marinade']
# =========
# gluten_free
# ['oil', '-', 'onions', 'lime juice', 'onions', 'salt', 'pepper', 'onions', 'cilantro']
# =========
# gluten_free
# ['-', 'sugar', 'berries pop']
# =========
# gluten_free
# ['puréei']
# =========
# gluten_free
# ['salt', 'freshly', 'black pepper', 'lime juice']
# =========
# gluten_free
# ['bruised', 'bok', 'choy', '-', 'carrot', '-', 'vegetable', 'oil', '4-', '-', 'bok', 'choy', 'carrot', 'ginger', 'Sherry', 'broth', 'sugar', 'scallions', 'bok', 'choy', 'scallions', 'carrot', 'vegetables', 'vegetables', 'fish', 'salt', 'pepper', 'cornstarch', 'curry powder', 'fillet', 'fillet', 'sesame', 'oil', 'salt', 'pepper', 'vegetable', '-', 'vegetable', 'oil', 'fish', 'fish', 'broth', 'vegetables', 'fish halves']
# =========
# gluten_free
# ['onion', 'carrot', 'mustard seeds', 'salt', 'pepper', 'butter', 'onion', 'broccoli', 'broth', 'broccoli', 'soup', 'puréed', 'lemon juice', 'salt', 'pepper', 'soup', 'sour cream', 'soup']
# =========
# gluten_free
# ['oil', 'shallots', 'shallots', 'Shallots', 'shallot', 'oil', 'dressing', 'lemon juice', 'salt', 'pepper', 'shallot', 'oil', 'prunes', 'escarole', 'shallots', 'salt', 'shallots']
# =========
# gluten_free
# ['mustard', 'mustard seeds', 'raspberry', 'vinegar', 'cranberries', 'sugar', 'eggs', '-', 'mustard', 'cranberries', 'lemon juice', 'honey', 'salt', 'pepper', 'cranberry -', 'mustard', 'mustard']
# =========
# gluten_free
# ['green', 'beans', 'ice', 'fennel', 'lemon', 'chiles', 'vinegar', 'sugar', 'peppercorns', 'salt', 'green', 'beans']
# =========
# gluten_free
# ['wine', 'sugar', 'mint', 'sugar', 'syrup', 'mint', 'vegetable', 'lemons', 'white pith', 'lemons', 'juice', 'lemons', 'seeds', 'lemons', 'juice', '/', 'lemon', 'mint syrup', 'salt', 'lamb', 'salt', 'pepper', 'oil', '-', 'lamb', '-', 'lamb', 'compote']
# =========
# gluten_free
# ['yogurt', 'cilantro', 'garlic', 'lemon juice', 'salt', 'pitas', 'pitas', 'carrots']
# =========
# gluten_free
# ['fishmonger', 'crabs', 'vegetable', 'oil', 'garlic', 'cloves', 'Bay', 'seasoning', 'fish', 'salt', 'pepper', 'crabs', 'muffins', 'butter', 'lemon juice', 'parsley', 'shallot', 'salt', 'pepper', 'butter', '-', 'crabs', 'basket', 'red', 'muffins', 'herb', 'butter', 'sandwich', 'crab', 'halves', '-', 'crabs', 'white', 'gills', 'crabs']
# =========
# gluten_free
# ['zest', 'lemon juice', 'shallot', 'mustard', 'salt', 'oil', 'dressing', 'pepper', 'parsley', 'zucchini', 'oil', 'zucchini', 'zucchini', '-', 'zucchini', 'purslane', 'tomatoes', 'dressing']
# =========
# gluten_free
# ['kiwi', 'strawberries', 'almonds', 'sparkling', 'juice']
# =========
# gluten_free
# ['-', 'dried', 'tomatoes', 'white', 'wine', 'white', 'wine', 'vinegar', 'black', 'peppercorns', 'bay leaf', 'tomatoes', 'tomato', 'cream', 'chicken', 'stock', 'thyme', 'salt']
# =========
# gluten_free
# ['olive', 'oil', 'onion', 'tomato', 'bell pepper', 'vegetables', 'chicken', 'broth', 'almonds', 'bay', 'sauce', 'bay leaf', 'sauce', 'salt', 'pepper', 'salt', 'pepper', 'meatballs', 'meatballs', 'sauce', 'almonds']
# =========
# gluten_free
# ['matzoh', 'meal', 'kosher', 'salt', 'pepper', 'brisket', 'matzoh', 'oil', '-', 'oil', 'brisket', 'fat', 'oil', 'shallots', 'garlic', 'wine', 'chicken', 'stock', 'cherries', 'sugar', 'balsamic', 'vinegar', 'anise', 'kosher', 'salt', 'salt', 'brisket', 'fat', '-', 'carrots', '-', 'ice', 'carrots', 'meat', 'braised', 'meat', '-', 'meat', 'meat', 'grain', 'fat', 'sauce', 'anise', 'salt', 'sauce', 'meat', 'sauce', 'meat', 'sauce', 'carrots', 'brisket', "'"]
# =========
# gluten_free
# ['ice - cream', 'coconut', 'snowballs', 'mocha', 'sauce', 'sugar', 'corn syrup', 'powder', 'sugar', 'chocolate', 'cream', 'Kahlûa', 'salt', 'sauce', 'mocha', 'sauce', 'snowballs', 'sauce']
# =========
# gluten_free
# ['butter', 'onions', '-', 'matzoh', 'eggs', 'matzoh', 'egg', 'onions', 'smoked', 'salmon', 'salt', 'pepper', 'butter', 'egg', 'eggs', 'dill']
# =========
# gluten_free
# ['banana', 'sorbet', 'fruit', 'juices', 'coconut']
# =========
# gluten_free
# ['-', 'almonds', 'nuts', 'chocolate', 'chocolate', 'almonds', 'matzoh', 'cake', 'meal', 'potato', 'starch', 'salt', 'yolks', 'coconut', 'milk', 'vanilla', 'chocolate', 'almond', 'grainy', 'egg', 'whites', 'salt', 'sugar', 'whites', 'whites', 'chocolate', 'whites', 'almond', 'batter', 'cake', '-', 'cake', 'reinvert', 'cake', 'sugar', 'potato', 'starch', 'coffee / spice', 'powdery', 'almonds', 'powdered sugar', 'berries']
# =========
# gluten_free
# ['nuts', 'nuts', 'nuts', 'nuts', '-', 'nuts']
# =========
# gluten_free
# ['bouillon', 'oil', 'beef', 'beef', 'oil', 'onions', 'garlic', 'onions', 'bouillon', 'tomatoes', 'juices', 'lemongrass', 'curry powder', 'bay', 'beef', 'juices', '-', 'beef', 'carrots', 'potatoes', 'mushrooms', 'vegetables', 'potatoes', 'potato', 'salt', 'pepper', 'parsley']
# =========
# gluten_free
# ['juicer', 'garbanzo', 'beans', 'parsley', 'tahini', 'lemon juice', 'onion', 'cumin', 'Braggs', 'tahini', 'garbanzo', 'spice', 'sesame seeds', 'powder', 'garbanzo', '-']
# =========
# gluten_free
# ['bacon', 'fat', 'bacon', 'fig', 'melon -', 'cheese', 'melon -', 'fig', 'fig halves', 'whole', 'figs', 'sugar', 'cumin', 'salt', 'bacon', 'bacon', 'fig', 'figs', 'bacon', 'bacon', 'mesclun', 'lemon juice', 'salt', 'pepper', 'oil', 'figs', 'salad']
# =========
# gluten_free
# ['fennel', 'celery', 'shallot', 'parsley', 'celery', 'pomegranate seeds', 'lime juice', 'oil', 'salt', 'pepper', 'pomegranate seeds']
# =========
# gluten_free
# ['bacon', 'cabbage', 'bacon fat', 'cabbage', 'bacon', 'salt', 'pepper', 'potatoes']
# =========
# gluten_free
# ['giblets', 'liver', 'turkey', 'turkey', 'whole', 'nutmeg', '-', 'cleaver', 'nutmeg', 'Sichuan', 'peppercorns', 'anise', 'cinnamon', 'cloves', 'coriander seeds', 'spices', 'stock', 'spice', 'ginger', 'salt', 'spice', 'ginger', 'turkey', 'brine', 'brine', 'turkey', 'chicken', 'stock', 'rice', 'pine', 'nuts', 'freom', 'chestnuts', 'sugar', 'chestnuts', 'butter', 'oil', 'shallots', 'garlic', 'sausage', 'mushrooms', 'rice', 'grains', 'oil', 'stock', 'rice', 'stock', 'rice', 'pine', 'nuts', 'chestnuts', 'salt', 'pepper', 'turkey', 'brine', 'breast', '-', 'stuffing', 'legs', 'bird', 'butter', 'breast', 'turkey', 'breast', 'butter', 'turkey', 'breast', 'juices', 'stuffing', 'fleshy', 'bone', 'juices', 'breast', 'turkey', 'stuffing', 'turkey']
# =========
# gluten_free
# ['oil', 'lemon', 'beans', 'cream', 'dill', 'lemon juice', 'sauce', 'beans', 'beans', 'salt', 'pepper']
# =========
# gluten_free
# ['black', 'beans', 'garlic', 'garlic', 'cumin', 'oil', 'black', 'beans', 'juice', 'salt', 'beans', 'cilantro']
# =========
# gluten_free
# ['jalapeño', 'turmeric', 'ginger', 'garlic', 'cilantro', 'oil', 'lime zest', 'lime juice', 'flecks', 'cilantro', 'salt', 'corn', 'charred', '6–8', 'kernels', 'kernels', '-', '-', '8–10', 'peppers', 'blackened', '12–18', 'charred', 'corn', 'tomatoes', 'blackened', 'tomatoes', 'endive', 'greens', 'corn', 'dressing', 'salt']
# =========
# gluten_free
# ['milk', 'rice', 'sugar', 'butter', 'cinnamon', 'salt', '-', 'rice', 'cinnamon', 'raisins', 'vanilla', 'milk', 'egg', 'yolks', 'milk', 'beaten', 'yolks', 'egg', 'rice', 'rice', 'pudding', 'nonmetal', 'rice', 'pudding', 'milk']
# =========
# gluten_free
# ['15x10x2-inch', 'olive', 'oil', 'salt', 'polenta', 'polenta', 'polenta', 'pepper', 'polenta', 'polenta', 'polenta', 'polenta', 'polenta', 'oil', '-', 'polenta', 'polenta', 'polenta', 'oil', 'polenta', 'Spicy', 'Tomato -', 'Basil', 'Sauce', 'fresh', 'basil sprigs', 'yellow', 'cornmeal', '- bodied red', 'wine', 'spicy', 'sauce', 'Montresor', 'Veronese', 'Valpolicella', 'lovely red', 'dried', 'fruit', 'vanilla']
# =========
# gluten_free
# ['coriander seeds', 'cumin seeds', 'caraway seeds', 'crushed red pepper', 'spice']
# =========
# gluten_free
# ['beets', 'cookie', 'beets', 'beets', 'sour cream', 'juice', 'cardamom', 'salt', 'garlic', 'zest', 'pita']
# =========
# gluten_free
# ['ice cream']
# =========
# gluten_free
# ['oil', 'vinegar', 'olivada', 'garlic', 'salt', 'pepper', 'chicken', '8x8x2-inch', 'thyme', 'dressing', 'chicken', 'oil', 'dressing', 'chicken', 'dressing', 'chicken', '-', 'dressing', 'chicken', 'marinade', 'marinade', 'chicken', 'salt', 'pepper', 'greens', 'fennel', 'radicchio', 'onion', 'dressing', 'chicken', 'breasts', '-', 'salads', 'figs', 'pine', 'nuts']
# =========
# gluten_free
# ['chicken', 'salt', 'pepper', 'onion', 'salt', 'pepper', 'oil', '10-', 'garlic', 'chicken', 'onion', 'cheese', 'tortilla', 'chicken', 'tortilla', '-', 'quesadillas', 'quesadillas', 'cheese']
# =========
# gluten_free
# ['capers', 'salt', 'vinegar', 'Salsa', 'salsa', 'vinegar']
# =========
# gluten_free
# ['cream', 'milk', 'syrup', 'pumpkin', 'yolks', 'cinnamon', 'nutmeg', 'salt', 'pumpkin', 'yolks', 'custard', '-', 'custard', 'custard', 'custards', 'custard', 'custards', '-', '-', '0852']
# =========
# gluten_free
# ['tentacles', 'octopus', '6-', '-', 'octopus', 'salt', 'octopus', 'purple', 'octopus', 'tomatoes', 'juices', 'Sautá', 'garlic', 'red pepper', 'oil', '6-', 'parsley', 'basil', 'tomatoes', 'juices', 'octopus', 'salt', 'pepper', 'linguine', 'octopus', 'sauce', 'linguine']
# =========
# gluten_free
# ['leek', 'onion', 'garlic', 'salt', 'pepper', 'oil', 'leek', 'potato', 'potato', 'zucchini', 'broth', 'leek', 'potato', 'puréed', 'cream', 'lemon juice', 'salt', 'pepper', 'soup', 'soup', 'ice', 'lemon juice', 'salt', 'pepper', 'soup', 'lemon']
# =========
# gluten_free
# ['cumin', 'oil', 'lime juice', 'chipotle', 'chilies', 'dressing', 'salt', 'pepper', 'peppers', 'blackened', 'seed', 'peppers', 'peppers', '-', 'corn', 'green', 'onions', 'cilantro', 'dressing', 'spinach', 'cilantro', 'Chipotle', 'chilies', 'canned', 'spicy', 'tomato', 'sauce', 'adobo']
# =========
# gluten_free
# ['zucchini', 'broth', '-', 'zucchini', 'soup', 'soup', 'cream', 'nutmeg', 'cheese', 'salt', 'pepper']
# =========
# gluten_free
# ['chicken', 'broth', 'rice', 'salt', 'pepper', 'rice', 'rice', 'chicken', 'broilerproof', 'chicken', 'olive', 'oil', 'chicken', 'salt', 'pepper', 'cumin', 'chicken', 'chicken', 'chicken', 'black', 'beans', 'corn', 'bell pepper', 'red', 'onion', 'cilantro', 'rice', 'chicken', 'broth', 'olive', 'oil', 'cumin', 'lime juice', 'garlic', 'garlic', 'salt', 'pepper', 'dressing', 'salad', 'well.(Can']
# =========
# gluten_free
# ['sugar', 'juniper', 'berries', 'rosemary', 'salt', 'sugar', 'blueberries', 'syrup', 'berries', 'gin']
# =========
# gluten_free
# ['-', 'heat).Blend', 'salsa', 'salt', 'fish', 'olive', 'oil', 'salt', 'pepper', 'salsa', 'pineapple']
# =========
# gluten_free
# ['polenta', 'Polenta', '-', 'oil', 'sausage', 'sausage', 'sausage', 'fat', 'sausage', 'polenta', 'diamond', 'polenta', 'fat', 'oil', 'polenta', 'sausage', 'oil', 'broccoli', 'rabe', 'salt', 'garlic', 'tomato', 'sauce', 'sausage', 'polenta', 'polenta', 'Parmesan', 'salt', 'cornmeal', 'polenta', 'cornmeal', 'polenta', 'polenta', 'Polenta', 'polenta', 'lumpless', 'flavor', '-', 'Marcella', 'polenta', 'flavorful', 'polenta', 'imported', 'polenta', 'precooked', 'cornmeal']
# =========
# gluten_free
# ['rice', '1/2-quart', 'rice', 'salt', 'rice', 'rice', 'rice', 'onion', 'tomatoes', 'shallot', 'parsley', 'casings', 'sausages', '-', 'sausages', 'oil', 'pink', 'onion', 'tomatoes', 'shallot', 'onion', 'rice', 'parsley', 'salt', 'pepper', 'stuffing', 'Stuffing', 'butter', 'Cornish hens', 'hens', 'salt', 'pepper', 'stuffing', 'hen', 'stuffing', '-', 'butter', 'hens', 'hens', 'Port', 'broth', 'hens', 'bone', 'hens', 'broth', 'stuffing', 'hens', 'Port', 'bits', 'glaze', 'broth', 'broth', 'arrowroot', 'broth', 'salt', 'pepper', 'hens', 'hens', 'hen', 'stuffing', 'sauce']
# =========
# gluten_free
# ['olives', 'herbs', 'lemon juice', 'zest', 'oil', 'olives', 'marinated', 'olives', 'olives']
# =========
# gluten_free
# ['-', 'potatoes', 'oil', 'potatoes', 'dressing', 'potatoes', 'potato']
# =========
# gluten_free
# ['chocolate', 'hazelnuts', 'hazelnuts', 'hazelnut', 'nuts', 'sugar', 'butter', 'sugar', 'yolks', 'vanilla', 'salt', 'chocolate', 'hazelnut', 'whites', 'salt', '-', 'whites', 'chocolate', 'whites', 'batter', 'crumbs', 'torte', 'torte', 'chocolate', 'cream', 'chocolate', 'glaze', 'glaze', 'torte', 'butter', 'glaze', 'torte', 'hazelnuts', 'torte', 'glaze', 'torte', 'whipped cream', 'ice cream']
# =========
# gluten_free
# ['cranberries', 'sugar', 'orange juice', 'sugar', 'sauce', '/', 'cranberries', 'parsley', 'orange', 'cranberry', 'relish', 'cranberry', 'sauce']
# =========
# gluten_free
# ['Butter', '-', '-', 'almonds', 'almond', 'cream', 'cheese', 'sugar', 'eggs', 'filling', 'crust', 'apple', 'lemon juice', 'butter', 'apples', 'sugar', 'cinnamon', 'butter', 'glazed', 'cheesecake', 'apples', 'cheesecake', 'apples', 'juices']
# =========
# gluten_free
# ['sauce', 'salt', 'pepper']
# =========
# gluten_free
# ['salt', 'pepper']
# =========
# gluten_free
# ['tomatillos', 'jalapeño', 'cilantro', 'garlic', 'green', 'onions', 'salt', 'avocado', 'seasoning']
# =========
# gluten_free
# ['chicken', 'salt', 'chicken', 'tamarind', 'pulp', '-', 'shallots', 'chiles', 'ginger', 'turmeric', 'cumin', 'coriander', 'lemongrass', 'coconut', 'milk', 'tamarind', 'shallot', 'lemongrass', 'galangal', 'sugar', '6-', '7-quart', 'chicken', 'chicken', 'sauce', 'fat', 'lemongrass', 'sauce', 'salt', 'chicken']
# =========
# gluten_free
# ['corn', 'kernels', 'cornmeal', 'corn', 'kernels', 'corn', 'corn', 'corn', 'onion', 'bell pepper', 'lime', 'rice', 'cilantro', 'jalapeño', 'salt', 'cumin', '-', 'patties', 'burgers', 'tortillas', 'tortillas', 'tortilla', 'burger', 'sour cream', 'salsa', 'tortillas']
# =========
# gluten_free
# ['-', 'compote', 'sorbet']
# =========
# gluten_free
# ['bouillon', 'bouillon', 'shrimp', 'shrimp', 'shrimp', 'Shell', 'shrimp', 'coffee / spice', 'caraway seeds', 'caraway', 'vinegar', 'sugar', 'salt', 'pepper', 'sugar', 'oil', 'shrimp', 'watercress', 'bite -', 'sprigs', 'endives', 'endives', '-', 'watercress', 'shrimp']
# =========
# gluten_free
# ['oil', 'onions', 'garlic', 'salt', 'pepper', 'onions', 'onions', 'prunes', 'Armagnac', '1-', 'stuffing', '-', 'prunes', 'pork', 'Armagnac', 'prunes', 'pork', 'salt', 'pepper', 'parsley', 'thyme', 'sage', 'bay leaf', 'peppercorns', 'cloves', 'pork', 'mustard', 'sugar', 'oil', 'meat', 'pork', 'white', 'wine', 'Armagnac', 'prunes', 'broth', 'onions', 'Armagnac', 'pork', 'juices', 'pork fat', 'prunes', 'meat', 'stuffing', 'pork', '-', 'pork', 'pork', 'fat', 'sauce', 'vinegar', 'salt', 'pepper']
# =========
# gluten_free
# ['olive', 'oil', 'lemon juice', 'capers', 'cayenne', 'parsley', 'fettuccine', 'lemon', 'salt', 'fillets', 'salt', 'pepper', '-', 'vegetable', 'oil', 'fillets', 'fillets', 'fettuccine', 'fillets', 'fillet', 'lemon']
# =========
# gluten_free
# ['peaches', 'peaches', 'peaches', 'peaches']
# =========
# gluten_free
# ['sprigs', 'fresh', 'tarragon', 'parsley', 'bird', 'butter', 'salt', 'pepper', 'bird', 'tarragon', 'breast', 'bird', 'seasoned', 'butter', 'tarragon', 'spitted', 'chicken', 'tarragon', 'butter', 'tarragon', 'butter', 'potatoes', 'roasted', 'fresh', 'raw', 'vegetables']
# =========
# gluten_free
# ['lemongrass', 'lemongrass', 'stock', 'chiles', 'shallot', 'garlic', 'ginger', 'turmeric', 'kaffir lime leaf', 'coriander', 'cumin', 'salt', 'sugar', 'Curry']
# =========
# gluten_free
# ['parsley', 'orange', 'rosemary', 'garlic', 'cloves', 'potatoes', '13x9x2-inch', 'oil', 'salt', 'pepper', 'potatoes', 'halibut', 'fillets', 'potatoes', 'fish', 'salt', 'pepper', 'fish', 'potatoes', 'potatoes', 'fish', 'orange juice', 'vinegar', 'parsley', 'garlic clove', 'bits', 'sauce', 'salt', 'pepper', 'sauce', 'fish', 'parsley']
# =========
# gluten_free
# ['sugar', 'anise', 'sugar', 'syrup', 'anise', 'pineapple', 'rind', 'chunks', 'juice', 'rind', 'chunks', 'syrup', 'ice cream', 'pineapple', '-', 'butter', 'pineapple', 'butter', 'pineapple', 'undersides', 'roasted', 'pineapple', 'sorbet']
# =========
# gluten_free
# ['berries', 'sugar', 'juicy', 'vinegar', 'vinegar thourough', '-']
# =========
# gluten_free
# ['beans', 'shallot', 'bay', 'salt', 'beans', '-', 'beans', 'anchovies', 'garlic', 'parsley', 'capers', 'lemon zest', 'lemon juice', 'oil', 'salt', 'pepper', 'beans', 'shallot', 'bay', 'parsley', 'bean', 'soup', 'beans', 'beans', 'salt', 'lemon juice', 'salt', 'salt', 'halibut', 'fish', 'salty', 'halibut', 'oil', '-', 'halibut', 'crust', 'butter', 'butter', 'fillets', 'halibut', 'beans', 'lemon']
# =========
# gluten_free
# ['mayonnaise', 'salt', 'black pepper', 'cayenne pepper', 'mushroom', 'onion', 'oil', 'salt', 'pepper', 'thyme', 'mushrooms', 'gill', 'garlic', '-', 'mushrooms', 'gill', 'onion', 'vegetables', 'mushrooms', 'onion', 'mushrooms', 'gill', 'cheese', 'cheese', 'mushrooms', 'bottoms', 'aioli', 'mushroom', 'onion', 'watercress', 'aioli', 'watercress']
# =========
# gluten_free
# ['onions', 'onions', 'sugar', 'red', 'wine', 'vinegar', 'balsamic', 'vinegar', 'onions', 'bite', 'onions', 'yolk', 'garlic', 'mustard', 'vinegar', 'aïoli', 'salt', 'pepper', 'pepperoncini', 'bacon', 'ciabatta', 'turkey', 'ciabatta', 'bottoms', 'onion', 'relish', 'meat', 'bacon', 'ciabatta', 'bacon', 'crispy', 'ciabatta', 'turkey', 'bacon', 'ciabatta', 'onion', 'relish', 'avocado', 'sandwiches', 'bacon', 'aïoli', 'ciabatta', 'sandwiches']
# =========
# gluten_free
# ['garlic', 'cloves', 'garlic', 'seasoning', 'salt']
# =========
# gluten_free
# ['egg', 'lemon juice', 'mustard', 'sea', 'salt', 'freshly', 'white', 'black pepper', 'oil', 'dressing', 'mayonnaise']
# =========
# gluten_free
# ['gelatin', 'gelatin', 'sugar', 'lemon juice', 'sugar', 'candy', 'egg', 'whites', 'salt', 'syrup', 'egg', 'whites', 'gelatin', 'lemon', 'yogurt', 'custard']
# =========
# gluten_free
# []
# =========
# gluten_free
# ['berries', 'fresh', 'ginger', 'berries', '-', 'oil', 'spritz', 'oil', 'oats', '-', 'catching', 'yogurt', 'berries', 'oats']
# =========
# gluten_free
# ['- leaf', 'parsley', 'kale', 'ribs', 'berries', 'strawberries', 'raspberries', 'banana', 'flaxseed']
# =========
# gluten_free
# ['beans', 'avocados', 'chili powder', 'onion', 'pepper', 'garlic', 'avocado', 'beans', 'sour cream', 'taco', 'sauce', 'cheese', 'jalapeño', 'sauce', 'olives', 'scallions', 'tomatoes', 'sour cream', 'tortilla chips']
# =========
# gluten_free
# ['tenderloin', 'Pound', 'turkey', '-', 'bottomed', 'tenderloin', 'lemon juice', 'turkey', 'oil', '-', 'turkey', 'turkey', 'onion', 'garlic', 'wine', 'wine', 'glaze', 'broth', 'tomatoes', 'basil', 'lemon', 'sauce', 'turkey']
# =========
# gluten_free
# ['mashed', 'beans', '-', 'patties', 'burgers', 'onion', 'toasted', 'burgers', 'onion', 'burger', 'onion', 'watercress']
# =========
# gluten_free
# ['bacon', 'bacon', 'drippings', 'beans', '-', 'drippings', 'scallops', 'salt', 'pepper', 'scallops', 'beans', 'vinegar', 'mustard', 'drippings', 'bits', 'cream', 'sauce', 'salt', 'pepper', 'bacon', 'beans', 'scallops', 'sauce', 'dill']
# =========
# gluten_free
# ['tomatillos', 'tomatillos', 'tomatillos', 'celery', 'cilantro', 'radishes', 'julienne', 'salt', 'Salsa']
# =========
# gluten_free
# ['-', 'wheat', 'berries', 'amaranth', 'grains', 'wheat', 'berries', 'amaranth', 'grains', 'cream', 'sugar', 'yogurt', 'sugar', 'cream', 'yogurt', 'grains', 'fruit', 'grains', 'cream', 'fruit']
# =========
# gluten_free
# ['cockles', '-', 'shells', 'clams', 'juices', 'clams', 'clams', 'parsley', 'garlic', 'olive', 'oil', 'lemon juice', 'lemon zest', 'clams', 'oil', 'clams', 'shell', 'oil']
# =========
# gluten_free
# ['pumpkin seeds', '9-', '-', 'oil', 'sea', 'salt']
# =========
# gluten_free
# ['raspberries', 'strawberries', 'sugar', '2-', '-', 'fruit', 'sugar', '-', 'seeds']
# =========
# gluten_free
# ['clam juice', 'wine', 'clams', 'mussels', 'shellfish', 'mussels', 'clams', 'shellfish', 'shrimp shells', '4-cup', 'butter', 'leek', 'leek', 'potato', 'celery', 'Calvados', 'potato', 'shrimp', 'scallops', 'crème fraîche', 'egg', 'yolks', 'lemon juice', 'clams', 'mussels', 'shrimp', 'scallops', 'salt', 'pepper', 'parsley']
# =========
# gluten_free
# ['onion', 'onions', 'melon -', '1/3-inch -', 'shells', 'bottoms', 'thicker', 'scooped -', 'onion', 'onion shells', 'kale', 'onion', 'garlic', 'oil', 'red pepper', 'onion', 'onion', 'kale', 'salt', 'pepper', 'kale', 'cornstarch', 'kale', 'pimiento', 'Parmesan', 'salt', 'pepper', 'onion shells', 'kale', 'onions']
# =========
# gluten_free
# ['berries', 'sauce', 'cinnamon', 'cloves', 'bay leaf', 'sauce']
# =========
# gluten_free
# ['salt', 'pepper', 'Rewhisk']
# =========
# gluten_free
# ['cumin', 'coriander', 'garlic', 'oil', 'pork', 'chops', 'salt', 'pepper', 'spice', 'chops', 'oil', 'chops', 'pork', 'chops', 'cilantro', 'lime']
# =========
# gluten_free
# ['broth', 'lentils', 'lentils', 'olive', 'oil', '-', 'onion', 'bell pepper', 'celery', 'onion', 'lentils', 'tomato', 'sauce', 'salsa', '-', 'lentils', 'soup', 'broth', 'spinach', 'soup', 'salt', 'pepper']
# =========
# gluten_free
# []
# =========
# gluten_free
# ['sugar', 'sugar', 'syrup', 'cranberries', 'cranberries', 'sauce', 'ginger', 'peaches']
# =========
# gluten_free
# ['salsa', 'avocado', 'lime juice', 'olive', 'oil', 'cilantro', 'salt', 'pepper']
# =========
# gluten_free
# ['suds']
# =========
# gluten_free
# ['lemon', 'juice', 'lemon', 'artichokes', 'artichoke', 'base', 'green', 'yellow', 'base', '-', 'heart', 'artichoke', 'green', 'base', 'artichoke', 'fresh', 'green', 'artichoke hearts', 'melon -', 'grapefruit', 'purple -', 'artichoke', 'lemon', 'artichoke', 'lemon', 'artichokes']
# =========
# gluten_free
# ['oil', '4-', 'pappadam', 'oil', '-', 'pappadam', 'oil', 'pappadams', 'pappadams', 'oil', 'oil']
# =========
# gluten_free
# ['thyme sprigs', 'broth', 'salt', 'rice', '-', 'rice', '40–45', 'thyme', 'farro', 'thyme sprigs', 'broth', '35–40', 'white pith', 'tangerines', 'juice', 'juice', 'oil', 'tangerine juice', 'salt', 'pepper', 'tangerine', 'wild', 'rice', 'farro', 'scallions', 'tangerine juice']
# =========
# gluten_free
# ['scallops', 'peas', 'egg', 'white', 'cream', 'salt', 'tarragon', 'salmon', 'terrine', 'terrine', 'terrine', 'terrine', 'terrine', 'terrine', 'terrine', 'terrine', 'terrine', 'terrine', 'terrine', 'chive', 'butter', 'sauce', 'tsatsiki', 'shallot', 'vermouth', 'vinegar', 'butter', 'sauce', 'hollandaise', 'chives', 'salt']
# =========
# gluten_free
# []
# =========
# gluten_free
# ['garlic', 'garlic', 'oil', 'salt', 'pepper', 'cloves', 'cloves', 'cumin', '-', 'spice', 'yogurt', 'cucumber', 'cilantro', 'mint', 'jalapeño', 'lemon juice', 'cumin', 'salt', 'pepper', 'lemon juice', 'legumes', 'rice', 'legumes', 'rice', '-', 'legumes', 'rice', 'garlic', 'ginger', 'jalapeño', 'grainy', '-', 'tendrils', 'oil', '-', '1/4-cupfuls', 'batter', '1/4"-thick', 'cakes', 'oil', 'cakes', '-', 'oil', 'batter', 'raita', 'roasted', 'garlic clove', 'cakes']
# =========
# gluten_free
# ['vegetables', 'potatoes', '-', 'potatoes', 'ice', 'potatoes', 'carrots', 'green', 'beans', 'potatoes', 'onion', 'curry powder', 'oil', 'onion', 'tomatoes', 'vegetables', 'mayonnaise', 'yogurt', 'vegetable', 'chicken', 'pork', 'ham', 'salt', 'pepper', 'Salad']
# =========
# gluten_free
# ['feta', 'spices', 'coriander', 'cumin', 'caraway seeds', 'spices', 'olive', 'oil', 'salt', 'spices', 'oil', 'feta', 'feta', 'herbs', 'herbs', 'walnuts', 'radishes', 'lavash', 'feta', 'salt', 'herbs', 'flatbread', 'herbs', 'walnuts', 'cheese', 'radish', 'sandwich']
# =========
# gluten_free
# ['oil', '-', 'shallots', 'rice', 'wild', 'rice', 'wheat', 'berries', 'stock', 'grains', 'cranberries', 'apricots', 'currants', 'grains', 'vinegar', 'walnut', 'oil', 'sage', 'salad', 'salt', 'pepper.(Can', 'pecans', 'salad']
# =========
# gluten_free
# ['mayonnaise', 'apple', 'cider', 'vinegar', 'sugar', 'maple syrup', 'green cabbage', 'dressing', 'salt', 'pepper', 'paprika']
# =========
# gluten_free
# ['garlic', 'lemon zest', 'salt', 'lemon juice', 'vinegar', 'sugar', 'garlic', 'oil', 'seasoning']
# =========
# gluten_free
# ['agave', 'oil', 'oats', 'coconut', 'pecans', 'rice', 'cereal', 'sesame seeds', 'salt', 'cinnamon', 'egg', 'white', 'oat', 'oat', '-', 'granola', '25–30', 'granola', 'Granola']
# =========
# gluten_free
# ['rice', 'rice', 'rice', 'rice', 'rice', 'rice', 'rice', 'enameled', 'vinegar', 'sugar', 'salt', 'sugar', 'vinegar', 'rice', 'vinegared', 'rice']
# =========
# gluten_free
# ['shrimp', 'shell', 'shells', 'tomatoes', 'scallion', 'garlic', 'lemon', 'lime', 'juices', 'salt', 'pepper', 'avocado', 'tomato', 'salsa', 'salsa', 'shrimp', 'lime']
# =========
# gluten_free
# ['peaches', 'lemon juice', 'sugar', 'cardamom', 'raspberries']
# =========
# gluten_free
# ['Butter', 'sugar', 'honey', 'sugar', 'syrup', 'amber', 'pastry', 'almonds', 'praline', '9x5x23/4-inch', 'vanilla ice cream', 'brandy', 'orange', 'cookies', 'ice cream', 'vanilla ice cream', 'coffee ice cream', 'brandy', 'coffee', 'praline', 'coffee ice cream', 'vanilla ice cream', 'vanilla ice cream', 'coffee ice cream', 'torte', '-', 'oranges']
# =========
# gluten_free
# ['bagel halves', 'goat', 'cheese', 'salami', 'tomato', 'basil', 'toppings', 'pepper']
# =========
# gluten_free
# ['ginger', 'sugar', 'maple syrup', 'syrup', 'ginger', '- spice powder', 'sugar', 'Champagne', 'sugar', 'crystallized', 'ginger', 'anise', 'syrup', 'Champagne']
# =========
# gluten_free
# ['carrots', 'apples', 'grated', 'sour cream', 'horseradish', 'parsley', 'lemon juice', 'sugar', 'salt', 'pepper', 'salad']
# =========
# gluten_free
# ['herbs', 'butter', 'lemon zest', 'salt', 'Butter']
# =========
# gluten_free
# ['cocoa powder', 'sugar', 'vanilla', 'salt', 'cocoa powder', '-', '-', 'milk', 'scalded', 'chocolate', 'crème', 'menthe', 'crème', 'cacao', 'chocolate', 'chocolate', 'whipped cream', 'chocolate']
# =========
# gluten_free
# ['whites', 'salt', 'sugar', 'meringue', 'dabs', 'meringue', 'meringue', 'pastry', '-', 'cigars', 'meringue', 'pastry', 'cigars', 'cigars', 'pistachios', 'cigars', 'white', 'meringue', 'cigars', '-', 'zest', 'juice', 'sugar', 'eggs', 'butter', 'butter', 'curd', 'lemon curd', 'curd', 'cream', 'confectioners', "' sugar", 'whipped cream', 'lemon curd', 'cream', 'strawberries', 'meringue', 'cigars']
# =========
# gluten_free
# ['potatoes', 'mustard', 'honey', 'butter', '-', 'shallots', 'chard', 'potatoes', 'mustard', 'nutmeg', 'salt', 'pepper']
# =========
# gluten_free
# ['sweet', 'potatoes', 'butter', '- spice powder', 'freshly grated orange', '- spice powder', 'spice', 'supermarket']
# =========
# gluten_free
# ['yogurt', 'chicken', 'salt', 'pepper', 'Chutney', '-', 'oil', 'marinade -', 'chicken', 'chicken', 'chicken', '-', 'chutney']
# =========
# gluten_free
# ['butter', 'wine', 'vinegar', 'shallot', 'cream', 'butter', 'sauce', 'sauceboat', 'sauce', 'lemon juice', 'salt', 'pepper', 'sauce']
# =========
# gluten_free
# ['gelatin', 'orange juice', 'zest', 'berries', 'egg', 'yolks', 'sugar', 'yellow', 'liqueur', 'egg yolk', 'egg yolk', 'blackberry', '-', 'cream', 'blackberry', 'egg yolk', 'whole', 'blackberries', 'mint']
# =========
# gluten_free
# ['sugar', 'cream', 'tartar', 'sugar', 'syrup', 'amber', 'pastry', 'nuts', 'syrup', 'syrup', 'amber', 'nuts', 'syrup', 'praline', 'praline', 'praline', 'yolks', 'cream', 'milk', 'sugar', 'sugar', 'cream', 'yolks', '-', 'custard', '4-cup', 'white chocolate', 'chocolate', 'custard', 'chocolate', 'vanilla', 'custard', 'custard', 'ice cream', 'ice cream', '9x5x3-inch', 'ice cream', 'praline', 'ice cream', 'praline', 'ice cream', 'terrine', 'terrine', 'sauce', 'praline']
# =========
# gluten_free
# ['apples', 'juicer', 'juice', 'juice', 'vitamin', 'lemon juice', 'ginger', 'juicer', 'ginger juice', 'apple juice', 'sugar', 'basil', 'sugar', 'green', 'basil', 'apple juice', 'sugar', '-', '8-']
# =========
# gluten_free
# ['walnuts', 'potatoes', 'garlic', 'lemon zest', 'lemon juice', 'oil', 'salt', 'skordalia', 'oil', 'chives', 'toasted', 'walnuts', 'pita chips', 'cucumbers']
# =========
# gluten_free
# ['sugar', 'Angostura bitters', 'champagne', 'champagne', 'sparkling', 'wine', 'lemon', 'orange twist']
# =========
# gluten_free
# ['lemon', 'Cornish', 'hen halves', 'salt', 'pepper', 'hen halves', 'lemon', 'hen halves', 'orange marmalade', 'fresh', 'lemon juice', 'bourbon', 'grated', 'lemon', 'cloves', 'marmalade', 'glaze', 'marmalade glaze', 'salt', 'pepper', 'hen halves', 'marmalade glaze', 'hen halves', 'juices', 'hen halves', 'marmalade glaze']
# =========
# gluten_free
# ['eggs', 'tarragon', 'salt', 'pepper', 'cream', 'cheese', 'bits', 'butter', 'egg', 'eggs', 'salt']
# =========
# gluten_free
# []
# =========
# gluten_free
# ['papaya', 'mango', 'lime juice', 'ginger', 'sorbet', 'ice']
# =========
# gluten_free
# ['eggplant', 'oil', 'garlic', 'cloves', 'garlic', 'garlic', 'oil', 'eggplant', 'eggplant', 'eggplant', 'collapsed', 'garlic', 'eggplant', 'garlic', 'eggplant', 'eggplant', 'roasted', 'garlic', 'eggplant', 'lemon juice', 'tahini', 'parsley', 'salt', 'parsley', 'pita']
# =========
# gluten_free
# ['garlic', 'cloves', 'oil', 'garlic', 'chiles', 'chiles', 'garlic', 'chiles', 'vinegar', 'honey', 'oil', 'salt', '/', '-', '-', '4433']
# =========
# gluten_free
# ['tomatillos', 'chile', 'onion', 'garlic', 'salt', 'cilantro', 'lime juice', 'salt']
# =========
# gluten_free
# ['buttermilk', 'yogurt', 'avocado', 'cucumber', 'garlic', 'salt', 'scallions', 'herbs', 'chile', 'lime zest', 'salt', 'pepper', 'lime juice', 'sweetener', 'Seed', 'cucumber', 'soup', 'soup', 'chives', 'radishes', 'herb sprigs', 'pistachios']
# =========
# gluten_free
# ['pistachios', 'oil', 'salt', 'pistachios', '5–7', 'curry powder', 'oil', 'garlic', 'vinegar', 'mustard', 'curry', 'oil', 'dressing', 'salt', 'beets', 'dressing', 'salt', 'beets', '8–10', 'carrots', 'dressing', 'salt', 'lemon juice', 'pistachios', 'Curry', 'dressing']
# =========
# gluten_free
# ['bourbon', 'whiskey', 'orange juice', 'sugar', 'butter']
# =========
# gluten_free
# ['pickled', 'watermelon', 'rind', '-', 'vinegar', 'coriander seeds', 'peppercorns', 'onion', 'shrimp', 'lemon', 'salt', 'shrimp', 'rind', 'marinade', 'salt']
# =========
# gluten_free
# ['garlic clove', 'oil', 'mussels', 'mussels', 'mussels', 'mussels', 'liqueur', 'marinade', 'mussels', 'shells', 'shell', 'mussel', 'mussels', 'marinade', 'salt', 'mussels', 'shells', 'garlic clove', 'oil', 'garlic', 'oil', 'chervil', 'parsley', 'salt', 'herbs', 'Chervil', 'oil', 'oil', 'mussel shells', '‚', 'chervil', 'oil', 'shell', 'mussels', 'chervil']
# =========
# gluten_free
# ...
# =========
# kosher
# ['vegetable', 'oil', '-', 'sugar', '- spice powder', 'cumin', 'freshly', 'black pepper', 'sugar', 'pecan halves', 'pecans', 'kosher', 'salt']
# =========
# kosher
# ['beets', 'beets', 'olive', 'oil', 'salt', 'pepper', 'beets', 'beets', 'beets', 'cubes', 'yogurt', 'lemon juice', 'tahini', 'beets', 'salt', 'pepper', 'cucumber', 'parsley', 'green', 'onions', '-', 'virgin', 'olive', 'oil', 'lemon juice', 'salt', 'pepper', '-', 'tuna cubes', 'tuna', 'olive', 'oil', 'salt', 'pepper', 'oregano', 'tuna', 'charred', 'pink', 'pita', 'breads', 'charred', 'pita', 'bread', 'parsley', 'salad', 'pita', 'tuna', 'beet tahini', 'onion', 'lemon']
# =========
# kosher
# ['rice', 'rice', '2-', 'coconut', 'milk', 'whole', 'milk', 'rice', 'sugar', 'salt', 'lime zest', 'pudding', 'pudding', '2/3-cup', 'custard', 'Puddings', 'puddings', 'coconut']
# =========
# kosher
# ['rind', 'melon', 'fruit', 'melon', 'sugar', 'lime juice', 'mint', 'ice', 'limeade']
# =========
# kosher
# ['butter', 'sugar', 'milk', 'egg', 'flour', 'powder', 'cinnamon', 'salt', 'milk', 'blueberries', 'batter']
# =========
# kosher
# ['raspberries', 'sugar', 'sugar', 'berries', 'thaw', 'raspberry', 'lemon', 'raspberry syrup', 'raspberry syrup', 'lemon juice', 'sparkling', 'pitcher', 'ice cubes', 'raspberry lemonade', 'fresh', 'raspberries', 'lemon']
# =========
# kosher
# ['flours', 'powder', 'soda', 'salt', 'yogurt', 'orange juice', 'sugar', 'orange zest', 'vanilla', 'Vitamix', 'yogurt', 'flour', 'cranberries', 'dough', '23-cm', 'milk']
# =========
# kosher
# ['egg', 'yolks', 'sugar', 'cream', 'seeds', 'vanilla', 'bean', 'bean', 'cream', 'cream', 'yolks', 'custard', 'custard', 'chocolate', 'custard', 'chocolate', 'custard', 'chocolate', 'custard', '2/3-cup', 'custard', 'custards', 'vanilla', 'custard', 'chocolate', 'custard', 'vanilla', 'custard', 'sugar', 'sugar', 'browns', 'custards', 'sugar', 'custards']
# =========
# kosher
# ['milk', 'coffee', 'milk', 'sugar']
# =========
# kosher
# ['oil', 'shallot', 'ginger', 'shallots', 'mustard seeds', 'cinnamon', 'seeds', 'toasted', 'pop', 'cranberries', 'sugar', 'orange zest', 'cranberries', 'cinnamon', 'orange']
# =========
# kosher
# ['celery', 'parsnips', 'potatoes', 'vegetables', 'vegetables', 'milk', 'salt', 'pepper', 'butter']
# =========
# kosher
# ['potatoes', 'carrots', 'potatoes', 'zucchini', 'potatoes', 'carrots', 'onion', 'vegetables', 'mess', 'Vegetables', 'grated', 'grater', 'grated', 'vegetables', 'beaten', 'eggs', 'salt', 'pepper', 'matzah', 'meal', 'batter', 'pancakes', '-', 'latkes', '-', 'oil', 'oil', 'applesauce']
# =========
# kosher
# ['thawed', 'raspberries', 'syrup', 'raspberry', 'raspberry', 'eggs', 'sugar', 'honey', 'candy', 'ice', 'cream', 'cream', 'walnuts', 'egg', 'raspberry', 'egg', '6-ounce', 'parfaits', 'parfaits', 'parfaits', 'chocolate', 'fresh', 'raspberries', 'parfaits']
# =========
# kosher
# ['broccoli', 'cauliflower', 'oil', '-', 'garlic', 'broccoli', 'cauliflower', 'corn', 'snow', 'peas', 'mushrooms', 'eggplant', 'vegetables', 'coconut', 'milk', 'soy', 'sauce', 'oyster', 'sauce', 'tofu', 'bok', 'choy', 'green', 'onion', 'vegetables', 'sauce', 'pepper', 'vegetables']
# =========
# kosher
# ['soy', 'milk', '-', 'pitcher', 'mirin', 'soy', 'sauce', 'nigari', 'mushrooms', 'bamboo', 'asparagus stalk', 'soy -', 'milk', 'pitcher', 'vegetables', 'mar', 'soy', 'milk', 'mitsuba', 'asparagus', 'soy', 'milk', 'pitcher', '-', 'bottomed', '-', 'diced bamboo', 'custard', 'soy', 'milk', 'soy', 'milk - drenched mitsuba', 'asparagus', 'custard', '-', 'custards', 'custards', 'custards', 'custards', 'custard', 'saucer', 'custards', 'pockmarking', 'cotton -', 'custards']
# =========
# kosher
# ['vinegar', 'salt', 'pepper', 'oil', 'dressing', 'beets', 'dressing', 'radish', 'dressing', 'mâche', 'dressing', 'mâche', 'beets', 'radish', 'salad']
# =========
# kosher
# ['butter', '/', 'meal', 'buttermilk', 'dough', 'dough', '3/4-', '-', 'biscuit', 'cookie', 'dough', 'scraps', 'biscuits', 'biscuits', 'cream', 'black pepper', 'biscuits']
# =========
# kosher
# ['rice', 'rice', 'rice', 'rice', 'rice', 'vinegar', 'sugar', 'salt', 'sugar', 'sesame seeds', 'rice', 'vinegar', 'rice', 'sesame seeds', 'vinegar', 'oil', 'ginger', 'scallions', 'carrot', 'cucumber', 'Salad', 'salad', '-', 'nori', 'green', 'nori', '-', 'avocado', 'avoado', 'avocado', 'salad', 'surmimi', 'nori', 'wasabi powder', 'soy', 'sauce', 'ginger juice', 'salad', 'nori', 'dressing']
# =========
# kosher
# ['onions', 'oil', 'tomato', 'vinegar', 'currants', 'thyme', 'parsley', 'garlic', 'sugar', 'salt', 'pepper', 'onions', 'glaze', 'onion']
# =========
# kosher
# ['dried', 'mushrooms', '-', '-', '-', 'mushrooms', 'soaked', 'mushrooms', 'ribs', 'salt', 'pepper', '6-', 'meat', 'ribs', 'broth', 'meat', 'onion', 'carrots', 'celery', 'creminis', 'oil', 'barley', 'bones', 'fat', 'gristle', 'meat', 'meat', 'broth', 'barley', 'barley', 'fat', 'dill', 'salt']
# =========
# kosher
# ['butter', 'apples', 'sugar', 'cinnamon', 'brandy', 'whites', 'apple', 'blackberries', 'soufflés', 'confectioners', "' sugar", 'soufflés']
# =========
# kosher
# ['artichokes', 'hearts', 'acidulated', 'juice', 'lemons', 'feathery', 'fennel', 'base', 'artichoke hearts', 'salad', 'salad', 'fennel', 'lemon juice', 'fennel', 'salt', 'pepper', 'artichoke hearts', 'lemon juice', 'salt', 'pepper', 'shavings', 'Parmesan', 'cheese slicer', 'vegetable', 'artichoke', 'parsley', 'cheese', 'salt', 'pepper', 'lemon juice']
# =========
# kosher
# ['cucumbers', 'onion', 'mint', 'dressing', 'salad', 'salt', 'pepper', 'peanuts']
# =========
# kosher
# ['375ºF.', '9x9-inch', 'coconut', 'oil', '-', 'plantain', 'eggs', 'salt', 'eggs', 'plantain', 'flatbread', 'poached egg(s', 'salt', 'pepper', 'honey']
# =========
# kosher
# ['onions', 'oil', '-', 'onions', 'kosher', 'salt', 'pepper', 'onions', 'crème fraîche', 'onions', 'cranberries', 'sauce', 'onions', 'salt', 'pepper', 'pomegranate seeds']
# =========
# kosher
# ['parsnips', 'carrots', 'vegetables', 'oil', 'vegetables', 'salt', 'pepper', 'vegetables', 'carrot']
# =========
# kosher
# ['horseradish', 'horseradish', 'horseradish', 'salt', 'horseradish']
# =========
# kosher
# ['butter', 'banana', 'sugar', 'banana', 'rum', 'banana', 'sugar', 'nutmeg', 'cinnamon', 'salt', 'sauce', 'banana', 'nuts']
# =========
# kosher
# ['-', 'dried', 'tomatoes', 'sugar', 'tomato', 'sauce', 'wine', 'sauce', 'tomato', 'lemon zest', 'juice', 'oregano', 'basil', 'parsley', 'red pepper', 'salt', 'peppercorns', 'garlic', 'vinegar']
# =========
# kosher
# ['Butter', '-', '-', 'batter', 'cakes', 'cakes', 'cakes', 'cake', 'cake', 'frosting', 'cake', 'frosting', 'cake', 'cake', 'frosting', 'cake', 'almonds', 'cake', 'frosting']
# =========
# kosher
# ['tofu', 'soy', 'sauce', 'sesame', 'oil', 'sugar', 'ginger', 'garlic', 'Tabasco', 'vegetable', 'oil', 'pie', 'tofu', '-', 'seasoned', 'tofu', 'marinade', 'marinade', 'tofu', 'tofu', 'vegetable', 'oil', 'greens', 'marinade', 'greens', 'greens', 'marinade', 'greens', 'tofu']
# =========
# kosher
# ['Butter', '2-', '1/2-quart', 'asparagus', '5-', '-', 'oil', 'butter', 'shallots', 'bread', 'pine', 'nuts', 'pepper', 'Parmigiano - Reggiano', 'salt', 'asparagus', 'mascarpone', 'Parmigiano - Reggiano', 'salt', 'bread - crumb', 'asparagus']
# =========
# kosher
# ['butter', 'cornmeal', 'flour', 'sugar', 'soda', 'salt', 'pepper', 'egg', 'buttermilk', 'butter', 'corn', 'batter', 'madeleines', 'madeleines', 'sour cream', 'pastry', 'caviar']
# =========
# kosher
# ['cheese', 'tomatoes', 'olives', 'garlic', 'crushed red pepper', 'cheese', 'basil', 'pasta', 'bite', 'pasta', 'pasta', 'pasta', 'cheese', 'cheese', 'sauce', 'pasta', 'pasta', 'pasta', 'salt', 'basil sprigs']
# =========
# kosher
# ['biscotti', 'almonds', 'butter', 'tartlet', 'bottoms', 'bottoms', 'cream', 'white chocolate', 'cream', 'cheese', 'white chocolate', 'cream', 'sugar', 'vanilla', '-', 'cream', 'cheese', 'filling', 'tartlet', 'strawberries', 'sugar', 'lemon juice', 'Tartlets', 'coulis', 'tartlets', 'tartlet', 'strawberry', 'coulis']
# =========
# kosher
# ['-', 'cake', '-', 'vegetable', 'oil', 'flour', 'milk', 'vanilla', 'butter', 'sugar', 'egg', 'molasses', 'milk', 'pears', 'batter', 'cake', 'cake', 'cake', 'Cake', 'whipped cream']
# =========
# kosher
# ['molasses', 'sugar', 'spices', '4-', 'soda', 'butter', 'butter', 'egg', 'flour', 'salt', 'dough', 'dusting', 'flour', 'dough', 'dough', 'cookies', 'cutters', 'cookies', 'darker', 'cookies', 'cookies', 'cookies', 'dough', 'scraps', 'pastry', 'cookies']
# =========
# kosher
# ['ricotta', 'sugar', 'coffee', 'cream', 'brandy', 'custard']
# =========
# kosher
# ['vinegar', 'honey', 'kosher', 'salt', 'pepper', 'shallot', 'oil', 'oil', 'chanterelles', '-', 'kosher', 'salt', 'pepper', 'shallot', 'pear', 'salad', 'arugula', 'vinaigrette', 'chanterelles', 'arugula', 'cheese', 'vegetable', 'salad', 'salads', 'vinaigrette']
# =========
# kosher
# ['salt', 'pepper', 'fillet', 'banana leaf', 'banana leaf', 'fillet', 'crimping']
# =========
# kosher
# ['Twist', 'portabellas', 'gills', 'portabella', 'shiitakes', 'shiitakes', 'white', 'mushrooms', 'portabella', 'shiitake', 'white', 'mushrooms', 'oil', '17-', 'barley', 'barley', 'smell', 'mushrooms', 'barley', 'onion', 'onion', 'celery', 'trimmings', 'celery', 'onion', 'celery', 'trimmings', 'mushroom', 'bay leaf', 'roasted', 'barley', 'broth', '-', 'broth', 'oil', '5-', 'onion', 'celery', 'thyme', 'vegetables', 'tomato', 'wine', 'bits', 'roasted', 'mushrooms', 'strained', 'broth', 'mushroom -', 'bits', 'mushroom', 'salt', 'pepper', 'vegetables', '-', 'salt', 'pepper']
# =========
# kosher
# ['red', 'yellow', 'bell', 'peppers', 'seeds', 'ribs', 'red', 'bell pepper', 'oil', 'pepper halves', 'bulgur', 'salt', 'bulgur', 'oil', '-', 'red pepper', 'currants', 'pine', 'nuts', 'cumin', 'spinach', 'bulgur', 'mint', 'dill', 'cheese', 'salt', 'pepper', 'bulgur', 'pepper halves', 'cheese', 'peppers', 'cracked', 'wheat']
# =========
# kosher
# ['flour', 'cinnamon', 'ginger', 'soda', 'salt', 'cloves', 'butter', 'sugar', 'egg', 'molasses', 'dough', 'butter', 'sugar', 'dough', 'sugar', 'cookies', 'dough', '1/2-', 'cookies puff', 'cookies']
# =========
# kosher
# ['cabbage', 'onions', 'bell', 'peppers', 'peas', 'yogurt', 'mayonnaise', 'capers', 'thyme', 'salt', 'pepper', 'dressing', 'peas', 'salad', 'salad', 'salad', 'salt', 'pepper']
# =========
# kosher
# ['sugar', 'Pernod', 'zest', 'sugar', 'lemon juice', 'syrup', 'cantaloupe', 'cream', 'syrup', 'ice - cream']
# =========
# kosher
# ['garlic', 'lime juice', 'miso', 'coconut nectar', 'garlic', 'oil', '-', 'green', 'beans', 'blister', '8–12', 'garlic', 'green', 'beans', 'red pepper', 'sea', 'salt', 'black pepper', 'cilantro']
# =========
# kosher
# ['salt', 'pepper']
# =========
# kosher
# ['oil', 'garlic', 'chicken', 'oregano', 'salt', 'pepper', 'broth', 'lime juice', '-', 'chicken', 'soup', 'salt', 'pepper', 'crushed', 'tortilla chips', 'soup', 'soup', 'avocados', 'tomatoes', 'green', 'onions', 'cilantro', 'jalapeños', 'lime']
# =========
# kosher
# ['lime zest', 'juice', 'butter', 'oil', 'sugar', 'salt', '1/4teaspoon pepper', 'quinoa', 'quinoa', 'salt', 'quinoa', 'quinoa', 'dressing', 'dressing', 'salt', 'pepper']
# =========
# kosher
# ['wine', 'vinegar', 'shallot', '2-', 'cream', 'salt', 'white pepper', 'butter', 'butter', 'sauce', 'hollandaise', 'salt', 'pepper', 'sauce', '-', 'sauceboat', 'shallot']
# =========
# kosher
# ['peppers', 'bell pepper', 'vinegar', 'salt', 'pepper']
# =========
# kosher
# ['flour', 'butter', 'sugar', 'salt', 'meal', 'ice', 'dough', 'dough', 'dough', 'flour', 'dough', 'pie', 'filling', 'dough', 'pie', 'tart', 'juices', 'crust', 'apples', 'pie', 'tart', 'tart', 'crème fraîche', 'butter', 'sugar', 'Calvados', 'applejack', 'zest', 'cinnamon', 'apples', 'apples', 'glazed', 'syrup', 'zest', 'cinnamon', 'lemon juice', 'syrup', 'apples', 'rich', 'filling', '11-', '1/2-quart', 'pie', 'apples']
# =========
# kosher
# ['-', 'flour', 'soda', 'powder', 'salt', 'whole -', 'wheat', 'flour', 'oats', 'buttermilk', 'egg', 'dough', 'dough', '-', 'flour', 'dough', 'dough', 'halves', 'loaves', 'loaves', 'oats', 'flour', 'loaves']
# =========
# kosher
# ['potatoes', 'potatoes', 'potatoes', 'cubes', 'cucumbers', 'onion', 'potatoes', 'salt', 'pepper']
# =========
# kosher
# ['sugar', 'ginger', 'cardamom', 'anise', '-', 'sugar', 'syrup', 'clementines', 'white pith', 'fruit', '-', 'syrup', 'pomegranate seeds']
# =========
# kosher
# ['-', 'rice', 'egg', 'yolks', 'cream', 'rice', 'chocolate', 'orange', 'cardamom', 'pudding', 'pudding', 'Dried', 'Cranberry', 'Compote']
# =========
# kosher
# ['roasted', 'peppers', 'mayonnaise', 'lemon juice', 'cumin', 'tuna', 'egg', 'cherry pepper', 'salt', 'black pepper', 'bottoms', 'onion', 'Swiss', 'cheese', 'oil', 'sandwiches', 'bread', 'cheese']
# =========
# kosher
# ['tomatoes', 'tomatoes', 'tomatoes', 'seeds', 'seeds', 'tomatoes', 'tomatoes', 'gazpacho', 'salt', 'pepper']
# =========
# kosher
# ['beets', 'balsamic', 'vinegar', 'frisée', 'oil', 'lemon juice', 'salt', 'pepper', 'goat', 'cheese', 'baguette', '-', 'sandwiches', 'toasted', 'walnuts', 'beets', 'frisée']
# =========
# kosher
# ['4-', 'eggplant', 'onion', 'bell pepper', 'garlic', 'oil', 'salt', 'pepper', 'relish', 'relish', 'flavor', 'relish', 'crackers', 'toasts']
# =========
# kosher
# ['pesto', 'pesto', '-', 'pizza', 'vegetable', 'oil', 'dough', 'dough', 'shrinks', 'pesto', 'dough', '-', 'dried', 'tomatoes', 'cheeses', 'pizza', 'crust', 'browns', 'cheeses']
# =========
# kosher
# ['honey', 'orange juice', 'zest', 'syrup', 'sweet', 'Manto', 'syrup', 'syrup']
# =========
# kosher
# ['beans', 'beans', 'beans', 'olive', 'oil', 'onion', 'thyme', 'garlic', 'green cabbage', 'tomatoes', 'celery', 'carrots', 'beans', 'stock', 'potatoes', 'basil', 'red cabbage', 'zucchini', 'vegetables', 'toasted', 'bread', 'soup', 'cheese', 'soup', 'pepper', 'olive', 'oil']
# =========
# kosher
# ['onion', 'parsley', 'oregano', 'garlic', 'salt', 'black pepper', 'red pepper', 'oil', 'vinegar', 'herbs']
# =========
# kosher
# ['mushrooms', 'parmesan', 'mozzarella', 'parsley', 'seed', 'bell', 'peppers', 'barley', 'barley', 'olive', 'oil', '-', 'oil', 'mushrooms', 'salt', 'black pepper', 'mushroom', 'mushrooms', 'mushrooms', 'barley', 'mushrooms', 'Parmesan', 'mozzarella', 'cheeses', 'parsley', 'pepper halves', 'kosher', 'salt', 'barley', 'filling', 'pepper halves', 'filling', 'peppers', 'peppers', 'bread', 'crumbs', 'bread', 'crumbs']
# =========
# kosher
# ['tortilla', 'jelly -', 'oil', 'cumin', 'salt', 'pepper', 'crisps', 'salt', 'tortilla crisps']
# =========
# kosher
# ['baguette', 'pepper', 'salt', 'baguette', 'bread', 'cheese', 'cheese']
# =========
# kosher
# ['nuts', '20–30', 'nuts', 'butter', 'raw', 'cacao', 'delicious chocolate']
# =========
# kosher
# ['oil', 'squash', 'squash', 'oil', 'onion', 'garlic', 'curry powder', 'lentils', 'broth', 'lentils', 'squash', 'pepper', 'soup', 'salt', 'freshly', 'black pepper']
# =========
# kosher
# ['jam', 'cream', 'butter', 'granulated sugar', 'egg', 'yolks', 'cinnamon', 'zest', 'salt', 'flour', 'dough', 'hazelnuts', 'chocolate', 'dough', 'tart', 'dough', 'thicker', 'jam', 'tart shell', 'dough', 'pastry', '-', 'jam', 'dough', '-', 'Linzertorte', 'Linzertorte', 'Linzertorte', 'confectioners', "' sugar", 'Linzertorte', 'whipped cream']
# =========
# kosher
# ['butter', '9x13-inch', 'butter', 'milk', 'sugar', 'dough', 'dough', 'dough', '9x13-inch', 'dough', '-', 'butter', 'seasoning', 'paprika', 'grated', 'Parmesan']
# =========
# kosher
# ['tomatoes', 'tomatoes', 'oil', 'salt', 'pepper', 'salt', 'cornmeal', '-', 'polenta', 'Parmesan', 'butter', 'cayenne pepper', 'polenta', '-', 'Sauce', 'polenta', 'eggplant', 'salt', '-', 'eggplant', 'zucchini', 'oil', 'salt', 'pepper', 'oil', 'eggplant', 'polenta', 'eggplant', 'zucchini', 'basil leaf', 'mozzarella', 'eggplant', 'cheese', 'sauce', 'eggplant', 'basil']
# =========
# kosher
# ['onion', 'vinegar', 'salt', 'oil', 'beans', 'olives']
# =========
# kosher
# ['sugar', 'cornstarch', 'eggs', '- spice powder', 'salt', 'milk', 'egg', 'custard', 'custard', 'custard', 'custard', 'litchis', 'cream', 'custard', 'cream', 'custard', 'ice - cream', 'Ice cream']
# =========
# kosher
# ['oil', 'onion', 'garlic', 'curry powder', 'flavor', 'zucchini', 'yellow', 'squash', 'potatoes', 'carrots', 'broth', 'honey', 'cinnamon', 'vegetables', 'tomatoes', 'corn', 'couscous', 'Raita', 'mint']
# =========

# %%
# False negatives
for category in ["gluten_free", "vegan", "kosher"]:
    print(category.upper())
    saved_model = "/Users/Carol/Google Drive/nlp_data/models/20200613_{}.p".format(category)
    clf = pickle.load(open(saved_model, "rb"))
    ypred_test = clf.predict(X_test)
    y_test = test[category]
    FN = np.where((ypred_test == False) & (y_test==True))[0].tolist()
    fn_title = test.title[FN]
    fn_ing = test.joined_ingredients[FN]
    for title, ing in zip(fn_title, fn_ing):
        print(category)
        print(title)
        print(ing)
        print("=========")
# Out:
# GLUTEN_FREE
# gluten_free
# Asparagus, Fingerling Potato, and Goat Cheese Pizza
# 5 ounces fingerling potatoes. Cornmeal (for sprinkling). Pizza Dough. 2 tablespoons extra-virgin olive oil, divided. 1 garlic clove, pressed. 4 green onions, thinly sliced, divided. 1 1/3 cups grated whole-milk mozzarella cheese (about 6 ounces). 4 ounces soft fresh goat cheese, crumbled. 8 ounces asparagus, trimmed, each spear cut in half lengthwise, then crosswise into 2- to 3-inch pieces. 1/2 cup grated Parmesan cheese.
# =========
# gluten_free
# Citrus Marinated Shrimp Cocktail
# 1 cup orange juice. 1 cup fresh lemon juice. 3/4 cup ketchup. 1/3 cup vodka. 1/4 teaspoon hot pepper sauce. 1/4 cup olive oil. 1 1/2 pounds cooked peeled large shrimp. 1 small red onion, thinly sliced (about 1 3/4 cups). 1 cup finely chopped fresh cilantro.
# =========
# gluten_free
# Sauteed Shrimp on Parmesan Grits with Redeye Gravy
# 6 tablespoons (3/4 stick) butter. 4 ounces ham, diced (about 1 cup). 1 1/2 cups sliced stemmed shiitake mushrooms. 1 cup finely chopped green bell pepper. 1/2 cup minced onion. 2 teaspoons minced fresh thyme. 1 cup canned low-salt chicken broth. 1/2 cup freshly brewed hot coffee. 1/2 cup seeded chopped tomatoes. 1 teaspoon hot pepper sauce. 1/4 cup Madeira. 2 teaspoons cornstarch. 1 pound large uncooked shrimp, peeled, deveined. Parmesan Grits. Freshly grated Parmesan cheese.
# =========
# gluten_free
# Beef Tenderloin Steaks with Chili Sauce
# 1 large dried ancho chili*. 1/2 dried New Mexico chili*. 1 large plum tomato. 1 cup water. 4 tablespoons olive oil. 6 garlic cloves, chopped. 1 cup (or more) chicken stock or canned low-salt chicken broth. 1 cup beef stock or canned beef broth. 2 cups dry red wine. 2 tablespoons (1/4 stick) butter. 1/2 teaspoon minced fresh rosemary. 4 6- to 7-ounce beef tenderloin steaks (about 1 inch thick).
# =========
# gluten_free
# Chicken Pasta Salad in Creamy Curry Dressing
# 1/4 pound rotelle. 1 whole skinless boneless chicken breast (about 3/4 pound), poached and cut into bite-size pieces (about 1 1/2 cups). 5 cherry tomatoes, quartered. 2 scallions, sliced thin. 1 tablespoon finely chopped fresh basil leaves. 1/2 teaspoon minced garlic. 1 teaspoon minced peeled fresh gingerroot. 1 tablespoon unsalted butter. 1/4 cup heavy cream. 1 tablespoon white-wine vinegar. 3/4 teaspoon curry powder. dried hot red pepper flakes to taste. 1 tablespoon finely chopped drained bottled mango chutney, or to taste.
# =========
# gluten_free
# Lamb Chops with Pomegranate and Dried Fig Relish
# 2/3 cup pomegranate seeds. 1/4 cup diced dried Calimyrna figs. 1 teaspoon chopped fresh mint. 1 teaspoon balsamic vinegar. 1 teaspoon pomegranate molasses. 5 teaspoons olive oil, divided. 1/2 teaspoon cumin seeds, lightly crushed, divided. 2 5-ounce lamb loin chops or shoulder blade chops.
# =========
# gluten_free
# Grilled Peaches with Black Pepper and Basil-Lime Syrup
# 1/2 cup brown sugar, plus more, for sprinkling. 1/4 cup water. 1/4 cup fresh lime juice. 1/4 cup basil leaves, plus thinly sliced basil, for garnish. Vegetable oil, for grilling. 4 large peaches, quartered and pitted. Freshly ground black pepper.
# =========
# gluten_free
# Corn, Tomato, and Lobster Salad
# 2 cups roughly chopped ripe tomatoes. 2 cups dry white wine. 1/2  cup water. 1 cup thinly sliced onions. 3 black peppercorns. 2 sprigs fresh tarragon. 1 (1 1/2-pound) lobster. 2 tablespoons minced shallot or red onions. 2 tablespoons champagne vinegar or white wine vinegar. 2 tablespoons freshly squeezed lemon juice. 1/2  teaspoon grated lemon zest. 1/3  cup plus 1/2 teaspoon extra-virgin olive oil. 1/2 teaspoon salt, plus more for seasoning. 1/8 teaspoon cayenne pepper. 1 1/4 cups Silver Queen (or other regional variety) fresh corn kernels (from about 2 ears). 1 pint mixed tiny heirloom tomatoes, such as cherry, cherub, grape, or pear, of different colors and sizes. 2 tablespoons chopped fresh tarragon leaves. 1 tablespoon chopped fresh parsley leaves. 8 Bibb lettuce leaves, rinsed and patted dry. Freshly ground black pepper.
# =========
# gluten_free
# Ambrosia
# 4 seedless navel (or blood) oranges. 2 Ruby Red grapefruit (1 lb each). 3 tbsp honey. 1 starfruit, thinly sliced. 1 cup seedless red grapes, halved. 1/2 cup champagne grapes (optional). Julienned orange zest.
# =========
# gluten_free
# Greek-Style Braised Lamb Shanks
# 3 tablespoons olive oil. 6 12- to 14-ounce lamb shanks. 2 celery stalks, chopped. 1 large onion, chopped. 1 large carrot, chopped. 6 large garlic cloves, chopped. 3 drained canned anchovies. 2 cinnamon sticks. 2 small bay leaves. 2 fresh thyme sprigs. 5 juniper berries or 2 tablespoons gin. 1/4 teaspoon ground nutmeg. 1 tablespoon tomato paste. 1 750-ml bottle Merlot. 1 14-ounce can low-salt chicken broth. 1 14-ounce can low-salt beef broth.
# =========
# gluten_free
# Eggplant Fritters
# 1 cup besan (chickpea flour)*. 2 teaspoons rice flour. 3/4 cup water. Pinch of nigella seeds (also called black onion seeds)*. 3/4 teaspoon salt. 1 (1-lb) eggplant. 1 cup canola oil.
# =========
# gluten_free
# Poached Salt Cod
# 4 lb center-cut skinless boneless salt cod, rinsed well. 3 quarts water. 1 medium onion, halved. 3 sprigs fresh thyme. 2 bay leaves. 1/2 teaspoon whole black peppercorns.
# =========
# gluten_free
# Marshmallow Frosting
# 1/2 cup agave nectar. 2 egg whites.
# =========
# gluten_free
# Mint-Truffle Ice Cream Terrine with Mint and Chocolate Sauces
# 1 1/2 cups heavy whipping cream. 16 ounces bittersweet or semisweet chocolate, chopped. 2 teaspoons pure peppermint extract. Unsweetened cocoa powder. 5 cups (2 1/2 pints) vanilla ice cream, slightly softened. 3/4 cup sugar. 1/3 cup water. 2 cups (lightly packed) fresh mint leaves.
# =========
# gluten_free
# Mixed Berries with Mascarpone-Limoncello Cream
# 3/4 cup chilled whipping cream. 1/2 8-ounce container mascarpone cheese. 3 tablespoons plus 1/2 cup sugar. 3 tablespoons limoncello (lemon liqueur). 8 cups assorted fresh berries (such as raspberries, blueberries, blackberries, and hulled sliced strawberries; about 2 pounds). 3/4 cup raspberry preserves. 1 tablespoon grated lemon peel.
# =========
# gluten_free
# Lemon-Rosemary Chicken Skewers
# 8 skinless boneless chicken breast halves (each about 7 ounces). 48 8-inch bamboo skewers, soaked in water 30 minutes, drained. 1 1-pint basket grape tomatoes or small cherry tomatoes. 1 cup olive oil. 1 cup fresh lemon juice. 6 bay leaves, broken into small pieces. 3 tablespoons chopped fresh rosemary. 4 large garlic cloves, pressed. 2 teaspoons salt. 2 teaspoons hot pepper sauce. 1 cup light mayonnaise.
# =========
# gluten_free
# Dark Chocolate-Lime Souffles
# 2/3 cup sugar. 2 tablespoons grated lime peel. 10 ounces bittersweet or semisweet chocolate, chopped. 5 large eggs, separated, room temperature. 1/8 teaspoon salt. 1/2 cup semisweet chocolate chips. 1 cup chilled whipping cream. 1 1/2 tablespoons fresh lime juice.
# =========
# gluten_free
# Lobster Salad with Green Beans, Apple, and Avocado
# 3 tablespoons coarse sea salt. 10 ounces slim haricots verts (green beans), trimmed at both ends and cut into 1/2-inch pieces (2 cups). 1 cup Greek-style yogurt. 1 tablespoon imported French mustard. 1/4 teaspoon fine sea salt. 1/4 cup minced fresh chives. 1 Granny Smith apple, cored, and cut into 1/4-inch cubes (do not peel). 1 large ripe avocado, halved, pitted, peeled, and cut into 1/4-inch cubes. 1 pound (2 cups) cooked lobster meat, cut into bite-sized pieces. Equipment: A 5-quart pasta pot fitted with a colander; 4 chilled large dinner plates.
# =========
# gluten_free
# Spoon Bread with Sour Cream and Cheese
# 1 onion. 2 garlic cloves. 1 cup yellow cornmeal. 1 1/2 teaspoons baking powder. 1 teaspoon salt. 2 cups milk. 3 large eggs. 2 tablespoons unsalted butter, softened. an 8-ounce container sour cream. 2 cups coarsely grated Cheddar (about 4 ounces).
# =========
# gluten_free
# Sweet Chocolate Glaze
# 3 ounces semisweet or bittersweet chocolate, chopped. 3 tablespoons orange juice or water. 3 tablespoons unsalted margarine or (if not keeping glaze pareve) butter. 3 tablespoons sugar.
# =========
# gluten_free
# Grilled Leg of Lamb with Red Wine, Garlic, Mustard and Sage
# 1 cup dry red wine (such as Zinfandel). 3/4 cup chopped shallots (about 3 large). 1/2 cup whole grain Dijon mustard. 1/3 cup plus 1 tablespoon finely chopped fresh sage (about 1/2 ounce) plus sprigs for garnish (optional). 1/4 cup olive oil. 3 garlic cloves, pressed. 1 7-pound leg of lamb, boned, evenly flattened, outside fat partially trimmed (yields about 5 2/3 pounds). 1 cup low-salt beef broth. 2 tablespoons (1/4 stick) chilled unsalted butter, cut into 1/2-inch cubes. Special equipment: 1 2-gallon resealable plastic bag.
# =========
# gluten_free
# Braised Veal Breast with Bulb Vegetables
# 3-pound veal breast. Coarse salt and white pepper, to taste. 2 tablespoons corn oil. 2 large shallots, peeled. 1 onion, quartered. 1 leek, split and cleaned. 12 cloves of garlic, unpeeled. 2 bay leaves. 1/3 cup diced celery root. 4 whole cloves. 1/2 teaspoon white peppercorns. 1/2 teaspoon ground cumin. 1/2 cabbage, quartered. 2 cups dry white wine. 1 1/3 cups apple cider. 1/3 cup snipped chives.
# =========
# gluten_free
# Grilled Chicken Moroccan Style
# 1 cup olive oil. 1/4 cup red wine vinegar. 3 tablespoons ground cumin. 1 1/2 tablespoons ground coriander. 2 teaspoons ground cinnamon. 2 teaspoons salt. 2 teaspoons sugar. 1/4 teaspoon cayenne pepper. 4 large chicken breast halves with skin and ribs, cut crosswise in half. 4 chicken legs. 4 chicken thighs. 1/4 cup minced fresh parsley.
# =========
# gluten_free
# Peanut Butter Chocolate Eggs
# 10 1/2 ounces bittersweet chocolate, tempered. 5 ounces bittersweet chocolate, chopped. Generous 2 cups (about 18 ounces) smooth peanut butter.
# =========
# gluten_free
# Coriander and Cumin Flatbread
# 1 3/4 cups (or more) all purpose flour. 1 1/2 teaspoons coarse kosher salt. 3/4 cup lukewarm water (95°F to 100°F). 1 1/2 teaspoons sugar. 1 1/2 teaspoons active dry yeast. 3 tablespoons (about) extra-virgin olive oil, divided. 1 teaspoon cumin seeds. 1 teaspoon coriander seeds. 1 tablespoon chopped fresh Italian parsley.
# =========
# gluten_free
# Mustard Aspic
# 1 envelope (about 1 tablespoon) of unflavored gelatin. 1 cup cold water. 3/4 cup white-wine vinegar. 1/4 cup sugar. 3 tablespoons English-style dry mustard. 2 tablespoons mustard seeds. 4 large eggs, beaten lightly. 1 teaspoon sweet paprika. 1 cup well-chilled heavy cream. 1/3 cup minced fresh parsley leaves.
# =========
# gluten_free
# Cherry-Almond Focaccia
# Master Sweet Dough. 3 tablespoons extra-virgin olive oil, divided. 2 cups drained pitted tart cherries in light syrup (such as Morello) plus 1 cup syrup (from a 24-28-oz. jar). 3 tablespoons granulated sugar. 3/4 cup sliced almonds (with or without skins). 1/3 cup raw sugar. Ingredient info: Tart cherries in light syrup can be found at some supermarkets and at Middle Eastern markets and sahadis.com..
# =========
# gluten_free
# Green Salad with Miso-Ginger
# 1 tablespoon unseasoned rice vinegar. 1 tablespoon white miso. 2 teaspoons grated peeled fresh ginger. 1 garlic clove, minced. 1/2 teaspoon sugar. 3 tablespoons vegetable oil. 1 5-ounce bag mixed greens. 1/2 English hothouse cucumber, halved lengthwise, seeded, thinly sliced crosswise. 1 large carrot, peeled, coarsely grated. 1 large green onion, sliced on diagonal.
# =========
# gluten_free
# Orange and Endive Salad with Maple Chipotle Vinaigrette
# 1/4 cup fresh orange juice. 2 tablespoons dark amber or Grade B maple syrup. 2 tablespoons extra-virgin olive oil. 1 tablespoon Sherry vinegar. 1 tablespoon finely chopped red onion. 1 teaspoon fresh lemon juice. 1 teaspoon chopped canned chipotle chile in adobo plus 1 teaspoon adobo sauce. 1/2 teaspoon salt. 3 navel oranges. 4 large Belgian endives, ends trimmed.
# =========
# gluten_free
# Squid and Pork Noodle Salad
# 1 pound buckwheat noodles. 2 teaspoons canola oil. 3 cloves garlic, finely chopped. 1/2 pound ground pork. 1 teaspoon salt. 3/4 pound fresh squid, cut into bite-size pieces. 3-6 red Thai bird chiles, finely chopped (found in grocery stores' Asian section). 3 cloves garlic, finely chopped. 1 cup lime juice (from 4 to 5 limes). 1/4 cup plus 1 tablespoon fish sauce. 1/4 cup plus 1 tablespoon sugar. 1 cucumber, seeded and sliced. 1 cup grape tomatoes, halved. 1 cup mixed fresh mint and cilantro. 1/2 cup finely chopped celery hearts. 1/2 cup thinly sliced red onion. 1/4 cup crushed peanuts.
# =========
# gluten_free
# White Bean Salad
# 1 cup dried small white beans, such as cannellini or Great Northern, or 1 15-ounce can. 1 clove garlic. 1 bay leaf. 1/4 cup extra-virgin olive oil. 1/2 teaspoon grated lemon zest. 1 tablespoon lemon juice. 1/2 teaspoon honey. 1 tablespoon chopped shallot. 1 cup snow peas or sugar snap peas. 1/2 bunch fresh chives, chopped. 5 mild radishes, such as Lady Slipper radishes, thinly sliced. 3 tablespoons chopped fresh basil.
# =========
# gluten_free
# Pork Tostadas with Corn Salsa
# 2 pounds boneless pork shoulder, cut into 2-inch pieces. 2 yellow or white onions. 3 tablespoons distilled white vinegar. 2 garlic cloves, minced. 3 tablespoons vegetable oil plus additional for frying the tortillas. 3 ears of corn. 2 tomatoes, chopped fine. 1/2 cup finely chopped red onion. 1 to 2 fresh jalapeño chilies including the seeds, or to taste, minced (wear rubber gloves). 1/2 cup loosely packed fresh coriander, chopped fine. 4 tablespoons fresh lime juice. 2 avocados (preferably California). eight 7-inch corn tortillas.
# =========
# gluten_free
# Grilled-Fish Tacos
# 1 medium red onion. 1/2 cup cider vinegar. 1/4 cup sugar. 7 tablespoons fresh lime juice, divided. 1/4 cup chopped cilantro. 1 tablespoon olive oil. 1 1/4 pound (1-inch-thick) skinless mahimahi fillet or tuna steak, cut into 12 pieces. 2/3 cup mayonnaise. 2/3 cup crema or sour cream. 12 (6-inch) corn tortillas. 6 to 8 radishes. 1 to 2 (6- to 8-ounce) firm-ripe avocados. 4 cups thinly sliced green cabbage (1/2 small head). Equipment: an adjustable-blade slicer; 12 (6- to 8-inch) wooden skewers, soaked in water 30 minutes. Accompaniment: lime wedges.
# =========
# gluten_free
# Apricot and Chocolate Bavarois
# 1 3/4 lb firm-ripe apricots (9 large), chopped. 1/2 cup dried apricots, chopped. 1 cup sugar. 3 teaspoons unflavored gelatin (from two 1/4-oz envelopes). 2 cups whole milk. 5 large egg yolks. 1/2 cup sugar. 1 cup chilled heavy cream. 1/8 teaspoon salt. 2 teaspoons fresh lemon juice. 4 oz fine-quality bittersweet chocolate (not unsweetened), finely chopped. 3 large eggs, separated. 5 tablespoons sugar. 1/4 teaspoon salt.
# =========
# gluten_free
# Pork Loin Stuffed with Fuji Apples
# 1/4 cup golden raisins. 3/4 cup Riesling (or Gewürztraminer). 1 1/2 Fuji apples, peeled, cored and cut into 1/2-inch cubes, peel and core reserved. Pinch of cinnamon. 2 lb center-cut boneless pork loin (ask butcher to make a 1-inch incision in the center all the way through). Sea salt. Vegetable-oil cooking spray. 1 medium onion, diced large. 1 carrot, diced large. 1 celery stalk, diced large. 4 stems fresh rosemary. 1/2 cup balsamic vinegar.
# =========
# gluten_free
# BBQ Beef Brisket
# 1 (12-pound) whole beef brisket. 2 cups BBQ Beef Coffee Cure. 2 cups ketchup. 2 cups diced tomatoes. 1 tablespoon tomato paste. 1 1/3 cups distilled white vinegar. 5 tablespoons Dijon mustard. 4 teaspoons granulated garlic. 4 teaspoons kosher salt. 2 teaspoons black peppercorns, crushed. 1/2 pound brown sugar. 2/3 cups molasses.
# =========
# gluten_free
# Red Snapper with Black Olives, Capers, and Tomatoes
# 25 black, salt-cured olives such as Gaeta or Kalamata, rinsed, pitted, and roughly chopped. 2 1/2 teaspoons bottled capers, rinsed. 2 tablespoons plus 1 1/2 teaspoons red onion, finely diced. 8 ripe plum tomatoes, cut into medium dice. 10 large basil leaves, roughly chopped. 1/2 cup plus 3 tablespoons fresh Italian flat-leaf parsley, roughly chopped. 1/2 cup extra-virgin olive oil. 1 tablespoon plus 2 teaspoons kosher salt. 1 1/2 teaspoons freshly ground black pepper plus more to taste. 1 teaspoon red pepper flakes. 10 (6-ounce) red snapper fillets, skin on. 1 cup canola oil. 6 tablespoons fresh lemon juice (from 2 lemons).
# =========
# gluten_free
# Vanilla Frosting/Vanilla Sauce
# 1 ½ cups unsweetened soy milk. ¾ cup dry soy milk powder. 1 tablespoon coconut flour. ¼ cup agave nectar. 1 tablespoon pure vanilla extract. 1 ½ cups coconut oil. 2 tablespoons fresh lemon juice.
# =========
# gluten_free
# Hazelnut Meringue Kisses
# 3 large egg whites. 1/4 teaspoon cream of tartar. 1/4 teaspoon salt. 3/4 cup sugar. 1/2 teaspoon vanilla extract. 1/2 teaspoon instant espresso powder. 1/2 teaspoon unsweetened cocoa powder (not Dutch-process). 3/4 cup hazelnuts (about 3 1/2 ounces), toasted lightly and skinned and ground fine. 42 whole hazelnuts,toasted lightly and skinned. 6 ounces fine-quality bittersweet chocolate (not unsweetened), chopped.
# =========
# gluten_free
# Guacamole Tacos with Tomatillo and Steak Sauce
# 12 guajillo chiles* (about 2 ounces), wiped clean, seeded, deveined. 4 dried chiles de árbol*. 1 pound tomatillos (about 10), husked, rinsed. 4 cups water (or more), divided. 2 garlic cloves, peeled. 1/4 teaspoon (generous) aniseed. 1/4 teaspoon (generous) dried oregano (preferably Mexican). 2 tablespoons olive oil. 1 pound skirt steak, cut into 1/3-inch cubes. 3 large avocados, halved, pitted. 1/2 cup (packed) finely chopped fresh cilantro. 1/4 cup finely chopped white onion. 1 teaspoon salt. 1/4 cup vegetable oil. 12 corn tortillas. *Available at some supermarkets and specialty foods stores and at Latin markets..
# =========
# gluten_free
# Arugula Salad with Roasted Eggplant and Sweet Pomegranate Dressing
# 2 medium eggplants. 1/4 cup peanut and olive oil, combined. Sea salt. 2 tsp whole fennel seeds. 1 clove garlic. 1/4 cup balsamic vinegar. 1/4 cup honey. Juice of 1 lemon. 1 Tbsp Dijon mustard. 1/4 cup pomegranate molasses. 1/4 cup extra virgin olive oil. 4 large handfuls arugula leaves. 1 small red onion, thinly sliced. 2 cups cherry tomatoes, sliced. Salt and pepper. 1/2 cup toasted pine nuts. 1/2 cup fresh pomegranate seeds.
# =========
# gluten_free
# Turkey Chili with White Beans
# 1 tablespoon vegetable oil. 2 medium onions, chopped. 1 1/2 teaspoons dried oregano. 1 1/2 teaspoons ground cumin. 1 1/2 pounds lean ground turkey. 1/4 cup chili powder. 2 bay leaves. 1 tablespoon unsweetened cocoa powder. 1 1/2 teaspoons salt. 1/4 teaspoon ground cinnamon. 1 28-ounce can whole tomatoes. 3 cups beef stock or canned beef broth. 1 8-ounce can tomato sauce. 3 15-ounce cans small white beans, rinsed, drained. Chopped red onion. Chopped fresh cilantro. Plain low-fat yogurt or light sour cream.
# =========
# gluten_free
# White Fish Terrine with Salmon Roe and Dill
# 1 1/4 lb skinless cod, scrod, or gray sole fillets, well chilled. 2 teaspoons kosher salt or 1 teaspoon table salt. 1/4 teaspoon white pepper. 1/4 teaspoon freshly grated nutmeg. 1 large egg white. 2 cups chilled heavy cream. 2 tablespoons minced fresh dill. 3 tablespoons salmon roe. Special equipment: a 4-cup terrine mold or loaf pan; a tamis (drum sieve) with 30 to 40 holes per square centimeter*; a slightly flexible bowl scraper; a kitchen scale; an offset spatula; an instant-read thermometer. Accompaniment:beurre blanc.
# =========
# gluten_free
# Roasted Tomato and Red Bell Pepper Soup
# 2 1/4 pounds tomatoes, halved lengthwise. 2 large red bell peppers, quartered, seeded. 1 onion, cut into thin wedges. 4 large garlic cloves, peeled. 2 tablespoons olive oil (preferably extra-virgin). 1 teaspoon fresh thyme leaves or 1/2 teaspoon dried. 2 cups (about) water. 4 tablespoons part-skim ricotta cheese, room temperature. Fresh thyme sprigs (optional).
# =========
# gluten_free
# Smoked-Turkey, Plum, and Fennel Salad
# 1/3 cup balsamic vinegar. 1 tablespoon packed light brown sugar. 1/4 cup extra-virgin olive oil. 1 (1-pound) smoked turkey drumstick. 1 large fennel bulb, stalks discarded. 1/2 head radicchio. 1/2 pound firm-ripe black or red plums (2 to 3), thinly sliced. 3 ounces pecans, toasted and cooled. An adjustable-blade slicer.
# =========
# gluten_free
# Poached Shrimp with Lemon-Horseradish Dipping Sauce
# 1 cup dry white wine. 6 whole black peppercorns. 1/2 lemon. 1 Turkish bay leaf. Pinch of coarse kosher salt. 8 uncooked unpeeled large shrimp. 1/4 cup crème fraîche or sour cream. 1 tablespoon chopped fresh chives. 1 teaspoon prepared white horseradish. 1/2 teaspoon finely grated lemon peel. Coarse kosher salt. Whole fresh chives (for garnish).
# =========
# gluten_free
# Marbled Mint-Chocolate Pudding
# 4 ounces white chocolate, chopped. 1/4 teaspoons mint extract. 1 cup heavy cream. 1/4 teaspoons kosher salt. 2 large egg yolks. 4 ounces bittersweet or semisweet chocolate, chopped. 1/2 cup heavy cream. 1/2 cup whole milk. 2 tablespoons sugar. 1/4 teaspoons kosher salt. 2 large egg yolks. Chocolate cookies, broken into large pieces (for serving).
# =========
# gluten_free
# Spiced Apple-Cider Granita with Ginger Whipped Cream
# 4 cups apple cider. 2/3 cup (packed) golden brown sugar. 20 whole allspice. 10 whole cloves. Ginger Whipped Cream.
# =========
# gluten_free
# Green Beans
# 1 1/4 pounds green beans, trimmed. as an accompaniment. 1/2 cup Dijon mustard. 2 tablespoons sugar. 1/4 cup white-wine vinegar. 2/3 cup vegetable oil. 3 to 4 tablespoons water.
# =========
# gluten_free
# Coriander Pork Tenderloin with Carrot-Ginger Sauce
# 1 pound carrots, peeled, cut into 1-inch pieces. 1/3 cup whipping cream. 1 tablespoon finely grated peeled fresh ginger. 1/4 cup whole coriander seeds. 3 pork tenderloins (about 3 pounds total), trimmed. 2 tablespoons olive oil.
# =========
# gluten_free
# Winter Fruit Compote with Ginger
# 2 to 2 1/2 cups dried cranberries (available at specialty foods shops and some supermarkets). 2 cups fresh orange juice. a 10 1/2-ounce jar preserved ginger in syrup. 3 cups seedless green grapes, halved. 3 large pink grapefruit, the rind and pith cut away with a serrated knife and the flesh sectioned. 1/2 pineapple, peeled, cored, and cut into 1/2-inch pieces. 1 large navel orange, the rind and pith cut away with a serrated knife and the flesh sectioned..
# =========
# gluten_free
# Lamb Chops with Dried Cherries and Port
# 2 teaspoons olive oil. 4 4-to 5-ounce loin lamb chops. 1/3 cup chopped shallots. 3/4 cup ruby Port. 1/2 cup low-salt chicken broth. 1/2 cup dried tart cherries. 3 tablespoons cherry jam. 1 tablespoon balsamic vinegar. 1/2 teaspoon ground cardamom. Chopped fresh mint or parsley.
# =========
# gluten_free
# Fennel, Grapefruit, and Prosciutto Salad
# 2 tablespoons pine nuts. 1 tablespoon extra-virgin olive oil. 1 tablespoon white-wine vinegar. 1/2 teaspoon Dijon mustard. 1 small grapefruit (preferably pink). 1/2 fennel bulb (sometimes called anise). 1 small head radicchio. 1/4 pound thinly sliced prosciutto.
# =========
# gluten_free
# Curry-Spiced Citrus and Avocado Salsa
# 2 large oranges. 1 large red grapefruit. 1 tablespoon curry powder. 1 avocado, peeled, seeded, diced. 1/2 cup chopped red onion. 2 tablespoons chopped fresh chives or green onions. 1 tablespoon avocado oil or vegetable oil. Ground white pepper.
# =========
# gluten_free
# Curried Chicken Salad with Spiced Chickpeas and Raita
# 1 medium onion, chopped (1 cup). 1 tablespoon minced garlic. 1 tablespoon minced peeled ginger. 2 tablespoons vegetable oil. 1 tablespoon curry powder. 1 teaspoon ground cumin. 2 medium tomatoes, chopped (1 cup). 1 cup plain yogurt. 2 tablespoons cilantro. 1 rotisserie chicken, meat coarsely shredded (3 to 4 cups). 1 cup red grapes, halved. 1 tablespoon vegetable oil. 1 (19-ounce) can chickpeas, rinsed, drained, and patted dry (2 cups). 1 teaspoon ground cumin. 1/2 teaspoon turmeric. 1/4 teaspoon cayenne. 1 cup plain yogurt. 1 seedless cucumber, peeled, cored, and chopped (2 cups). 2 tablespoons chopped mint. 1/2 cup sliced almonds, toasted. 4 (16-ounce) wide jars or containers with lids.
# =========
# gluten_free
# Salmon with Parsley Cream Sauce
# 1 cup dry white wine. 3 tablespoons bottled clam juice. 3 large garlic cloves, minced. 2 large shallots, minced. 1 cup whipping cream. 1/2 cup plus 3 tablespoons chopped parsley. 1 1 1/2-pound salmon fillet (about 3/4 to 1 inch thick). Olive oil. 1 tablespoon minced fresh tarragon or 1 teaspoon dried. 1 tablespoon minced chives or green onion. Parsley sprigs.
# =========
# gluten_free
# Coconut Tamales
# 15 dried corn husks (2 oz, or 1/4 package). 2 cups masa harina for tamales (see Tips, below). 1/4 cup sugar. 1/4 vanilla bean, or 3/4 teaspoon pure nonalcoholic vanilla flavoring (see Tips, below) or vanilla extract. 1 cup unsweetened shredded coconut. 1/3 cup vegetable shortening or butter, softened. 1/4 teaspoon baking powder (optional, see Tips, below). 1/3 cup raisins.
# =========
# gluten_free
# Yemenite High Holy Day Soup
# 3 celery stalks, cut into 2-inch pieces. 1 medium zucchini, peeled and cubed. 3 carrots, cut into 3-inch pieces. 1 large tomato, almost quartered but not cut apart at bottom. 3 potatoes, peeled and diced, kept in cold water. 3 pounds beef shoulder, ribs, or stew meat (fat removed). 3 pieces (about 2 pounds) marrow bones. 1 3-pound chicken, cleaned and quartered. Up to 5 quarts water. 10-12 cloves garlic, unpeeled. 9 small white onions. 1 large white turnip, quartered but unpeeled. 4 leeks or 8 green onions, coarsely cut. 1 small bunch fresh parsley or fresh coriander, woody stems trimmed away. Salt to taste. 1 tablespoon hawayij (Yemenite spices), or to taste. Storage cups for refrigerating. Covered soup kettle. Large slotted spoon.
# =========
# gluten_free
# Chocolate-Almond Soufflé Torte
# 1 cup (about 5 ounces) whole almonds, toasted, cooled. 4 tablespoons plus 1/3 cup sugar. 2 tablespoons vegetable oil. 3/4 cup (1 1/2 sticks) unsalted butter. 1/2 cup whipping cream. 1 pound bittersweet (not unsweetened) or semisweet chocolate, finely chopped. 6 large eggs, separated, room temperature. 1 cup chilled whipping cream. 2 tablespoons amaretto or 1 teaspoon almond extract. Powdered sugar. 1/2 cup almond slices, toasted.
# =========
# gluten_free
# Veal Scallops with Parsley, Lemon and Garlic
# 3 tablespoons minced fresh parsley. 1 1/2 teaspoons grated lemon peel. 1 large garlic clove, minced. 1 1/2 tablespoons butter. 1/2 pound veal scallops (about 2 large). 1/3 cup dry vermouth.
# =========
# gluten_free
# Sea Bass with Citrus-Olive-Caper Sauce
# 8 sea bass fillets (about 5 ounces each), skin on. 3 tablespoons olive oil, divided. 1 teaspoon salt, divided. 1/2 teaspoon freshly ground black pepper, divided. 2 lemons, peeled and thinly sliced, segments halved. Juice of 2 lemons. 2 tablespoons chopped fresh oregano. 2 tablespoons capers, rinsed. 3/4 cup pitted Kalamata olives, roughly chopped.
# =========
# gluten_free
# Flan with Pink Grapefruit and Mint Syrup
# 4 large pink grapefruit. 2 cups sugar. 1 cup (packed) mint leaves. 3/4 cup whole milk. 3/4 cup half and half. 4 large eggs. 1 teaspoon vanilla extract. Pinch of salt.
# =========
# gluten_free
# Braised Baby Onions with Orange Juice and Balsamic Vinegar
# 2 pounds fresh small cipolline onions or pearl onions. 1/4 cup extra-virgin olive oil. 3/4 cup fresh orange juice. 3/4 cup balsamic vinegar.
# =========
# gluten_free
# Black-Pepper Beef Ribs
# 2 tablespoons cracked black pepper. 1 tablespoon packed dark brown sugar. 1 tablespoon kosher salt. 1 teaspoon paprika. 2 racks beef back ribs (not short ribs; 5 to 6 pounds).
# =========
# gluten_free
# Pear, Chocolate, and Hazelnut Crostata
# Easy Tart Crust. 1 large egg. 2 tablespoons whipping cream. 4 large firm but ripe Bosc pears, peeled, quartered, cored, each quarter cut lengthwise into 3 slices. 3 tablespoons chopped husked toasted hazelnuts. 2 tablespoons coarsely chopped imported milk chocolate. 2 tablespoons coarsely chopped bittersweet (not unsweetened) or semisweet chocolate. 6 tablespoons raw sugar, divided. 1/4 teaspoon coarse sea salt (optional).
# =========
# gluten_free
# Grapefruit with Campari Syrup
# 3 large pink or ruby red grapefruit (4 pounds total), chilled. 2 tablespoons sugar, or to taste. 2 tablespoons Campari, or to taste.
# =========
# gluten_free
# Lemon Cream Cheese Icing
# 3/4 cup powdered sugar. 1 3-ounce package cream cheese. 1 tablespoon fresh lemon juice. 1 teaspoon finely grated lemon peel. 1 teaspoon vanilla extract. 1/4 cup (or more) whipping cream.
# =========
# gluten_free
# Baby Zucchini and Patty Pan Squash Sauteed in Herb Butter
# 3 tablespoons unsalted butter. 2 cups (about 1 pound) baby zucchini, stems removed and cut in half lengthwise. 2 cups (about 3/4 pound) small yellow patty pan squash, trimmed and cut in half crosswise. 1 teaspoon sea salt. 1/2 teaspoon freshly ground black pepper. 3/4 cup (about 16 leaves) fresh basil, torn and loosely packed. 1/2 cup (about 32 leaves) fresh mint, loosely packed.
# =========
# gluten_free
# Yellow Salad with Citrus-Date Vinaigrette
# 2 Medjool dates, pitted. 1/4 cup olive oil. 2 tablespoons fresh lemon juice. 2 tablespoons fresh orange juice. 1 tablespoon whole grain Dijon mustard. 1/2 teaspoon ground cumin. Kosher salt, freshly ground pepper. Mixed yellow and orange raw fruits and vegetables (such as corn, Sun Gold tomatoes, golden beets, apricots, clementines, and pineapple), halved, sliced, and/or cut into wedges.
# =========
# gluten_free
# Gluten-Free Shells with Beets, Ricotta, and Pistachios
# 1/3 cup raw pistachios. 1 teaspoon plus 5 tablespoons olive oil; plus more for drizzling. Kosher salt, freshly ground pepper. 1 cup ricotta. 2 pounds small golden beets, scrubbed. 1 large shallot, finely chopped. 3 tablespoons Champagne vinegar. 12 ounces gluten-free shells or other short pasta. 1 tablespoon finely chopped fresh chives. Flaky sea salt.
# =========
# gluten_free
# Grilled Steak and Onions with Rosemary-Balsamic Butter Sauce
# 8 tablespoons (1 stick) chilled unsalted butter, divided. 1 large shallot, minced. 1/2 cup balsamic vinegar. 2 large fresh rosemary sprigs. 2 pounds mixed sweet onions, large shallots, baby leeks, and green onions. 2 tablespoons olive oil. 4 (1 1/4-inch-thick) New York strip steaks (each about 6 ounces). 2 tablespoons orange juice.
# =========
# gluten_free
# Spiced Sweet Potato Gratin
# 4 pounds red-skinned sweet potatoes (yams; about 3 1/4 pounds). 1 tablespoon curry powder. 1 tablespoon ground cumin. 3/4 teaspoon ground cinnamon. 3/4 teaspoon ground ginger. 1/2 teaspoon (scant) salt. 1 1/2 cups sour cream, divided. 3 cups shredded extra-sharp white cheddar (about 12 ounces).
# =========
# gluten_free
# Mango and Coconut Rice Salad
# 2/3 cup jasmine or basmati rice. 1 tsp unsalted butter. Salt. 1/2 cup water. 1 cup loosely packed Thai basil. 1 cup Camargue red rice. 1 red bell pepper, thinly sliced. 2 tbsp mint leaves, roughly chopped. 2/3 cup cilantro leaves, roughly chopped. 2 green onions, thinly sliced. 1 fresh red chile, seeded and finely chopped. Grated zest and juice of 1 lemon. 1 large mango or 2 smaller ones, cut roughly into 1-inch dice. 1/2 cup roasted salted peanuts, roughly chopped. 2/3 cup flaked coconut. 2 tbsp peanut oil. 3/4 cup crisp-fried shallots (homemade or bought, optional).
# =========
# gluten_free
# Gluten-Free Orange Almond Coconut Muffins
# 1 cup (177 g/6.25 oz) brown rice flour. 2/3 cup (58 g/2 oz) almond flour. 1/2 cup (70 g/2.46 oz) arrowroot. 1/3 cup (56 g/2 oz) Sucanat. 2 teaspoons (10 g/0.34 oz) baking powder. 1/2 teaspoon (1.5 g/0.05 oz) kosher salt. 1/3 cup (100 g/3.5 oz) maple syrup. 1/2 cup (121 g/4.3 oz) orange juice. Finely grated zest of 1 orange. 1 1/2 teaspoons (6 g/0.21 oz) vanilla extract. 1/2 cup (42 g/1.5 oz) chopped almonds. 1/4 cup (21 g/0.75 oz) unsweetened shredded coconut.
# =========
# gluten_free
# Curried Meatballs
# Olive oil. 6 scallions, cut into 1-inch pieces. 2 jalapeños, seeds removed if desired. 6 garlic cloves. 1 (1-inch) piece ginger, peeled, chopped. 1 tablespoon fresh lemon juice. 1 tablespoon garam masala. 1 teaspoon ground coriander. 1/2 teaspoon ground cumin. 1/2 teaspoon cayenne pepper. 2 pounds ground beef (20% fat). 1 large egg, beaten to blend. 3 tablespoons plain yogurt. 2 teaspoons kosher salt. 1/4 cup olive oil. 4 medium onions, chopped. 10 garlic cloves, crushed. 1 (1 1/2-inch) piece ginger, peeled, chopped. 3 dried chiles de árbol. 4 teaspoons curry powder. 4 teaspoons ground cumin. 4 teaspoons ground turmeric. 3 tablespoons ground coriander. 1 teaspoon black peppercorns. 1 (14.5-ounce can) crushed tomatoes. 1 bay leaf. 1 tablespoon kosher salt, plus more. 1 tablespoon fresh lemon juice. 1/2 teaspoon cayenne pepper. Cilantro leaves with tender stems (for serving).
# =========
# gluten_free
# Celery Root and Apple Salad with Hazelnut Vinaigrette
# 2 tablespoons Dijon mustard. 2 tablespoons white wine vinegar. 1 tablespoon fresh lemon juice. 1/2 teaspoon salt. 1/2 small garlic clove, pressed. 1/4 cup hazelnut oil plus additional for drizzling (optional). 2 tablespoons olive oil. 1 medium celery root, peeled, cut into matchstick-size strips. 1 medium fennel bulb, halved lengthwise, thinly sliced. 1 unpeeled Gala apple, cut into strips. Parmesan cheese shavings.
# =========
# gluten_free
# Grilled Shrimp with Fiery Lemongrass-Chile Sambal
# 6 (or more) Thai bird chiles or 2 (or more) serrano or jalapeño chiles (preferably red), seeded, coarsely chopped. 1 1/2 cups coarsely chopped shallots (about 8 ounces). 1/4 cup chopped peeled fresh ginger. 3 tablespoons chopped lemongrass (from bottom 4 inches of 2 large stalks). 6 macadamia nuts. 4 garlic cloves, coarsely chopped. 2 teaspoons (packed) golden brown sugar. 2 teaspoons turmeric. 1 1/2 teaspoons salt. 1 teaspoon ground coriander. 1 teaspoon paprika. 1 bay leaf, crumbled. 1/2 teaspoon freshly ground black pepper. 2 tablespoons (or more) vegetable oil. 1 cup water. 2 tablespoons fresh lime juice. 3 tablespoons (or more) vegetable oil. 3 pounds uncooked unpeeled large shrimp, or 2 1/2 pounds uncooked peeled large shrimp, deveined, tails left intact.
# =========
# gluten_free
# Watermelon With Yogurt, Poppy Seeds, and Fried Rosemary
# 2 tablespoons olive oil. 1 (6-inch) rosemary sprig. 1/2 cup plain whole-milk Greek yogurt. 1 tablespoon honey. Kosher salt. 1 (3-pound) seedless watermelon, rind removed, cut into 2-inch pieces. 3 tablespoons fresh grapefruit juice. Flaky sea salt. 1 teaspoon crushed red pepper flakes. 1 teaspoon poppy seeds.
# =========
# gluten_free
# Pink Greyhound
# 1/3 cup pink grapefruit juice. 1/3 cup vodka. 1 teaspoon grenadine. Pink-grapefruit twist for garnish.
# =========
# gluten_free
# Feta with Rosemary Pepper Honey
# 1/2 cup honey. 1/4 cup water. 2 teaspoons chopped fresh rosemary leaves. 1 teaspoon black peppercorns, cracked coarse. 1 pound feta cheese, rinsed and patted dry.
# =========
# gluten_free
# Grilled Tuna with Provençal Vegetables and Easy Aioli
# Nonstick vegetable oil spray. 4 5-ounce albacore tuna steaks (from the U.S. or Canada; about 1 inch thick). 2 zucchini, quartered lengthwise. 1 eggplant (about 1 pound), cut lengthwise into 3/4-inch-thick slices. 4 tablespoons (about) olive oil. 2 cups assorted cherry tomatoes, halved. 2 teaspoons herbes de Provence*. 1 garlic clove, minced. Easy Aioli.
# =========
# gluten_free
# Grilled Tandoori Lamb
# In dry skillet, toast until aromatic:. 2 tablespoons cumin seeds. 2 teaspoons fennel seeds. 2 teaspoons cardamom seeds. 1/2 teaspoon whole black peppercorns. Grind cooled spices in spice mill with:. 1 1/2 teaspoons dried crushed red pepper. Transfer spice blend to small bowl and mix in:. 6 tablespoons olive oil. 2 tablespoons minced fresh ginger. 4 garlic cloves, pressed. Rub mixture all over, then cover and refrigerate 3 hours:. 1 5 3/4-pound leg of lamb, boned and butterflied (about 4 pounds boned).
# =========
# gluten_free
# Lobster Gelees with Fresh Tarragon Oil
# 8 quarts water. 4 (1 1/4-lb) live lobsters. 1 cup dry white wine. 3 carrots, chopped. 2 celery ribs, chopped. 1 fennel bulb (sometimes labeled "anise") with fronds, stalks, and bulb chopped and fronds reserved for fresh tarragon oil. 1 medium onion, finely chopped. 3 large garlic cloves, minced. 3 (6-inch) plus 8 (1-inch) sprigs fresh tarragon. 1 teaspoon salt. 1/4 teaspoon fennel seeds, slightly crushed. 1/4 teaspoon dried hot red-pepper flakes. 2 1/2 teaspoons unflavored gelatin (from two 1/4-oz envelopes). 1 1/2 teaspoons tarragon white-wine vinegar. 1/3 cup fresh tarragon oil. Special equipment: a 10- to 12-qt pot; heavy-duty (sometimes labeled "fine") cheesecloth; 8 (5- to 6-oz) baba au rhum molds or ramekins. Accompaniment: lobster claw toasts.
# =========
# gluten_free
# Citrus Icing
# 1/2 cup fresh orange juice, strained. 1 teaspoon fresh lemon juice, strained. 1 (1-pound) box confectioners sugar. 4 teaspoons powdered egg whites (not reconstituted) such as Just Whites.
# =========
# gluten_free
# Minted Lamb Patties
# 10 to 12 ounces ground lamb. 1 green onion, finely chopped. 2 tablespoons minced fresh mint. 1 garlic clove, pressed. 3 teaspoons chutney, such as Major Grey's.
# =========
# gluten_free
# Roasted Quail with Red Grapes and Pearl Onions
# 1 cup balsamic vinegar. 2 tablespoons honey. 10 fresh thyme sprigs plus 1 teaspoon chopped fresh thyme leaves. 3 tablespoons warm clarified butter (recipe follows). 1 pound small pearl onions. 8 whole quail* (5 to 6 ounces each), cleaned and necks and feet removed  if necessary. 1 pound red seedless grapes (about 3 cups). Garnish: fresh thyme leaves. Accompaniment:baked wild rice amandine. unsalted butter, cut into 1-inch pieces. *available at some butcher shops.
# =========
# gluten_free
# Spice-Crusted Salmon with Ginger-Cilantro Yogurt Sauce
# 1/2 cup plain yogurt. 2 tablespoons chopped fresh cilantro. 3 teaspoons fresh lime juice, divided. 3 teaspoons olive oil, divided. 1 teaspoon minced peeled fresh ginger. 1 garlic clove, pressed. 1 teaspoon fennel seeds. 1 teaspoon coriander seeds. 4 6-ounce salmon fillets with skin. Lime wedges.
# =========
# gluten_free
# Flourless Almond Cookies With Cardamom, Orange Zest, and Pistachios
# 1 cup sugar. 1/3 cup virgin coconut oil, softened at room temperature. 1 large egg. 1 tablespoon plus 1 teaspoon finely grated orange zest (from about 2 oranges). 2 cups almond flour. 1/4 cup potato starch. 1 1/2 teaspoons ground cardamom. 1/4 teaspoon kosher salt. 1/2 cup roasted, salted pistachios, finely chopped. 3 ounces dark chocolate (for drizzling; optional).
# =========
# gluten_free
# Cumin-Scented Eggplant with Pomegranate and Cilantro
# 5 cups water. 2 1/2 tablespoons sea salt or coarse kosher salt. 2 pounds eggplant (about 2 medium), cut crosswise into 1/2-inch-thick slices. 1 tablespoon (or more) olive oil. 2 teaspoons ground cumin. 1/8 teaspoon cayenne pepper. 2 garlic cloves, minced. Pomegranate molasses* (for drizzling). 2/3 cup pomegranate seeds. 1/4 cup cilantro leaves.
# =========
# gluten_free
# Lemongrass Tofu with Mushrooms
# Vegetable oil (for frying). 14 ounces firm tofu, drained, cut into 3/4-inch squares. 3 tablespoons vegetable oil. 2 tablespoons minced fresh lemongrass. 2 garlic cloves, minced. 1 teaspoon (heaping) chopped seeded jalapeño chili. 1 onion, thinly sliced. 1/2 red bell pepper, cut into 3/4-inch pieces. 4 ounces shiitake mushrooms, stemmed, thickly sliced. 2 teaspoons fish sauce (nuoc mam)*. 1 tablespoon sugar. 1 1/2 tablespoons chopped fresh cilantro.
# =========
# gluten_free
# Chocolate Panna Cotta with Port- and Balsamic-Glazed Cherries
# Canola oil. 1 cup whole milk. 2 1/4 teaspoons unflavored gelatin. 2 cups whipping cream. 1/2 cup sugar. 5 ounces bittersweet or semisweet chocolate, chopped. 1/2 teaspoon vanilla extract. 1 pound cherries, stemmed, pitted. 3/4 cup ruby Port. 1/2 cup sugar. 2 tablespoons balsamic vinegar.
# =========
# gluten_free
# Spit-Roasted Chicken with Herbs Under the Skin, Garden Vegetables, Toasted Country Bread, and Roasti
# 1 chicken (cleaned), 4 1/2 pounds. 10 1/2 ounces butter. 1 shallot. 7 ounces white mushrooms. 1 bunch of Italian parsley. 1 bunch of chervil. sprig of tarragon. Chives. 1 head of garlic. 4 cups of chicken juices. Salt and freshly ground pepper. 12 white onions (average size). 1 tablespoon of ricotta. 1 tablespoon of parmesan. 1 tablespoon of chopped Italian parsley. 1 small stick of celery. 2 tablespoons of grilled pine nuts. 1 tablespoon of salted pork fat. 2 tablespoons of roasted chicken juices. A little chopped sage. Olive oil. Salt & white pepper. 16 ripe tomatoes. 20 tomato quarters confit (remove the pips and interior). 4 white onions (not too big). 1 tablespoon of chopped parsley. 1 tablespoon of ground basil. 1 tablespoon of grated parmesan. 2 tablespoons of chicken juices. 4 cloves of garlic (unpeeled). 1 sprig of thyme. 1 sprig of rosemary. Olive oil. Salt & pepper.
# =========
# gluten_free
# Moroccan Lamb Kebabs with Golden Couscous
# 3/4 cup olive oil. 2/3 cup fresh lemon juice. 6 large garlic cloves, minced. 2 tablespoons chopped fresh mint. 4 teaspoons salt. 4 teaspoons grated lemon peel. 2 teaspoons ground black pepper. 2 teaspoons ground coriander. 1 teaspoon ground cumin. 4 pounds well-trimmed boneless leg of lamb, cut into 2-inch cubes. 16 12-inch-long metal skewers. 32 whole dried apricots (preferably Mediterranean), soaked in boiling water 5 minutes, drained. 4 red onions, each cut into 8 chunks. Golden Couscous.
# =========
# gluten_free
# Herb and Garlic-Crusted Beef Tenderloin with Red and Yellow Pepper Relish
# 8 tablespoons olive oil. 2 2 1/4- to 2 3/4-pound pieces beef tenderloin (thick end), trimmed. 6 garlic cloves, minced. 2 1/2 tablespoons minced fresh thyme. 2 1/2 tablespoons minced fresh rosemary. 6 tablespoons Dijon mustard. Red and Yellow Pepper Relish.
# =========
# gluten_free
# Spice-Roasted Chickpeas
# 3/4 teaspoon cumin seeds. 3/4 teaspoon coriander seeds. 1 15-to 15 1/2-ounce can chickpeas (garbanzo beans), drained, rinsed, well dried. 1 tablespoon extra-virgin olive oil. Pinch of cayenne pepper. Coarse kosher salt. Test-kitchen tip: To make sure the chickpeas get crunchy, it's important to dry them thoroughly. Spreading them out on paper towels works well..
# =========
# gluten_free
# Tamarind "Teriyaki" Chicken Skewers
# 1 tablespoon tamarind paste (or substitute with pomegranate molasses). 1 tablespoon dark brown sugar. 2 teaspoons unseasoned rice vinegar. 2 teaspoons molasses. 1/4 teaspoon garlic powder. 3 garlic cloves, diced. 3/4 cup water plus 2 tablespoons. 1 tablespoon cornstarch. 2 teaspoons sesame oil. 8 boneless, skinless chicken thighs, cut into 1/2-inch-wide strips. Bamboo skewers. White toasted sesame seeds, for garnish. 2 green onions, thinly sliced (everything but the bulb), for garnish.
# =========
# gluten_free
# Lime and Grapefruit Daiquiri Ice Pops
# 3/4 cup fresh lime juice. 1 1/4 cups sugar, divided. 1/2 cup white rum, divided. 1 1/2 cups fresh grapefruit juice. Twelve 3-ounce ice-pop molds.
# =========
# gluten_free
# Sausage, Cranberry, and Corn Bread Stuffing
# 1 1/2 loavesCorn Bread. 2 cups pecans. 7 leeks (about 1 pound; white and pale green parts only). 3 celery ribs. 3/4 stick (6 tablespoons) unsalted butter. 1/2 pound sweet Italian sausage (about 3 links). 2 cups fresh or unthawed frozen cranberries. 1/4 cup sugar. 1/2 cup packed fresh flat-leafed parsley leaves. 2 cups chicken broth.
# =========
# gluten_free
# Red Wine Mushroom Ragoût
# 1/4 cup vegetable oil. 5 pounds meaty beef neck bones, cut into 2-inch pieces. 1 pound onions, sliced. 7 cups water. 2 750-ml bottles dry red wine. 1 large plum tomato, chopped. 1/8 teaspoon ground cloves. 1/4 cup (1/2 stick) unsalted pareve margarine. 1 cup chopped shallots. 1 large fresh rosemary sprigs. 3 pounds mushrooms, thickly sliced.
# =========
# gluten_free
# Kumquat Champagne Cocktail
# 1 1/4 cups thinly sliced kumquats. 1/3 cup Grand Marnier or other orange liqueur. 1/4 cup sugar. 1 750-ml bottle brut Champagne, well chilled.
# =========
# gluten_free
# Zucchini and Carrots with Green Onions and Dill
# 1 1/2 to 1 3/4 pounds zucchini, trimmed, coarsely grated. 3 tablespoons olive oil. 1 1/2 cups chopped green onions (about 6 large), divided. 1 1/2 pounds carrots (about 5 large), peeled, coarsely grated. 4 tablespoons chopped fresh dill, divided.
# =========
# gluten_free
# Indian Sweet Coconut Dumplings
# 3/4 cup whole milk. 1/2 cup grated dried unsweetened coconut. 1/4 cup packed light brown sugar. 2 tablespoons slivered almonds. 2 tablespoons golden raisins. 1/4teaspoon ground cardamom. About 24 dumpling or wonton wrappers. About 4 cups vegetable oil.
# =========
# gluten_free
# Brandied-Peach Pork Chops
# 4 (1-inch-thick) loin pork chops. 2 tablespoons vegetable oil. 2 tablespoons unsalted butter. 1/2 cup thinly sliced shallots. 1 teaspoon finely chopped thyme. 1/4 cup plus 1 tablespoon brandy, divided. 1 (10-ounce) bag frozen peaches, thawed. 1/3 cup peach preserves.
# =========
# gluten_free
# Spiced Mango-Mojito Sauce
# 2 large mangoes, peeled, pitted, diced. 6 tablespoons plain whole-milk yogurt. 4 tablespoons (or more) sugar. 3 tablespoons spiced rum. 1 tablespoon fresh Key lime juice. 1 1/2 teaspoons (packed) finely chopped fresh mint.
# =========
# gluten_free
# Sliced Tomatoes and Mozzarella with Three-Herb Pesto
# 3 large vine-ripened tomatoes (about 1 1/2 pounds), sliced. 3/4 pound mozzarella cheese (preferably fresh), sliced 1/4 inch thick. 1/2 cup Three-Herb Pesto. freshly ground black pepper to taste. basil, mint, and/or parsley sprigs for garnish if desired.
# =========
# gluten_free
# Triple-Chocolate Cookie and Strawberry Ice Cream Sandwiches
# 1 1/2 cups chopped fresh strawberries. 1/3 cup plus 1/4 cup sugar. 2 tablespoons light corn syrup. 1 cup heavy whipping cream. 1/2 cup whole milk. 4 large egg yolks. 1/4 teaspoon vanilla extract. 16 frozen Triple-Chocolate Cookies.
# =========
# gluten_free
# Grilled Mahi-Mahi Tacos
# 5 plum tomatoes, seeded, chopped. 1/2 small yellow onion, finely chopped. 4 scallions, white and light-green parts only, thinly sliced. 1/2 cup chopped fresh cilantro. 1 teaspoon fresh lemon juice. 1 teaspoon chopped fresh oregano. 1 jalapeño, stemmed, seeded, minced. Kosher salt. freshly ground black pepper. 1/4 cup heavy cream. 2 tablespoons sour cream. Kosher salt. freshly ground black pepper. Hot pepper sauce. 1 tablespoon paprika. 1 teaspoon garlic powder. 1 teaspoon onion powder. 1 teaspoon dried oregano. 1 teaspoon dried thyme. 1 teaspoon kosher salt. 1/2 teaspoon freshly ground black pepper. 1/4 teaspoon cayenne pepper. 1 1-pound mahi-mahi fillet. Vegetable oil (for brushing). 8 6" corn tortillas, warmed. 1 cup finely shredded cabbage. 1 lime, cut into wedges.
# =========
# gluten_free
# Mascarpone Cheesecake with Quince Compote
# 1 1/3 cups pecans, toasted. 1/2 cup walnuts, toasted. 1/2 cup (packed) golden brown sugar. 1/2 cup (1 stick) unsalted butter, melted. 3 1/2 cups whipping cream. 1/4 cup water. 3 1/2 teaspoons unflavored gelatin (from 2 envelopes). 3 1/2 cups plus 2 tablespoons mascarpone cheese* (about 28 1/2 ounces; from four 8-ounce containers). 1 1/4 cups powdered sugar, sifted. Quince Compote.
# =========
# gluten_free
# Chopped Spinach with Toasted Sesame Seeds
# 1/4 cup sesame seeds. 5 large (8- to 9-ounce) bunches fresh spinach, stem ends and roots trimmed, rinsed well. 4 teaspoons oriental sesame oil. 1 tablespoon unseasoned rice vinegar. 1/4 teaspoon hot pepper sauce.
# =========
# gluten_free
# Swiss Chard and Crisp Shallot Rolls with Cilantro Raita
# 1 cup vegetable oil. 1/2 pound shallots, thinly sliced (2 cups). 8 medium Swiss chard leaves, stems trimmed flush with leaves. 1 small garlic clove. 1/2 teaspoon fine sea salt. 1/2 cup chopped fresh cilantro. 1 cup whole-milk yogurt. a deep-fat thermometer.
# =========
# gluten_free
# Iced Almond Latte
# 2 cups plus 1 teaspoon finely ground espresso coffee beans. 3 cups water. 3 tablespoons golden brown sugar. 1 1/2 cups whole milk. 5 teaspoons almond syrup (such as Torani). Ice cubes. Espresso Whipped Cream.
# =========
# gluten_free
# Pineapple-Citrus Juice
# 2 1/2 cups fresh pink grapefruit juice. 2 1/2 cups fresh orange juice. 1 pineapple, peeled, cored, and chopped (about 4 cups).
# =========
# gluten_free
# Clams Casino
# ...
# kosher
# Asparagus Goat Cheese Bruschetta with Porcini Vinaigrette
# 1/2 ounce dried porcini mushrooms. 1 cup boiling water. 1/4 cup sherry vinegar. 1/4 cup minced shallots. 2 teaspoons sugar. 1/4 cup extra-virgin olive oil, plus additional for brushing. 2 bunches (2 pounds) green asparagus (not pencil), ends trimmed to 6 inches. 8 ounces fresh goat cheese, softened. 8 (1/2-inch thick) slices good quality bread, such as pain de mie, pullman or sourdough, crusts trimmed.
# =========
# kosher
# Harvey Wallbanger
# 1 1/2 ounces vodka. 4 ounces orange juice. 1/2 ounce Galliano. 1 orange slice for garnish.
# =========
# kosher
# Cantaloupe Raspberry Shake
# A 2 1/2-pound cantaloupe, seeded and cut into 3/4-inch pieces. 1 pint raspberry sorbet. 1 cup ice cubes.
# =========
# kosher
# Dried Cranberry Compote
# 1 1/2 cups dried cranberries, coarsely chopped. 1 cup cranberry juice cocktail. 1/4 teaspoon vanilla extract. Pinch of salt.
# =========
# kosher
# Southwest Fusilli with Tomatoes, Garlic and Chilies
# 2 3/4 pounds plum tomatoes. 1/3 cup olive oil. 2 tablespoons plus 2 teaspoons minced garlic. 2/3 cup chopped fresh cilantro. 1/3 cup chopped red onion. 2 tablespoons plus 2 teaspoons fresh lime juice. 4 teaspoons minced serrano or jalapeño chilies. 4 teaspoons tomato paste. 2 3/4 teaspoons chili powder. 12 ounces fusilli or other corkscrew pasta. 1 1/3 cups (about 6 ounces) crumbled feta cheese. 1/4 cup chopped fresh cilantro.
# =========
# kosher
# Coffee Custard Sauce
# 3 large egg yolks. 1/4 cup sugar. 1 cup whipping cream. 1 teaspoon instant coffee powder. 1 1/2 teaspoons coarsely ground espresso beans.
# =========
# kosher
# Vegetarian Tagine
# 1 tablespoon olive oil. 1 small onion, diced. 1 garlic clove, minced. 1 stalk celery, diced. 1 carrot, diced. 1 teaspoon paprika. 1/2 teaspoon ground cinnamon. 1/2 teaspoon ground cumin. 1/2 teaspoon fresh ginger, grated or 1/4 teaspoon ground ginger. 2 teaspoons salt. 1 (14.5-ounce) can diced tomatoes. 1 small butternut squash, peeled and cut into chunks (about 2 cups). 2 cups cauliflower florets (1 small head). 2 cups low sodium vegetable broth. 2 cups cooked chickpeas or 1 (15-ounce) can, rinsed and drained. 1/4 cup raisins or currants. 3 cups cooked couscous.
# =========
# kosher
# Turkey Albondigas Soup
# 3/4 pound ground turkey. 1/4 cup packed fresh white breadcrumbs. 1 egg. 1 1/2 teaspoons dried oregano. 8 cups canned low-salt chicken broth. 1 15-ounce can golden hominy, drained. 1 8-ounce can tomato sauce. 3 carrots, peeled, thinly sliced. 1 onion, finely chopped. 1 4-ounce can diced green chilies. 8 ounces coarsely chopped fresh spinach leaves. 1/2 cup chopped fresh cilantro.
# =========
# kosher
# Easy Steak Sauce with Seared Hanger Steak
# 3 tablespoons vegetable oil, divided. 1 medium onion, chopped. 4 garlic cloves, chopped. 1 Fresno chile or red jalapeño, seeded, chopped. Kosher salt, freshly ground pepper. 1 freshly ground pepper. 1 tablespoon tomato paste. 1/2 cup Worcestershire sauce. 1/2 cup red wine vinegar. 1/4 cup (packed) dark brown sugar. 2 tablespoons whole grain mustard. Few dashes of hot sauce. 1 1/2 pounds hanger steak, center membrane removed, cut into 4 pieces.
# =========
# kosher
# Turkey Shawarma with Tomato Relish and Tahini Sauce
# 2 1/2 pounds 1/4-inch-thick turkey cutlets. 2 onions, cut into 1/4-inch-thick rounds. 1 tablespoon turmeric. 2 teaspoons coarse kosher salt. 2 teaspoons ground coriander. 1 teaspoon ground cumin. 1 teaspoon ground black pepper. 1 teaspoon ground white pepper. 1 teaspoon hot paprika or cayenne pepper. 8 tablespoons (about) extra-virgin olive oil, divided. 8 whole pita breads. Tomato Relish. Tahini Sauce. 1 cup thinly sliced pickled eggplant* or sour dill pickles.
# =========
# kosher
# Peach and Berry Salad
# 3 peaches. 2 1/2-pint baskets blackberries. 1 1-pint basket strawberries, hulled, sliced. 1/4 cup honey. 1/2 teaspoon ground cardamom.
# =========
# kosher
# Chris Lilly's Flank Steak and Shiitake Yakitori
# 28 shiitake mushroom caps. 3/4 cup soy sauce. 3/4 cup mirin (rice wine). 1/2 cup sugar. 1/4 cup water. Juice of 1/2 lime. 1 tablespoon chopped fresh cilantro. 1 clove garlic, minced. 3/4 teaspoon peeled, grated fresh ginger. 1/8 teaspoon hot red pepper flakes. 1 (1 1/2-to 2-pound) flank steak. 1 bunch scallion tops. 1 teaspoon salt. 1 teaspoon freshly ground black pepper.
# =========
# kosher
# Green Beans with Sweet and Sour Red Onions
# 1 pound slender green beans, trimmed. 3 tablespoons butter. 1 very large (14- to 16-ounce) red onion, peeled, halved lengthwise, sliced lengthwise. 1 tablespoon chopped fresh marjoram. 1/2 teaspoon dried crushed red pepper. 1/3 cup red wine vinegar. 2 tablespoons (packed) dark brown sugar.
# =========
# kosher
# Ditalini Risotto
# 2 tablespoons unsalted butter. 2 tablespoons garlic oil (see Toasted Garlic-Beef Stock) or olive oil, plus more for drizzling. 1 medium onion, finely chopped. 1 cup dry white wine. 1 pound ditalini or other short, tubular pasta. 6 cups (or more) Toasted Garlic-Beef Stock. 1/2 cup finely grated Pecorino, plus more for serving. Kosher salt. 1 cup baby kale. 1 cup baby mustard greens or other spicy greens. 2 teaspoons freshly ground black pepper.
# =========
# kosher
# Ceviche Clásico (Classic Ceviche)
# 4 x 6-ounce white fish fillets (such as sole, croaker, or grouper). 2 cloves garlic, very finely chopped. 2 teaspoons limo chile (or substitute habanero), chopped. 1 cup key lime or lemon juice. 1 teaspoon chopped cilantro leaves. 2 or 3 ice cubes. 1 red onion, sliced into half-moon crescents. Salt and pepper. 1 corncob, cooked and kernels removed. 1/2 sweet potato, boiled and sliced.
# =========
# kosher
# Barbecue Brisket With Pickled Fennel
# 1 cup (250 ml) apple cider vinegar. 1/2 cup (110 g) white sugar. 5 whole cloves. 1 teaspoon fennel seeds. 1 bulb fennel, trimmed and sliced. 3 teaspoons garlic powder. 3 teaspoons ground coriander. 2 tablespoons smoked paprika. 4 tablespoons dark brown sugar. 5 tablespoons whole black peppercorns. 3/4 cup (100 g) sea salt. 6 lb 10 oz beef brisket. Brioche slider buns, to serve. Apple Slaw, to serve. Lemon wedges, to serve. Aïoli, to serve.
# =========
# kosher
# Garden Vegetable Enchiladas
# 4 tablespoons (1/2 stick) butter. 3 cups coarsely chopped zucchini and/or yellow crookneck squash. 1 cup chopped onion. 1 1/2 cups fresh corn kernels or frozen, thawed. 1 4-ounce can diced mild green chilies. 1/2 cup chopped fresh cilantro. 3 tablespoons chili powder. 2 tablespoons all purpose flour. 1 1/2 teaspoons ground cumin. 2 1/2 cups whole milk. 2 cups (packed) grated Monterey Jack and/or sharp cheddar cheese (about 8 ounces). 8 8-inch warm flour tortillas.
# =========
# kosher
# Mediterranean Salad with Chickpeas and Arugula
# 3 tablespoons red wine vinegar. 2 tablespoons chopped fresh Italian parsley. 2 tablespoons chopped fresh oregano. 1/2 teaspoon grated orange peel. 1/2 teaspoon fennel seeds. 1/2 teaspoon dried crushed red pepper. 1/4 cup extra-virgin olive oil. 1 fennel bulb, halved lengthwise, thinly sliced crosswise. 1 cup cherry tomatoes, halved. 1 8-ounce container small mozzarella balls, drained, halved. 1 15-ounce can chickpeas (garbanzo beans), drained. 1 cup thinly sliced red onion. 4 cups arugula.
# =========
# kosher
# Moroccan-Spiced Lamb Burgers with Beet, Red Onion, and Orange Salsa
# 2 tablespoons olive oil. 2 tablespoons fresh lemon juice. 1 tablespoon honey. 2 beets, boiled, peeled, cut into 1/3-inch cubes. 1 large orange, peel and pith cut away, flesh cut into 1/3-inch cubes. 1 cup chopped red onion. 1/4 cup chopped pitted green Greek olives. 1 large shallot, minced. 2 tablespoons chopped fresh cilantro. 1 jalapeño chile, seeded, minced. 1 garlic clove, minced. 1 1/4 teaspoons salt. 3/4 teaspoon ground black pepper. 1/2 teaspoon paprika. 1/2 teaspoon ground cumin. 1 3/4 pounds ground lamb. Nonstick vegetable oil spray. 4 large cracked-wheat hamburger buns, split horizontally. 1 1/3 cups thinly sliced Bibb lettuce. Mayonnaise.
# =========
# kosher
# Grilled Asian Chicken with Bok Choy, Shiitake Mushrooms, and Radishes
# 8 1/3-inch-thick rounds red onion. 8 large shiitake mushrooms, stemmed. 8 red radishes, trimmed, halved. 4 baby bok choy, halved lengthwise. 1 large orange bell pepper, cut lengthwise into 8 strips. 1 1/4 cups Mango-Sesame Dressing , divided. 6 boneless chicken breast halves with skin. Nonstick vegetable oil spray.
# =========
# kosher
# Seared Asian Steak and Mushrooms on Mixed Greens with Ginger Dressing
# 2 tablespoons soy sauce. 2 tablespoons seasoned rice vinegar. 4 1/2 teaspoons vegetable oil, divided. 1 tablespoon minced peeled fresh ginger. 1/2 teaspoon Asian chili-garlic sauce. 1/8 teaspoon plus 2 teaspoons Asian sesame oil, divided. 1/4 cup chopped fresh cilantro. 2 12-ounce rib-eye steaks. 2 tablespoons toasted sesame seeds. 8 ounces crimini (baby bella) mushrooms, quartered. 8 cups mixed greens.
# =========
# kosher
# Orange Banana Shake
# 1/2 banana, cut into pieces. 1/2 cup fresh orange juice. 1 tablespoon fresh lime juice. 1/4 cup plain yogurt. 1 teaspoon sugar. Garnish: 1 lime slice and 1 orange slice.
# =========
# kosher
# Blue Corn Bread
# 1/4 pound unsalted butter (1 stick). 8 tablespoon shortening. 4 serranos, seeded and minced. 3 garlic cloves, minced. 1 cup all-purpose flour. 1 1/4 cups blue cornmeal. 2 tablespoons sugar. 1 teaspoon baking powder. 1 1/2 teaspoons salt. 3 large eggs. 1 1/4 cups milk, at room temperature. 3 tablespoons chopped fresh cilantro. Olive oil for brushing.
# =========
# kosher
# Caper-Rosemary Tuna with Herb Salad
# 6 tablespoons extra-virgin olive oil. 1/4 cup fresh lemon juice. 2 tablespoons drained capers. 4 teaspoons liquid from capers in jar. 4 teaspoons finely grated lemon peel. 2 teaspoons finely minced fresh rosemary. 1 teaspoon fine sea salt. Large pinch of dried crushed red pepper. Pinch of sugar. 1 small onion, quartered through core, thinly sliced crosswise (1 scant cup). 6 6-to 7-ounce 1-inch-thick tuna steaks. 2 cups (loosely packed) fresh Italian parsley leaves. 1/2 cup (loosely packed) assorted fresh herb leaves (such as tarragon, chervil, oregano, celery leaves, and marjoram). 1 teaspoon extra-virgin olive oil. 1 teaspoon fresh lemon juice.
# =========
# kosher
# Grilled Fish with Cilantro Chutney in Banana Leaves
# 1 (1- by 1 1/2-inch) piece fresh ginger, peeled. 5 garlic cloves. 1 fresh hot green chile such as jalapeño or serrano, trimmed. 1/2 cup chopped fresh coconut (see how to crack and peel fresh coconut ). 3 cups fresh cilantro sprigs. 1/3 cup fresh mint leaves. 1/4 cup white-wine vinegar. 1 teaspoon sugar. 1/4 teaspoon salt, or to taste. 1 (1-pound) package frozen banana leaves, thawed. 6 (6-ounce) pieces white fish fillet (1 inch thick) such as wahoo, cod, or halibut. Special equipment: kitchen string.
# =========
# kosher
# Duck Breast with Sweet Cherry Sauce
# 1 tablespoon extra-virgin olive oil. 1/2 cup chopped onion (1 small). 3 garlic cloves, crushed. 1 tablespoon finely chopped shallot. 1 teaspoon tomato paste. 1/2 teaspoon black pepper. 1/2 teaspoon ground cumin. Scant 1/4 teaspoon dried hot red pepper flakes. 3/4 teaspoon salt. 1/2 cup coarsely chopped red bell pepper (1/2 medium). 1 plum tomato, coarsely chopped. 1/4 cup dry red wine. 1 1/2 to 2 tablespoons cider vinegar. 2 tablespoons sugar. 1/2 teaspoon Dijon mustard. 1 1/4 lb dark sweet cherries such as Bing, quartered and pitted (3 cups). 2 (3/4-lb) boneless Moulard duck breasts with skin*. 2 tablespoons water. 1 tablespoon chopped fresh tarragon or chives. Special equipment: an instant-read thermometer.
# =========
# kosher
# Sweet Tea with Vodka and Lemonade
# 2 large tea bags for iced tea. 1/2 cup boiling water. 8 fresh mint sprigs. 4 cups lemonade made from frozen concentrate. 1/2 cup vodka. Ice cubes. 8 lemon slices.
# =========
# kosher
# Asparagus with Prosciutto di Parma, Pecorino Pepato, and Poached Eggs
# 32 large asparagus spears (about 3 pounds), trimmed and peeled. 8 tablespoons extra-virgin olive oil, preferably unfiltered*. 8 large eggs. 4 teaspoons sea salt. 2 teaspoons freshly ground black pepper. 8 teaspoons freshly squeezed lemon juice (from 1 medium lemon). 8 thin slices proscuitto di Parma (about 4 ounces total). 3 ounces Pecorino Pepato,** finely grated. 2 tablespoons fresh flat-leaf parsley, finely chopped. *Unfiltered olive oil, which has a pronounced olive flavor, can contain small particles of olive skin and may appear cloudy. It can be purchased at specialty shops or williams-sonoma.com.. **Pecorina Pepato is an aged sheep milk's cheese flavored with whole black peppercorns. It is available through murrayscheese.com.. Special equipment: nonstick muffin pan with 12 (1/3-cup) cups.
# =========
# kosher
# Hatch Chile con Queso Dip
# 5 large fresh or 1 cup frozen, defrosted or canned, chopped hatch chiles, drained, squeezed dry. 3 tablespoons unsalted butter. 2 tablespoons grated onion. 3 garlic cloves finely grated using a microplane. 1/2 teaspoon kosher salt. 2 tablespoons all-purpose flour. 1/2 teaspoon ground cumin. 1 1/2 to 2 cups whole milk. 4 cups grated Cheddar cheese (nothing fancy!). 2 cups grated Monterey Jack cheese. 2 plum tomatoes, seeded, diced, drained. Roughly chopped cilantro (for serving). White-corn tortilla chips (for serving).
# =========
# kosher
# Cranberry Winter Pudding
# a 12-ounce bag of fresh cranberries, picked over. 1 firm ripe-pear, peeled, cored, and chopped fine. 3/4 cup firmly packed light brown sugar. 1/2 cup dried sour cherries (available at specialty foods shops) or golden raisins. 1/3 cup finely chopped dried apricots. two 2-inch strips of lemon zest removed with a vegetable peeler. a 3-inch cinnamon stick. 2 cups cranberry juice cocktail. 1/4 teaspoon vanilla. about 10 slices of homemade-type white bread, crusts removed. lightly sweetened whipped cream as an accompaniment.
# =========
# kosher
# Trail Mix Porridge
# 6 cups water. 1 1/2 cups chopped fresh cranberries. 3/4 cup pearled barley. 3/4 cup packed light brown sugar. 1/2 cup walnut pieces, toasted and coarsely ground. 6 tablespoons medium-ground bulgur (or #2). 6 tablespoons corn (or hominy) grits. 6 tablespoons millet. 6 tablespoons maple syrup. 1/2 teaspoon ground cinnamon. 1/4 teaspoon salt.
# =========
# kosher
# Lemongrass Consommé
# 4 stalks fresh lemongrass, root ends trimmed and 1 or 2 outer layers discarded. 1 (4-pound) whole chicken, cleaned and cut into 4 pieces. 2 stalks celery, trimmed and cut into 2-inch lengths. 1 leek (white and pale green parts only), cut into 2-inch lengths and washed well. 1 small white onion, peeled and quartered. 1 (2 1/2-inch-long) piece fresh ginger, peeled. 2 cloves garlic, peeled. 1 fresh or frozen kaffir lime leaf. 1 small whole dried red chile (such as chile de árbol). 1 teaspoon whole black peppercorns. 2 teaspoons kosher salt.
# =========
# kosher
# French Spiced Bread
# 2 tablespoons melted unsalted butter. 1/2 cup whole almonds. 1/2 cup store-bought or homemade candied orange peel. 1/2 cup dried apricots. 1/2 cup dried plums. 2 cups honey. 1 1/4 cups whole milk. 2 teaspoons kosher salt. 6 (3") cinnamon sticks. 3 star anise pods. 3 cups all-purpose flour. 1 tablespoon plus 1 teaspoon baking powder. 1 tablespoon plus 1 teaspoon Reims N.39 spice mix. 2 teaspoons baking soda. 2 large eggs. 2 (9x5") loaf pans.
# =========
# kosher
# Chicken with Olives, Caramelized Onions, and Sage
# 2 3 1/2- to 3 3/4-pound chickens, each cut into quarters, backbones removed. 2 teaspoons ground cumin. 2 teaspoons salt. 2 teaspoons Hungarian sweet paprika. 1 teaspoon turmeric. 2/3 cup olive oil. 1 1/4 pounds white onions, thinly sliced. 1 1/4 pounds red onions, thinly sliced. 1 1/2 tablespoons honey. 1 750-ml bottle dry white wine, divided. 9 large fresh sage leaves. 8 large shallots, peeled. 8 large garlic cloves, peeled. 3 Turkish bay leaves. 3 cups assorted brine-cured Mediterranean olives (such as Kalamata and picholine).
# =========
# kosher
# Mexican Chicken Sliders
# 1 pound ground chicken breast. 1 tablespoons chopped fresh cilantro. 1 teaspoon cumin. 1/2 teaspoon garlic powder. 1/4 teaspoon onion powder. 1 teaspoon salt. 1 large egg. 1 tablespoon oil.
# =========
